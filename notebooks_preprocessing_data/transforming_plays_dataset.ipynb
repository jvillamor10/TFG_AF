# %%
import pandas as pd

# %%
plays = pd.read_csv("raw_data/plays.csv")
plays.head()
# Out:
#        gameId  playId                                    playDescription  \
# 0  2018090600      75  (15:00) M.Ryan pass short right to J.Jones pus...
# 1  2018090600     146  (13:10) M.Ryan pass incomplete short right to ...
# 2  2018090600     168  (13:05) (Shotgun) M.Ryan pass incomplete short...
# 3  2018090600     190  (13:01) (Shotgun) M.Ryan pass deep left to J.J...
# 4  2018090600     256  (10:59) (Shotgun) M.Ryan pass incomplete short...
#
#    quarter  down  yardsToGo possessionTeam        playType yardlineSide  \
# 0        1     1         15            ATL  play_type_pass          ATL
# 1        1     1         10            ATL  play_type_pass          PHI
# 2        1     2         10            ATL  play_type_pass          PHI
# 3        1     3         10            ATL  play_type_pass          PHI
# 4        1     3          1            ATL  play_type_pass          PHI
#
#    yardlineNumber  ... preSnapHomeScore gameClock  absoluteYardlineNumber  \
# 0              20  ...              0.0  15:00:00                    90.0
# 1              39  ...              0.0  13:10:00                    49.0
# 2              39  ...              0.0  13:05:00                    49.0
# 3              39  ...              0.0  13:01:00                    49.0
# 4               1  ...              0.0  10:59:00                    11.0
#
#    penaltyCodes penaltyJerseyNumbers passResult  offensePlayResult  \
# 0           NaN                  NaN          C                 10
# 1           NaN                  NaN          I                  0
# 2           NaN                  NaN          I                  0
# 3           NaN                  NaN          C                 33
# 4           NaN                  NaN          I                  0
#
#    playResult       epa  isDefensivePI
# 0          10  0.261827          False
# 1           0 -0.372360          False
# 2           0 -0.702779          False
# 3          33  3.047530          False
# 4           0 -0.842272          False
#
# [5 rows x 27 columns]

# %%
games = pd.read_csv("raw_data/games.csv")
games.head()
# Out:
#        gameId    gameDate gameTimeEastern homeTeamAbbr visitorTeamAbbr  week
# 0  2018090600  09/06/2018        20:20:00          PHI             ATL     1
# 1  2018090901  09/09/2018        13:00:00          CLE             PIT     1
# 2  2018090902  09/09/2018        13:00:00          IND             CIN     1
# 3  2018090903  09/09/2018        13:00:00          MIA             TEN     1
# 4  2018090900  09/09/2018        13:00:00          BAL             BUF     1

# %%
plays = plays.sort_values(['gameId','playId'])
plays
# Out:
#            gameId  playId                                    playDescription  \
# 0      2018090600      75  (15:00) M.Ryan pass short right to J.Jones pus...
# 1      2018090600     146  (13:10) M.Ryan pass incomplete short right to ...
# 2      2018090600     168  (13:05) (Shotgun) M.Ryan pass incomplete short...
# 3      2018090600     190  (13:01) (Shotgun) M.Ryan pass deep left to J.J...
# 4      2018090600     256  (10:59) (Shotgun) M.Ryan pass incomplete short...
# ...           ...     ...                                                ...
# 18417  2018123015    3819  (5:42) J.Rosen pass short middle to C.Williams...
# 18418  2018123015    3932  (2:27) (Shotgun) J.Rosen sacked at SEA 37 for ...
# 18419  2018123015    3969  (2:00) (Shotgun) J.Rosen pass incomplete deep ...
# 18420  2018123015    4057  (1:29) (No Huddle, Shotgun) R.Wilson pass shor...
# 18421  2018123015    4104  (1:02) (No Huddle, Shotgun) R.Wilson pass deep...
#
#        quarter  down  yardsToGo possessionTeam        playType yardlineSide  \
# 0            1     1         15            ATL  play_type_pass          ATL
# 1            1     1         10            ATL  play_type_pass          PHI
# 2            1     2         10            ATL  play_type_pass          PHI
# 3            1     3         10            ATL  play_type_pass          PHI
# 4            1     3          1            ATL  play_type_pass          PHI
# ...        ...   ...        ...            ...             ...          ...
# 18417        4     1         10            ARI  play_type_pass          ARI
# 18418        4     2          9            ARI  play_type_sack          SEA
# 18419        4     3         12            ARI  play_type_pass          SEA
# 18420        4     2          6            SEA  play_type_pass          SEA
# 18421        4     1         10            SEA  play_type_pass          SEA
#
#        yardlineNumber  ... preSnapHomeScore gameClock  absoluteYardlineNumber  \
# 0                  20  ...              0.0  15:00:00                    90.0
# 1                  39  ...              0.0  13:10:00                    49.0
# 2                  39  ...              0.0  13:05:00                    49.0
# 3                  39  ...              0.0  13:01:00                    49.0
# 4                   1  ...              0.0  10:59:00                    11.0
# ...               ...  ...              ...       ...                     ...
# 18417              43  ...             24.0  05:42:00                    67.0
# 18418              34  ...             24.0  02:27:00                    44.0
# 18419              37  ...             24.0  02:00:00                    47.0
# 18420              29  ...             24.0  01:29:00                    39.0
# 18421              38  ...             24.0  01:02:00                    48.0
#
#        penaltyCodes penaltyJerseyNumbers passResult  offensePlayResult  \
# 0               NaN                  NaN          C                 10
# 1               NaN                  NaN          I                  0
# 2               NaN                  NaN          I                  0
# 3               NaN                  NaN          C                 33
# 4               NaN                  NaN          I                  0
# ...             ...                  ...        ...                ...
# 18417           NaN                  NaN          C                 12
# 18418           NaN                  NaN          S                 -3
# 18419           NaN                  NaN          I                  0
# 18420           NaN                  NaN          C                  5
# 18421           NaN                  NaN          C                 37
#
#        playResult       epa  isDefensivePI
# 0              10  0.261827          False
# 1               0 -0.372360          False
# 2               0 -0.702779          False
# 3              33  3.047530          False
# 4               0 -0.842272          False
# ...           ...       ...            ...
# 18417          12  0.732852          False
# 18418          -3 -0.750672          False
# 18419           0 -0.944168          False
# 18420           5 -0.254137          False
# 18421          37  1.827072          False
#
# [19239 rows x 27 columns]

# %%
plays.reset_index(inplace=True)

# %% [markdown]
# Cambiar los ids por el nuevo

# %%
id_list = []
for index,row in plays.iterrows():
    game = row["gameId"]
    play = row["playId"]
    week = games[games["gameId"]==game]["week"].values[0]
    id_list.append(str(game) + ":" + str(play) + ":" + str(week))

# %%
plays["id"] = id_list
plays
# Out:
#        index      gameId  playId  \
# 0          0  2018090600      75
# 1          1  2018090600     146
# 2          2  2018090600     168
# 3          3  2018090600     190
# 4          4  2018090600     256
# ...      ...         ...     ...
# 19234  18417  2018123015    3819
# 19235  18418  2018123015    3932
# 19236  18419  2018123015    3969
# 19237  18420  2018123015    4057
# 19238  18421  2018123015    4104
#
#                                          playDescription  quarter  down  \
# 0      (15:00) M.Ryan pass short right to J.Jones pus...        1     1
# 1      (13:10) M.Ryan pass incomplete short right to ...        1     1
# 2      (13:05) (Shotgun) M.Ryan pass incomplete short...        1     2
# 3      (13:01) (Shotgun) M.Ryan pass deep left to J.J...        1     3
# 4      (10:59) (Shotgun) M.Ryan pass incomplete short...        1     3
# ...                                                  ...      ...   ...
# 19234  (5:42) J.Rosen pass short middle to C.Williams...        4     1
# 19235  (2:27) (Shotgun) J.Rosen sacked at SEA 37 for ...        4     2
# 19236  (2:00) (Shotgun) J.Rosen pass incomplete deep ...        4     3
# 19237  (1:29) (No Huddle, Shotgun) R.Wilson pass shor...        4     2
# 19238  (1:02) (No Huddle, Shotgun) R.Wilson pass deep...        4     1
#
#        yardsToGo possessionTeam        playType yardlineSide  ...  gameClock  \
# 0             15            ATL  play_type_pass          ATL  ...   15:00:00
# 1             10            ATL  play_type_pass          PHI  ...   13:10:00
# 2             10            ATL  play_type_pass          PHI  ...   13:05:00
# 3             10            ATL  play_type_pass          PHI  ...   13:01:00
# 4              1            ATL  play_type_pass          PHI  ...   10:59:00
# ...          ...            ...             ...          ...  ...        ...
# 19234         10            ARI  play_type_pass          ARI  ...   05:42:00
# 19235          9            ARI  play_type_sack          SEA  ...   02:27:00
# 19236         12            ARI  play_type_pass          SEA  ...   02:00:00
# 19237          6            SEA  play_type_pass          SEA  ...   01:29:00
# 19238         10            SEA  play_type_pass          SEA  ...   01:02:00
#
#       absoluteYardlineNumber penaltyCodes  penaltyJerseyNumbers  passResult  \
# 0                       90.0          NaN                   NaN           C
# 1                       49.0          NaN                   NaN           I
# 2                       49.0          NaN                   NaN           I
# 3                       49.0          NaN                   NaN           C
# 4                       11.0          NaN                   NaN           I
# ...                      ...          ...                   ...         ...
# 19234                   67.0          NaN                   NaN           C
# 19235                   44.0          NaN                   NaN           S
# 19236                   47.0          NaN                   NaN           I
# 19237                   39.0          NaN                   NaN           C
# 19238                   48.0          NaN                   NaN           C
#
#       offensePlayResult playResult       epa  isDefensivePI  \
# 0                    10         10  0.261827          False
# 1                     0          0 -0.372360          False
# 2                     0          0 -0.702779          False
# 3                    33         33  3.047530          False
# 4                     0          0 -0.842272          False
# ...                 ...        ...       ...            ...
# 19234                12         12  0.732852          False
# 19235                -3         -3 -0.750672          False
# 19236                 0          0 -0.944168          False
# 19237                 5          5 -0.254137          False
# 19238                37         37  1.827072          False
#
#                        id
# 0         2018090600:75:1
# 1        2018090600:146:1
# 2        2018090600:168:1
# 3        2018090600:190:1
# 4        2018090600:256:1
# ...                   ...
# 19234  2018123015:3819:17
# 19235  2018123015:3932:17
# 19236  2018123015:3969:17
# 19237  2018123015:4057:17
# 19238  2018123015:4104:17
#
# [19239 rows x 29 columns]

# %%
plays.columns
# Out:
# Index(['index', 'gameId', 'playId', 'playDescription', 'quarter', 'down',
#        'yardsToGo', 'possessionTeam', 'playType', 'yardlineSide',
#        'yardlineNumber', 'offenseFormation', 'personnelO', 'defendersInTheBox',
#        'numberOfPassRushers', 'personnelD', 'typeDropback',
#        'preSnapVisitorScore', 'preSnapHomeScore', 'gameClock',
#        'absoluteYardlineNumber', 'penaltyCodes', 'penaltyJerseyNumbers',
#        'passResult', 'offensePlayResult', 'playResult', 'epa', 'isDefensivePI',
#        'id'],
#       dtype='object')

# %%
plays.drop(["gameId","playId"],axis=1,inplace=True)
plays = plays[['id', 'playDescription', 'quarter', 'down', 'yardsToGo',
       'possessionTeam', 'playType', 'yardlineSide', 'yardlineNumber',
       'offenseFormation', 'personnelO', 'defendersInTheBox',
       'numberOfPassRushers', 'personnelD', 'typeDropback',
       'preSnapVisitorScore', 'preSnapHomeScore', 'gameClock',
       'absoluteYardlineNumber', 'penaltyCodes', 'penaltyJerseyNumbers',
       'passResult', 'offensePlayResult', 'playResult', 'epa', 'isDefensivePI']]
plays
# Out:
#                        id                                    playDescription  \
# 0         2018090600:75:1  (15:00) M.Ryan pass short right to J.Jones pus...
# 1        2018090600:146:1  (13:10) M.Ryan pass incomplete short right to ...
# 2        2018090600:168:1  (13:05) (Shotgun) M.Ryan pass incomplete short...
# 3        2018090600:190:1  (13:01) (Shotgun) M.Ryan pass deep left to J.J...
# 4        2018090600:256:1  (10:59) (Shotgun) M.Ryan pass incomplete short...
# ...                   ...                                                ...
# 19234  2018123015:3819:17  (5:42) J.Rosen pass short middle to C.Williams...
# 19235  2018123015:3932:17  (2:27) (Shotgun) J.Rosen sacked at SEA 37 for ...
# 19236  2018123015:3969:17  (2:00) (Shotgun) J.Rosen pass incomplete deep ...
# 19237  2018123015:4057:17  (1:29) (No Huddle, Shotgun) R.Wilson pass shor...
# 19238  2018123015:4104:17  (1:02) (No Huddle, Shotgun) R.Wilson pass deep...
#
#        quarter  down  yardsToGo possessionTeam        playType yardlineSide  \
# 0            1     1         15            ATL  play_type_pass          ATL
# 1            1     1         10            ATL  play_type_pass          PHI
# 2            1     2         10            ATL  play_type_pass          PHI
# 3            1     3         10            ATL  play_type_pass          PHI
# 4            1     3          1            ATL  play_type_pass          PHI
# ...        ...   ...        ...            ...             ...          ...
# 19234        4     1         10            ARI  play_type_pass          ARI
# 19235        4     2          9            ARI  play_type_sack          SEA
# 19236        4     3         12            ARI  play_type_pass          SEA
# 19237        4     2          6            SEA  play_type_pass          SEA
# 19238        4     1         10            SEA  play_type_pass          SEA
#
#        yardlineNumber offenseFormation  ... preSnapHomeScore  gameClock  \
# 0                  20           I_FORM  ...              0.0   15:00:00
# 1                  39       SINGLEBACK  ...              0.0   13:10:00
# 2                  39          SHOTGUN  ...              0.0   13:05:00
# 3                  39          SHOTGUN  ...              0.0   13:01:00
# 4                   1          SHOTGUN  ...              0.0   10:59:00
# ...               ...              ...  ...              ...        ...
# 19234              43       SINGLEBACK  ...             24.0   05:42:00
# 19235              34          SHOTGUN  ...             24.0   02:27:00
# 19236              37          SHOTGUN  ...             24.0   02:00:00
# 19237              29          SHOTGUN  ...             24.0   01:29:00
# 19238              38          SHOTGUN  ...             24.0   01:02:00
#
#        absoluteYardlineNumber penaltyCodes penaltyJerseyNumbers  passResult  \
# 0                        90.0          NaN                  NaN           C
# 1                        49.0          NaN                  NaN           I
# 2                        49.0          NaN                  NaN           I
# 3                        49.0          NaN                  NaN           C
# 4                        11.0          NaN                  NaN           I
# ...                       ...          ...                  ...         ...
# 19234                    67.0          NaN                  NaN           C
# 19235                    44.0          NaN                  NaN           S
# 19236                    47.0          NaN                  NaN           I
# 19237                    39.0          NaN                  NaN           C
# 19238                    48.0          NaN                  NaN           C
#
#        offensePlayResult playResult       epa isDefensivePI
# 0                     10         10  0.261827         False
# 1                      0          0 -0.372360         False
# 2                      0          0 -0.702779         False
# 3                     33         33  3.047530         False
# 4                      0          0 -0.842272         False
# ...                  ...        ...       ...           ...
# 19234                 12         12  0.732852         False
# 19235                 -3         -3 -0.750672         False
# 19236                  0          0 -0.944168         False
# 19237                  5          5 -0.254137         False
# 19238                 37         37  1.827072         False
#
# [19239 rows x 26 columns]

# %% [markdown]
# Hasta aquí para sacar el nuevo id, nuevo cuaderno para preprocesamiento y tal

# %%
plays.to_csv("processed_data/new_id/plays_new_id.csv")
