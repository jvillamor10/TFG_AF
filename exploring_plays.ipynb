# %%
import pandas as pd
import pickle

# %%
pd.set_option('display.max_columns',None)

# %%
plays = pd.read_csv("processed_data/remove_st_nbt_spikes_strangeplays/plays.csv",index_col=0)
plays.head()
# Out:
#    level_0  index                id  \
# 0        0      0   2018090600:75:1
# 1        1      1  2018090600:146:1
# 2        2      2  2018090600:168:1
# 3        3      3  2018090600:190:1
# 4        4      4  2018090600:256:1
#
#                                      playDescription  quarter  down  \
# 0  (15:00) M.Ryan pass short right to J.Jones pus...        1     1
# 1  (13:10) M.Ryan pass incomplete short right to ...        1     1
# 2  (13:05) (Shotgun) M.Ryan pass incomplete short...        1     2
# 3  (13:01) (Shotgun) M.Ryan pass deep left to J.J...        1     3
# 4  (10:59) (Shotgun) M.Ryan pass incomplete short...        1     3
#
#    yardsToGo possessionTeam        playType yardlineSide  yardlineNumber  \
# 0         15            ATL  play_type_pass          ATL              20
# 1         10            ATL  play_type_pass          PHI              39
# 2         10            ATL  play_type_pass          PHI              39
# ...

# %%
plays.isnull().sum()
# Out:
# level_0                       0
# index                         0
# id                            0
# playDescription               0
# quarter                       0
# down                          0
# yardsToGo                     0
# possessionTeam                0
# playType                      0
# yardlineSide                251
# yardlineNumber                0
# offenseFormation             46
# personnelO                   29
# defendersInTheBox            46
# numberOfPassRushers         632
# personnelD                   29
# typeDropback                637
# preSnapVisitorScore         637
# preSnapHomeScore            637
# gameClock                   637
# absoluteYardlineNumber        0
# penaltyCodes              17861
# penaltyJerseyNumbers      17861
# passResult                    2
# offensePlayResult             0
# playResult                    0
# epa                           0
# isDefensivePI                 0
# dtype: int64

# %%
plays[plays["offenseFormation"].isnull()]
# Out:
#        level_0  index                  id  \
# 22          22     22   2018090600:1226:1
# 382        383    383   2018090903:2348:1
# 518        519    519   2018090906:1188:1
# 1345      1349   1349   2018091602:2823:2
# 1795      1802   1803   2018091608:1254:2
# 2069      2078   2079   2018091611:3501:2
# 2645      2659   2661    2018092303:950:3
# 2687      2702   2704   2018092303:3099:3
# 2865      2881   2884   2018092306:1098:3
# 3489      3506   3511   2018092400:2237:3
# 3688      3705   3711   2018093000:3462:4
# 5010      5031   5040   2018100701:3541:5
# 5224      5248   5257   2018100704:1490:5
# 5829      5857   5866   2018100711:2987:5
# 7032      7064   7076   2018101412:2923:6
# 7309      7342   7355   2018102101:3078:7
# 8213      8247   8261   2018102500:2679:8
# 8413      8447   8461   2018102802:1801:8
# 8621      8656   8670    2018102805:983:8
# 8861      8897   8911    2018102808:544:8
# 9088      9124   9143   2018102811:1719:8
# ...

# %% [markdown]
# Take care with spikes

# %%
plays["offenseFormation"].unique()
# Out:
# array(['I_FORM', 'SINGLEBACK', 'SHOTGUN', 'EMPTY', nan, 'PISTOL',
#        'WILDCAT', 'JUMBO'], dtype=object)

# %%
plays[plays["offenseFormation"].isnull()]["id"].values

# %%
pickle_file = open('resources/no_one_qb.pickle','wb')
pickle.dump(no_one_qb,pickle_file)
pickle_file.close()

# %%
plays[plays["personnelO"].isnull()]
# Out:
#        level_0  index                  id  \
# 518        519    519   2018090906:1188:1
# 1345      1349   1349   2018091602:2823:2
# 2069      2078   2079   2018091611:3501:2
# 2645      2659   2661    2018092303:950:3
# 2687      2702   2704   2018092303:3099:3
# 2865      2881   2884   2018092306:1098:3
# 5010      5031   5040   2018100701:3541:5
# 5224      5248   5257   2018100704:1490:5
# 5829      5857   5866   2018100711:2987:5
# 7032      7064   7076   2018101412:2923:6
# 8213      8247   8261   2018102500:2679:8
# 8413      8447   8461   2018102802:1801:8
# 8621      8656   8670    2018102805:983:8
# 8861      8897   8911    2018102808:544:8
# 9957      9997  10020   2018110408:3533:9
# 10093    10134  10157   2018110410:2201:9
# 10545    10588  10611  2018111103:3323:10
# 11537    11585  11611  2018111803:1789:11
# 12619    12675  12704  2018112503:1519:12
# 13490    13549  13582  2018120202:3380:13
# 13503    13562  13595  2018120202:4053:13
# ...

# %%
f = open("resources/missingpersonnelO.txt","w")
for index,row in plays[plays["personnelO"].isnull()].iterrows():
    f.write(row["id"])
    f.write("\n")
f.close()

# %%
plays[plays["defendersInTheBox"].isnull()]
# Out:
#        level_0  index                  id  \
# 22          22     22   2018090600:1226:1
# 382        383    383   2018090903:2348:1
# 518        519    519   2018090906:1188:1
# 1345      1349   1349   2018091602:2823:2
# 1795      1802   1803   2018091608:1254:2
# 2069      2078   2079   2018091611:3501:2
# 2645      2659   2661    2018092303:950:3
# 2687      2702   2704   2018092303:3099:3
# 2865      2881   2884   2018092306:1098:3
# 3489      3506   3511   2018092400:2237:3
# 3688      3705   3711   2018093000:3462:4
# 5010      5031   5040   2018100701:3541:5
# 5224      5248   5257   2018100704:1490:5
# 5829      5857   5866   2018100711:2987:5
# 7032      7064   7076   2018101412:2923:6
# 8213      8247   8261   2018102500:2679:8
# 8413      8447   8461   2018102802:1801:8
# 8621      8656   8670    2018102805:983:8
# 8861      8897   8911    2018102808:544:8
# 9088      9124   9143   2018102811:1719:8
# 9340      9378   9397   2018110400:2974:9
# ...

# %%
f = open("resources/missingdefendersInTheBox.txt","w")
for index,row in plays[plays["defendersInTheBox"].isnull()].iterrows():
    f.write(row["id"])
    f.write("\n")
f.close()

# %%
plays[plays["personnelD"].isnull()]
# Out:
#        level_0  index                  id  \
# 518        519    519   2018090906:1188:1
# 1345      1349   1349   2018091602:2823:2
# 2069      2078   2079   2018091611:3501:2
# 2645      2659   2661    2018092303:950:3
# 2687      2702   2704   2018092303:3099:3
# 2865      2881   2884   2018092306:1098:3
# 5010      5031   5040   2018100701:3541:5
# 5224      5248   5257   2018100704:1490:5
# 5829      5857   5866   2018100711:2987:5
# 7032      7064   7076   2018101412:2923:6
# 8213      8247   8261   2018102500:2679:8
# 8413      8447   8461   2018102802:1801:8
# 8621      8656   8670    2018102805:983:8
# 8861      8897   8911    2018102808:544:8
# 9957      9997  10020   2018110408:3533:9
# 10093    10134  10157   2018110410:2201:9
# 10545    10588  10611  2018111103:3323:10
# 11537    11585  11611  2018111803:1789:11
# 12619    12675  12704  2018112503:1519:12
# 13490    13549  13582  2018120202:3380:13
# 13503    13562  13595  2018120202:4053:13
# ...

# %%
f = open("resources/missingpersonnelD.txt","w")
for index,row in plays[plays["personnelD"].isnull()].iterrows():
    f.write(row["id"])
    f.write("\n")
f.close()

# %%
plays[plays["numberOfPassRushers"].notnull()]
# Out:
#        level_0  index                  id  \
# 0            0      0     2018090600:75:1
# 1            1      1    2018090600:146:1
# 2            2      2    2018090600:168:1
# 3            3      3    2018090600:190:1
# 4            4      4    2018090600:256:1
# ...        ...    ...                 ...
# 19112    19187  19234  2018123015:3819:17
# 19113    19188  19235  2018123015:3932:17
# 19114    19189  19236  2018123015:3969:17
# 19115    19190  19237  2018123015:4057:17
# 19116    19191  19238  2018123015:4104:17
#
#                                          playDescription  quarter  down  \
# 0      (15:00) M.Ryan pass short right to J.Jones pus...        1     1
# 1      (13:10) M.Ryan pass incomplete short right to ...        1     1
# 2      (13:05) (Shotgun) M.Ryan pass incomplete short...        1     2
# 3      (13:01) (Shotgun) M.Ryan pass deep left to J.J...        1     3
# 4      (10:59) (Shotgun) M.Ryan pass incomplete short...        1     3
# ...

# %%
plays[plays["passResult"].isnull()]
# Out:
#       index                 id  \
# 5430   5439   2018100706:690:5
# 7952   7965  2018102109:2662:7
#
#                                         playDescription  quarter  down  \
# 5430  (3:08) R.Freeman up the middle to DEN 20 for n...        1     1
# 7952  (9:07) (Shotgun) D.Johnson left guard to CLV 2...        3     1
#
#       yardsToGo possessionTeam           playType yardlineSide  \
# 5430         10            DEN  play_type_unknown          DEN
# 7952         10            CLE  play_type_unknown          CLE
#
#       yardlineNumber  ... preSnapHomeScore gameClock  absoluteYardlineNumber  \
# 5430              20  ...              NaN       NaN                     NaN
# 7952              29  ...              NaN       NaN                     NaN
#
#       penaltyCodes penaltyJerseyNumbers passResult  offensePlayResult  \
# 5430            DH               NYJ 99        NaN                  0
# 7952            DH                TB 56        NaN                 -2
#
# ...

# %%
plays[plays["penaltyCodes"].notnull()]
# Out:
#        index                  id  \
# 22        22   2018090600:1226:1
# 26        26   2018090600:1473:1
# 30        30   2018090600:1680:1
# 31        31   2018090600:1715:1
# 43        43   2018090600:2305:1
# ...      ...                 ...
# 19090  19137  2018123014:2170:17
# 19105  19152  2018123014:2855:17
# 19110  19157  2018123014:3359:17
# 19120  19167  2018123014:3870:17
# 19172  19219  2018123015:2742:17
#
#                                          playDescription  quarter  down  \
# 22     (8:23) (Shotgun) N.Foles pass incomplete short...        2     3
# 26     (4:20) M.Ryan pass short left to M.Sanu to PHI...        2     2
# 30     (1:57) (Shotgun) N.Foles pass short right to N...        2     2
# 31     (1:50) (Shotgun) N.Foles pass short right to N...        2     1
# 43     (13:44) (Shotgun) N.Foles pass incomplete shor...        3     1
# ...                                                  ...      ...   ...
# ...
