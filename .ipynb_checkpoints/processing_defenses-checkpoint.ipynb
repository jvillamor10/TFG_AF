# %%
import pandas as pd

# %%
defenses = pd.read_csv("weeks_frame1/frame1_process/defense_players_plays.csv")
defenses.head()
# Out:
#    Unnamed: 0      x      y     s     a   dis       o     dir      nflId  \
# 0           1  88.89  36.47  0.01  0.01  0.01  105.63   66.66    79848.0
# 1           3  86.31  22.01  0.09  0.42  0.01   70.12  168.91  2495613.0
# 2           5  73.64  28.70  0.03  0.02  0.01  103.05  219.41  2534832.0
# 3           7  86.48  31.12  0.09  0.03  0.04   95.90   33.36  2552315.0
# 4           8  82.67  20.53  0.03  0.07  0.01   81.14  174.57  2552689.0
#
#        displayName  jerseyNumber position  team playDirection               id
# 0  Malcolm Jenkins          27.0       SS  home          left  2018090600:75:1
# 1     Corey Graham          24.0       FS  home          left  2018090600:75:1
# 2    Rodney McLeod          23.0       FS  home          left  2018090600:75:1
# 3     Jordan Hicks          58.0      MLB  home          left  2018090600:75:1
# 4     Ronald Darby          21.0       CB  home          left  2018090600:75:1

# %%
plays = pd.read_csv("raw_data/plays.csv")
plays.head()
# Out:
#        gameId  playId                                    playDescription  \
# 0  2018090600      75  (15:00) M.Ryan pass short right to J.Jones pus...
# 1  2018090600     146  (13:10) M.Ryan pass incomplete short right to ...
# 2  2018090600     168  (13:05) (Shotgun) M.Ryan pass incomplete short...
# 3  2018090600     190  (13:01) (Shotgun) M.Ryan pass deep left to J.J...
# 4  2018090600     256  (10:59) (Shotgun) M.Ryan pass incomplete short...
#
#    quarter  down  yardsToGo possessionTeam        playType yardlineSide  \
# 0        1     1         15            ATL  play_type_pass          ATL
# 1        1     1         10            ATL  play_type_pass          PHI
# 2        1     2         10            ATL  play_type_pass          PHI
# 3        1     3         10            ATL  play_type_pass          PHI
# 4        1     3          1            ATL  play_type_pass          PHI
#
#    yardlineNumber  ... preSnapHomeScore gameClock  absoluteYardlineNumber  \
# 0              20  ...              0.0  15:00:00                    90.0
# 1              39  ...              0.0  13:10:00                    49.0
# 2              39  ...              0.0  13:05:00                    49.0
# 3              39  ...              0.0  13:01:00                    49.0
# 4               1  ...              0.0  10:59:00                    11.0
#
#    penaltyCodes penaltyJerseyNumbers passResult  offensePlayResult  \
# 0           NaN                  NaN          C                 10
# 1           NaN                  NaN          I                  0
# 2           NaN                  NaN          I                  0
# 3           NaN                  NaN          C                 33
# 4           NaN                  NaN          I                  0
#
#    playResult       epa  isDefensivePI
# 0          10  0.261827          False
# 1           0 -0.372360          False
# 2           0 -0.702779          False
# 3          33  3.047530          False
# 4           0 -0.842272          False
#
# [5 rows x 27 columns]

# %%
games = pd.read_csv("raw_data/games.csv")
games.head()
# Out:
#        gameId    gameDate gameTimeEastern homeTeamAbbr visitorTeamAbbr  week
# 0  2018090600  09/06/2018        20:20:00          PHI             ATL     1
# 1  2018090901  09/09/2018        13:00:00          CLE             PIT     1
# 2  2018090902  09/09/2018        13:00:00          IND             CIN     1
# 3  2018090903  09/09/2018        13:00:00          MIA             TEN     1
# 4  2018090900  09/09/2018        13:00:00          BAL             BUF     1

# %% [markdown]
# In plays, absoluteYardline is the most important column for now.

# %% [markdown]
# ![title](resources/field.png)

# %% [markdown]
# First we are going to identify how many players are there in the deepzone. We are going to divide the defenses zones like the below picture.

# %% [markdown]
# ![title](resources/zonas_defensivas.jpg)

# %% [markdown]
# The deep zone starts 15 yards from the line of scrimmage. It would be interesting to start with no red zones defenses, and then expand it. So let's identify no red zone defenses.

# %% [markdown]
# The red zone is when the attack team is inside the 20 yard of the opponent team.

# %%
plays_processed = plays.copy()
plays_processed.head()
# Out:
#        gameId  playId                                    playDescription  \
# 0  2018090600      75  (15:00) M.Ryan pass short right to J.Jones pus...
# 1  2018090600     146  (13:10) M.Ryan pass incomplete short right to ...
# 2  2018090600     168  (13:05) (Shotgun) M.Ryan pass incomplete short...
# 3  2018090600     190  (13:01) (Shotgun) M.Ryan pass deep left to J.J...
# 4  2018090600     256  (10:59) (Shotgun) M.Ryan pass incomplete short...
#
#    quarter  down  yardsToGo possessionTeam        playType yardlineSide  \
# 0        1     1         15            ATL  play_type_pass          ATL
# 1        1     1         10            ATL  play_type_pass          PHI
# 2        1     2         10            ATL  play_type_pass          PHI
# 3        1     3         10            ATL  play_type_pass          PHI
# 4        1     3          1            ATL  play_type_pass          PHI
#
#    yardlineNumber  ... preSnapHomeScore gameClock  absoluteYardlineNumber  \
# 0              20  ...              0.0  15:00:00                    90.0
# 1              39  ...              0.0  13:10:00                    49.0
# 2              39  ...              0.0  13:05:00                    49.0
# 3              39  ...              0.0  13:01:00                    49.0
# 4               1  ...              0.0  10:59:00                    11.0
#
#    penaltyCodes penaltyJerseyNumbers passResult  offensePlayResult  \
# 0           NaN                  NaN          C                 10
# 1           NaN                  NaN          I                  0
# 2           NaN                  NaN          I                  0
# 3           NaN                  NaN          C                 33
# 4           NaN                  NaN          I                  0
#
#    playResult       epa  isDefensivePI
# 0          10  0.261827          False
# 1           0 -0.372360          False
# 2           0 -0.702779          False
# 3          33  3.047530          False
# 4           0 -0.842272          False
#
# [5 rows x 27 columns]

# %%
for index,row in plays_processed.iterrows():
    week = games[games["gameId"]==row["gameId"]]["week"][0]
    playId = str(row["gameId"])+":"+str(row["playId"])+":"+str(week)
    direction_play = defenses[defenses["id"]==str(playId)]["playDirection"][0]
    print(direction_play)
    if row["absoluteYardlineNumber"] > 10 and row["absoluteYardlineNumber"] <= 30 and direction_play == "left":
        print("RZ!! on {}".format(playId))
# Out:
# left
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~/.local/lib/python3.9/site-packages/pandas/core/indexes/base.py in get_loc(self, key, method, tolerance)
#    3079             try:
# -> 3080                 return self._engine.get_loc(casted_key)
#    3081             except KeyError as err:
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.Int64HashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.Int64HashTable.get_item()
#
# KeyError: 0
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-39-ca49ac3827e0> in <module>
#       2     week = games[games["gameId"]==row["gameId"]]["week"][0]
#       3     playId = str(row["gameId"])+":"+str(row["playId"])+":"+str(week)
# ----> 4     direction_play = defenses[defenses["id"]==playId]["playDirection"][0]
#       5     print(direction_play)
#       6     if row["absoluteYardlineNumber"] > 10 and row["absoluteYardlineNumber"] <= 30 and direction_play == "left":
#
# ~/.local/lib/python3.9/site-packages/pandas/core/series.py in __getitem__(self, key)
#     851
#     852         elif key_is_scalar:
# --> 853             return self._get_value(key)
#     854
#     855         if is_hashable(key):
#
# ~/.local/lib/python3.9/site-packages/pandas/core/series.py in _get_value(self, label, takeable)
#     959
#     960         # Similar to Index.get_value, but we do not fall back to positional
# --> 961         loc = self.index.get_loc(label)
#     962         return self.index._get_values_for_loc(self, loc, label)
#     963
#
# ~/.local/lib/python3.9/site-packages/pandas/core/indexes/base.py in get_loc(self, key, method, tolerance)
#    3080                 return self._engine.get_loc(casted_key)
#    3081             except KeyError as err:
# -> 3082                 raise KeyError(key) from err
#    3083
#    3084         if tolerance is not None:
#
# KeyError: 0

# %%
week = games[games["gameId"]==2018090600]["week"][0]
print(week)
# Out:
# 1

# %%
defenses[defenses["id"]=="2018090600:75:1"]["playDirection"][0]
# Out:
# 'left'
