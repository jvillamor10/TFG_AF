# %%
import pandas as pd

# %%
plays = pd.read_csv("raw_data/plays.csv")
plays
# Out:
#            gameId  playId                                    playDescription  \
# 0      2018090600      75  (15:00) M.Ryan pass short right to J.Jones pus...
# 1      2018090600     146  (13:10) M.Ryan pass incomplete short right to ...
# 2      2018090600     168  (13:05) (Shotgun) M.Ryan pass incomplete short...
# 3      2018090600     190  (13:01) (Shotgun) M.Ryan pass deep left to J.J...
# 4      2018090600     256  (10:59) (Shotgun) M.Ryan pass incomplete short...
# ...           ...     ...                                                ...
# 19234  2018122200    2300  (7:53) J.Johnson pass incomplete short left [K...
# 19235  2018122200    3177  (6:53) (Shotgun) B.Gabbert pass incomplete sho...
# 19236  2018122201     566  (5:32) (Shotgun) P.Rivers pass deep right to K...
# 19237  2018122201    1719  (1:08) P.Rivers pass incomplete deep middle to...
# 19238  2018122201    2649  (7:16) (Shotgun) L.Jackson pass incomplete sho...
#
#        quarter  down  yardsToGo possessionTeam           playType  \
# 0            1     1         15            ATL     play_type_pass
# 1            1     1         10            ATL     play_type_pass
# 2            1     2         10            ATL     play_type_pass
# 3            1     3         10            ATL     play_type_pass
# 4            1     3          1            ATL     play_type_pass
# ...        ...   ...        ...            ...                ...
# 19234        3     2          5            WAS  play_type_unknown
# 19235        4     3          7            TEN  play_type_unknown
# 19236        1     3          4            LAC  play_type_unknown
# 19237        2     3          1            LAC  play_type_unknown
# 19238        3     1         10            BAL  play_type_unknown
#
#       yardlineSide  yardlineNumber  ... preSnapHomeScore gameClock  \
# 0              ATL              20  ...              0.0  15:00:00
# 1              PHI              39  ...              0.0  13:10:00
# 2              PHI              39  ...              0.0  13:05:00
# 3              PHI              39  ...              0.0  13:01:00
# 4              PHI               1  ...              0.0  10:59:00
# ...            ...             ...  ...              ...       ...
# 19234          WAS              31  ...              NaN       NaN
# 19235          WAS              37  ...              NaN       NaN
# 19236          LAC              49  ...              NaN       NaN
# 19237          LAC              48  ...              NaN       NaN
# 19238          LAC              49  ...              NaN       NaN
#
#        absoluteYardlineNumber  penaltyCodes penaltyJerseyNumbers passResult  \
# 0                        90.0           NaN                  NaN          C
# 1                        49.0           NaN                  NaN          I
# 2                        49.0           NaN                  NaN          I
# 3                        49.0           NaN                  NaN          C
# 4                        11.0           NaN                  NaN          I
# ...                       ...           ...                  ...        ...
# 19234                     NaN            DH               TEN 24          I
# 19235                     NaN            DH               WAS 31          I
# 19236                     NaN           OPI               LAC 13          C
# 19237                     NaN           DPI               BAL 23          I
# 19238                     NaN           DPI               LAC 43          I
#
#        offensePlayResult  playResult       epa  isDefensivePI
# 0                     10          10  0.261827          False
# 1                      0           0 -0.372360          False
# 2                      0           0 -0.702779          False
# 3                     33          33  3.047530          False
# 4                      0           0 -0.842272          False
# ...                  ...         ...       ...            ...
# 19234                  0           5  0.848703          False
# 19235                  0           5  1.227695          False
# 19236                 27         -10 -0.720168          False
# 19237                  0          15  1.336078           True
# 19238                  0           9  0.550256           True
#
# [19239 rows x 27 columns]

# %% [markdown]
# We should eliminate the special teams plays.

# %% [markdown]
# {2: 329,
#  3: 2100,
#  4: 544,
#  5: 1558,
#  8: 1243,
#  9: 1544,
#  10: 2472,
#  11: 1165,
#  12: 2125,
#  13: 1137,
#  14: 1570,
#  15: 3142,
#  17: 2739}

# %%
plays_processed = plays.copy()

# %% [markdown]
# There are three which are repeated in the same week

# %%
plays_processed.drop(plays_processed[(plays_processed["playId"]==2100) & (plays_processed["gameId"]==2018092309)].index,inplace=True)
plays_processed.drop(plays_processed[(plays_processed["playId"]==1243) & (plays_processed["gameId"]==2018102810)].index,inplace=True)
plays_processed.drop(plays_processed[(plays_processed["playId"]==2100) & (plays_processed["gameId"]==2018120200)].index,inplace=True)

# %%
special_teams_plays = {2: 329,
 4: 544,
 5: 1558,
 9: 1544,
 10: 2472,
 11: 1165,
 12: 2125,
 14: 1570,
 15: 3142,
 17: 2739}

# %%
week2 = pd.read_csv("raw_data/week2.csv")
week4 = pd.read_csv("raw_data/week4.csv")
week5 = pd.read_csv("raw_data/week5.csv")
week9 = pd.read_csv("raw_data/week9.csv")
week10 = pd.read_csv("raw_data/week10.csv")
week11 = pd.read_csv("raw_data/week11.csv")
week12 = pd.read_csv("raw_data/week12.csv")
week14 = pd.read_csv("raw_data/week14.csv")
week15 = pd.read_csv("raw_data/week15.csv")
week17 = pd.read_csv("raw_data/week17.csv")

# %%
week2.isnull().any()
# Out:
# time             False
# x                False
# y                False
# s                False
# a                 True
# dis              False
# o                 True
# dir               True
# event            False
# nflId             True
# displayName      False
# jerseyNumber      True
# position          True
# frameId          False
# team             False
# gameId           False
# playId           False
# playDirection    False
# route             True
# dtype: bool

# %%
weeks = [week2,week4,week5,week9,week10,week11,week12,week14,week15,week17]

# %%
games_weeks = {}

# %%
for week,play in zip(weeks,special_teams_plays):
    games_weeks[week[week["playId"]==special_teams_plays[play]]["gameId"].values[0]] = special_teams_plays[play]

# %%
games_weeks
# Out:
# {2018091607: 329,
#  2018093011: 544,
#  2018100700: 1558,
#  2018110402: 1544,
#  2018111104: 2472,
#  2018111808: 1165,
#  2018112509: 2125,
#  2018120901: 1570,
#  2018121611: 3142,
#  2018123012: 2739}

# %%
for play in games_weeks:
    plays_processed.drop(plays_processed[(plays_processed["playId"]==games_weeks[play]) & (plays_processed["gameId"]==play)].index,inplace=True)

# %% [markdown]
# Now all special teams plays are eliminated.

# %%
plays.isnull().any()
# Out:
# gameId                    False
# playId                    False
# playDescription           False
# quarter                   False
# down                      False
# yardsToGo                 False
# possessionTeam            False
# playType                  False
# yardlineSide               True
# yardlineNumber            False
# offenseFormation           True
# personnelO                 True
# defendersInTheBox          True
# numberOfPassRushers        True
# personnelD                 True
# typeDropback               True
# preSnapVisitorScore        True
# preSnapHomeScore           True
# gameClock                  True
# absoluteYardlineNumber     True
# penaltyCodes               True
# penaltyJerseyNumbers       True
# passResult                 True
# offensePlayResult         False
# playResult                False
# epa                       False
# isDefensivePI             False
# dtype: bool

# %% [markdown]
# penaltyCodes can be null, but the others? Let's study each one.

# %%
plays[plays["yardlineSide"].isnull()]
# Out:
#            gameId  playId                                    playDescription  \
# 25     2018090600    1473  (4:20) M.Ryan pass short left to M.Sanu to PHI...
# 95     2018090901     613  (6:24) (Shotgun) B.Roethlisberger pass incompl...
# 96     2018090901     635  (6:19) (No Huddle, Shotgun) B.Roethlisberger p...
# 312    2018090903    3485  (8:12) B.Gabbert pass incomplete short right t...
# 313    2018090903    3507  (8:07) (Shotgun) B.Gabbert pass short right to...
# ...           ...     ...                                                ...
# 18861  2018102101    3572  (3:47) (Shotgun) J.Flacco pass incomplete shor...
# 18885  2018102801    1899  (1:11) (Shotgun) J.Flacco pass short left to W...
# 18937  2018111103     612  (4:38) (Shotgun) B.Osweiler pass incomplete sh...
# 19066  2018120212    3149  (14:06) (Shotgun) T.Brady pass incomplete deep...
# 19117  2018120911    3612  (6:07) M.Stafford pass incomplete deep right t...
#
#        quarter  down  yardsToGo possessionTeam           playType  \
# 25           2     2          9            ATL     play_type_pass
# 95           1     1         10            PIT     play_type_pass
# 96           1     2         10            PIT     play_type_pass
# 312          4     2          3            TEN     play_type_pass
# 313          4     3          3            TEN     play_type_pass
# ...        ...   ...        ...            ...                ...
# 18861        4     4          7            BAL  play_type_unknown
# 18885        2     3          7            BAL  play_type_unknown
# 18937        1     1         10            MIA  play_type_unknown
# 19066        4     1         10             NE  play_type_unknown
# 19117        4     1         10            DET  play_type_unknown
#
#       yardlineSide  yardlineNumber  ... preSnapHomeScore gameClock  \
# 25             NaN              50  ...              3.0  04:20:00
# 95             NaN              50  ...              0.0  06:24:00
# 96             NaN              50  ...              0.0  06:19:00
# 312            NaN              50  ...             24.0  08:12:00
# 313            NaN              50  ...             24.0  08:07:00
# ...            ...             ...  ...              ...       ...
# 18861          NaN              50  ...              NaN       NaN
# 18885          NaN              50  ...              NaN       NaN
# 18937          NaN              50  ...              NaN       NaN
# 19066          NaN              50  ...              NaN       NaN
# 19117          NaN              50  ...              NaN       NaN
#
#        absoluteYardlineNumber  penaltyCodes penaltyJerseyNumbers passResult  \
# 25                       60.0           RPS               PHI 56          C
# 95                       60.0           NaN                  NaN          I
# 96                       60.0           NaN                  NaN          I
# 312                      60.0           NaN                  NaN          I
# 313                      60.0           NaN                  NaN          C
# ...                       ...           ...                  ...        ...
# 18861                     NaN           DPI                NO 26          I
# 18885                     NaN           OPI               BAL 83          C
# 18937                     NaN            DH                GB 26          I
# 19066                     NaN           DPI               MIN 24          I
# 19117                     NaN           DPI               ARI 36          I
#
#        offensePlayResult  playResult       epa  isDefensivePI
# 25                     8          23  1.651961          False
# 95                     0           0 -0.478473          False
# 96                     0           0 -0.874054          False
# 312                    0           0 -0.802575          False
# 313                    3           3  1.420129          False
# ...                  ...         ...       ...            ...
# 18861                  0          10  3.075807           True
# 18885                  9         -10 -0.375941          False
# 18937                  0           5  0.319275          False
# 19066                  0          20  1.165725           True
# 19117                  0          25  1.440287           True
#
# [254 rows x 27 columns]

# %% [markdown]
# There are some play types as unknown, this is interesting.

# %%
plays["playType"].unique()
# Out:
# array(['play_type_pass', 'play_type_sack', 'play_type_unknown'],
#       dtype=object)

# %% [markdown]
# This is something reasonable, when you pass there are two actions: you pass the ball or the defenders sacks you. The unknown play type is something rare.

# %%
plays[plays["playType"]=="play_type_unknown"]
# Out:
#            gameId  playId                                    playDescription  \
# 18606  2018090600    1226  (8:23) (Shotgun) N.Foles pass incomplete short...
# 18607  2018090600    1715  (1:50) (Shotgun) N.Foles pass short right to N...
# 18608  2018090600    2305  (13:44) (Shotgun) N.Foles pass incomplete shor...
# 18609  2018090600    3626  (8:31) (Shotgun) N.Foles pass short right to N...
# 18610  2018090600    4439  (:06) (Shotgun) M.Ryan pass incomplete short r...
# ...           ...     ...                                                ...
# 19234  2018122200    2300  (7:53) J.Johnson pass incomplete short left [K...
# 19235  2018122200    3177  (6:53) (Shotgun) B.Gabbert pass incomplete sho...
# 19236  2018122201     566  (5:32) (Shotgun) P.Rivers pass deep right to K...
# 19237  2018122201    1719  (1:08) P.Rivers pass incomplete deep middle to...
# 19238  2018122201    2649  (7:16) (Shotgun) L.Jackson pass incomplete sho...
#
#        quarter  down  yardsToGo possessionTeam           playType  \
# 18606        2     3          7            PHI  play_type_unknown
# 18607        2     1         10            PHI  play_type_unknown
# 18608        3     1         10            PHI  play_type_unknown
# 18609        4     3          4            PHI  play_type_unknown
# 18610        4     4         10            ATL  play_type_unknown
# ...        ...   ...        ...            ...                ...
# 19234        3     2          5            WAS  play_type_unknown
# 19235        4     3          7            TEN  play_type_unknown
# 19236        1     3          4            LAC  play_type_unknown
# 19237        2     3          1            LAC  play_type_unknown
# 19238        3     1         10            BAL  play_type_unknown
#
#       yardlineSide  yardlineNumber  ... preSnapHomeScore gameClock  \
# 18606          ATL              17  ...              NaN       NaN
# 18607          PHI              24  ...              NaN       NaN
# 18608          PHI              36  ...              NaN       NaN
# 18609          PHI              31  ...              NaN       NaN
# 18610          PHI              10  ...              NaN       NaN
# ...            ...             ...  ...              ...       ...
# 19234          WAS              31  ...              NaN       NaN
# 19235          WAS              37  ...              NaN       NaN
# 19236          LAC              49  ...              NaN       NaN
# 19237          LAC              48  ...              NaN       NaN
# 19238          LAC              49  ...              NaN       NaN
#
#        absoluteYardlineNumber  penaltyCodes penaltyJerseyNumbers passResult  \
# 18606                     NaN           DPI               ATL 21          I
# 18607                     NaN            DH               ATL 21          C
# 18608                     NaN           ICT               ATL 23          I
# 18609                     NaN           OPI               PHI 86          C
# 18610                     NaN           ICT               PHI 58          I
# ...                       ...           ...                  ...        ...
# 19234                     NaN            DH               TEN 24          I
# 19235                     NaN            DH               WAS 31          I
# 19236                     NaN           OPI               LAC 13          C
# 19237                     NaN           DPI               BAL 23          I
# 19238                     NaN           DPI               LAC 43          I
#
#        offensePlayResult  playResult       epa  isDefensivePI
# 18606                  0           8  1.169181           True
# 18607                  7           5  0.169598          False
# 18608                  0           5  0.309866          False
# 18609                 10         -10 -0.694743          False
# 18610                  0           5  1.383655          False
# ...                  ...         ...       ...            ...
# 19234                  0           5  0.848703          False
# 19235                  0           5  1.227695          False
# 19236                 27         -10 -0.720168          False
# 19237                  0          15  1.336078           True
# 19238                  0           9  0.550256           True
#
# [633 rows x 27 columns]

# %% [markdown]
# It looks like the unknown play type is related with penaltys, so let's check it.

# %%
unknown_play_type = plays[plays["playType"]=="play_type_unknown"]

# %%
unknown_play_type["penaltyCodes"].isnull().any()
# Out:
# False

# %%
unknown_play_type["penaltyCodes"].unique()
# Out:
# array(['DPI', 'DH', 'ICT', 'OPI', 'RPS', 'DH;OPI', 'DOF;RPS', 'ILM;DH',
#        'DH;DPI', 'DPI;OPI', 'ICT;TAU', 'OH;DH', 'DOF;DPI', 'DPI;FMM',
#        'OH;RPS', 'ICT;ICT', 'DH;UNSd', 'DPI;ILH', 'DH;ING', 'DPI;DH',
#        'DH;DOF', 'DPI;DOF', 'ICT;OPI', 'DPI;ICT;DH', 'OPI;IDP', 'OPI;DH',
#        'OPI;OH', 'RPS;UNR', 'DH;OH', 'ICT;DPI', 'DH;ICT', 'OPI;UNS',
#        'ICT;DH', 'RPS;ICT', 'OH;DH;OH', 'DH;DH', 'OH;DPI', 'TAUd;DH',
#        'OPI;ILF'], dtype=object)

# %%
unknown_play_type.isnull().sum()
# Out:
# gameId                      0
# playId                      0
# playDescription             0
# quarter                     0
# down                        0
# yardsToGo                   0
# possessionTeam              0
# playType                    0
# yardlineSide                9
# yardlineNumber              0
# offenseFormation           46
# personnelO                 29
# defendersInTheBox          46
# numberOfPassRushers       633
# personnelD                 29
# typeDropback              633
# preSnapVisitorScore       633
# preSnapHomeScore          633
# gameClock                 633
# absoluteYardlineNumber    633
# penaltyCodes                0
# penaltyJerseyNumbers        0
# passResult                  2
# offensePlayResult           0
# playResult                  0
# epa                         0
# isDefensivePI               0
# dtype: int64

# %% [markdown]
# So as we thought, every play with the type unknown, has a penalty code, so the unknown play type is a penalty. It would be interesting to change the value.

# %% [markdown]
# The fact is, if we eliminate the unknown plays type, there would be null values?

# %%
pass_sack = plays.drop(unknown_play_type.index)
pass_sack
# Out:
#            gameId  playId                                    playDescription  \
# 0      2018090600      75  (15:00) M.Ryan pass short right to J.Jones pus...
# 1      2018090600     146  (13:10) M.Ryan pass incomplete short right to ...
# 2      2018090600     168  (13:05) (Shotgun) M.Ryan pass incomplete short...
# 3      2018090600     190  (13:01) (Shotgun) M.Ryan pass deep left to J.J...
# 4      2018090600     256  (10:59) (Shotgun) M.Ryan pass incomplete short...
# ...           ...     ...                                                ...
# 18601  2018122201    3842  (2:19) (Shotgun) P.Rivers pass short right to ...
# 18602  2018122201    3884  (2:00) (Shotgun) P.Rivers pass short left to K...
# 18603  2018122201    3909  (1:41) (Shotgun) P.Rivers pass incomplete shor...
# 18604  2018122201    3931  (1:37) (Shotgun) P.Rivers pass incomplete deep...
# 18605  2018122201    3953  (1:31) (Shotgun) P.Rivers pass deep middle int...
#
#        quarter  down  yardsToGo possessionTeam        playType yardlineSide  \
# 0            1     1         15            ATL  play_type_pass          ATL
# 1            1     1         10            ATL  play_type_pass          PHI
# 2            1     2         10            ATL  play_type_pass          PHI
# 3            1     3         10            ATL  play_type_pass          PHI
# 4            1     3          1            ATL  play_type_pass          PHI
# ...        ...   ...        ...            ...             ...          ...
# 18601        4     2          2            LAC  play_type_pass          LAC
# 18602        4     1         10            LAC  play_type_pass          LAC
# 18603        4     1         10            LAC  play_type_pass          BAL
# 18604        4     2         10            LAC  play_type_pass          BAL
# 18605        4     3         10            LAC  play_type_pass          BAL
#
#        yardlineNumber  ... preSnapHomeScore gameClock  absoluteYardlineNumber  \
# 0                  20  ...              0.0  15:00:00                    90.0
# 1                  39  ...              0.0  13:10:00                    49.0
# 2                  39  ...              0.0  13:05:00                    49.0
# 3                  39  ...              0.0  13:01:00                    49.0
# 4                   1  ...              0.0  10:59:00                    11.0
# ...               ...  ...              ...       ...                     ...
# 18601              33  ...             10.0  02:19:00                    77.0
# 18602              40  ...             10.0  02:00:00                    70.0
# 18603              43  ...             10.0  01:41:00                    53.0
# 18604              43  ...             10.0  01:37:00                    53.0
# 18605              43  ...             10.0  01:31:00                    53.0
#
#        penaltyCodes penaltyJerseyNumbers passResult  offensePlayResult  \
# 0               NaN                  NaN          C                 10
# 1               NaN                  NaN          I                  0
# 2               NaN                  NaN          I                  0
# 3               NaN                  NaN          C                 33
# 4               NaN                  NaN          I                  0
# ...             ...                  ...        ...                ...
# 18601           NaN                  NaN          C                  7
# 18602           NaN                  NaN          C                 17
# 18603           NaN                  NaN          I                  0
# 18604           NaN                  NaN          I                  0
# 18605           NaN                  NaN         IN                  0
#
#        playResult       epa  isDefensivePI
# 0              10  0.261827          False
# 1               0 -0.372360          False
# 2               0 -0.702779          False
# 3              33  3.047530          False
# 4               0 -0.842272          False
# ...           ...       ...            ...
# 18601           7  0.460543          False
# 18602          17  0.712741          False
# 18603           0 -0.229687          False
# 18604           0 -0.460746          False
# 18605           0 -2.743690          False
#
# [18606 rows x 27 columns]

# %%
pass_sack.isnull().any()
# Out:
# gameId                    False
# playId                    False
# playDescription           False
# quarter                   False
# down                      False
# yardsToGo                 False
# possessionTeam            False
# playType                  False
# yardlineSide               True
# yardlineNumber            False
# offenseFormation           True
# personnelO                False
# defendersInTheBox          True
# numberOfPassRushers       False
# personnelD                False
# typeDropback               True
# preSnapVisitorScore        True
# preSnapHomeScore           True
# gameClock                  True
# absoluteYardlineNumber     True
# penaltyCodes               True
# penaltyJerseyNumbers       True
# passResult                False
# offensePlayResult         False
# playResult                False
# epa                       False
# isDefensivePI             False
# dtype: bool

# %%
pass_sack.isnull().sum()
# Out:
# gameId                        0
# playId                        0
# playDescription               0
# quarter                       0
# down                          0
# yardsToGo                     0
# possessionTeam                0
# playType                      0
# yardlineSide                245
# yardlineNumber                0
# offenseFormation             95
# personnelO                    0
# defendersInTheBox            16
# numberOfPassRushers           0
# personnelD                    0
# typeDropback                  6
# preSnapVisitorScore           6
# preSnapHomeScore              6
# gameClock                     6
# absoluteYardlineNumber        6
# penaltyCodes              18033
# penaltyJerseyNumbers      18033
# passResult                    0
# offensePlayResult             0
# playResult                    0
# epa                           0
# isDefensivePI                 0
# dtype: int64

# %% [markdown]
# Looking the amounts of null values, there are only 639 plays without the absoluteyardlinenumber, which should be easy to obtain.

# %%
week1 = pd.read_csv("processed_data/weeks_frame1/frame1_raw/week1_frame1.csv")
week2 = pd.read_csv("processed_data/weeks_frame1/frame1_raw/week2_frame1.csv")
week3 = pd.read_csv("processed_data/weeks_frame1/frame1_raw/week3_frame1.csv")
week4 = pd.read_csv("processed_data/weeks_frame1/frame1_raw/week4_frame1.csv")
week5 = pd.read_csv("processed_data/weeks_frame1/frame1_raw/week5_frame1.csv")
week6 = pd.read_csv("processed_data/weeks_frame1/frame1_raw/week6_frame1.csv")
week7 = pd.read_csv("processed_data/weeks_frame1/frame1_raw/week7_frame1.csv")
week8 = pd.read_csv("processed_data/weeks_frame1/frame1_raw/week8_frame1.csv")
week9 = pd.read_csv("processed_data/weeks_frame1/frame1_raw/week9_frame1.csv")
week10 = pd.read_csv("processed_data/weeks_frame1/frame1_raw/week10_frame1.csv")
week11 = pd.read_csv("processed_data/weeks_frame1/frame1_raw/week11_frame1.csv")
week12 = pd.read_csv("processed_data/weeks_frame1/frame1_raw/week12_frame1.csv")
week13 = pd.read_csv("processed_data/weeks_frame1/frame1_raw/week13_frame1.csv")
week14 = pd.read_csv("processed_data/weeks_frame1/frame1_raw/week14_frame1.csv")
week15 = pd.read_csv("processed_data/weeks_frame1/frame1_raw/week15_frame1.csv")
week16 = pd.read_csv("processed_data/weeks_frame1/frame1_raw/week16_frame1.csv")
week17 = pd.read_csv("processed_data/weeks_frame1/frame1_raw/week17_frame1.csv")

# %%
weeks = [week1,week2,week3,week4,week5,week6,week7,week8,week9,week10,week11,week12,week13,week14,week15,week16,week17]

# %%
for week in weeks:
    if week["x"].isnull().any() or week["y"].isnull().any() or week["playDirection"].isnull().any():
        print("Lack of information")

# %% [markdown]
# For x and y, there is no null values, thats very important.

# %%
for week in weeks:
    values = week["id"].unique()
    footballs = week[week["displayName"]=="Football"]
    if len(values) != len(footballs):
        print("not the same")

# %% [markdown]
# every play has the football

# %% [markdown]
# This is because there are some plays which have the same playId

# %%
offense_positions = ['QB','WR','RB','TE','FB','HB']
defense_positions = ['SS','FS','MLB','CB','LB','OLB','ILB','DL','DB','NT','S','DT']

# %%
for week in weeks:
    values = week["id"].unique()

# %%
week1["id"].unique()
# Out:
# array(['2018090600:75:1', '2018090600:146:1', '2018090600:168:1', ...,
#        '2018091001:4123:1', '2018091001:4147:1', '2018091001:4192:1'],
#       dtype=object)
