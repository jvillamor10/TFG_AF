# %%
import pandas as pd
import pickle

from sklearn import preprocessing
from sklearn.decomposition import PCA

# %%
pd.set_option('display.max_columns',None)

# %%
static_defenses = pd.read_csv("../processed_data/transformed_data/static_defenses.csv",index_col="id")
static_defenses.head()
# Out:
#                   Unnamed: 0  defensivelinezonePlayers  deepzonePlayers  \
# id
# 2018090600:75:1            0                         0                1
# 2018090600:146:1           1                         0                1
# 2018090600:168:1           2                         0                1
# 2018090600:190:1           3                         1                0
# 2018090600:320:1           5                         1                0
#
#                   hookzonePlayers  curlzonePlayers  flatzonePlayers  \
# id
# 2018090600:75:1                 3                2                1
# 2018090600:146:1                3                2                1
# 2018090600:168:1                2                2                2
# 2018090600:190:1                2                3                1
# 2018090600:320:1                3                3                1
#
#                   defenseArea  defenseAreaCoverDefenders  width  height  \
# id
# ...

# %%
static_defenses.drop(["Unnamed: 0","playDirection"],axis=1,inplace=True)

# %%
static_defenses.replace({"right":0,"left":1},inplace=True)

# %%
static_defenses
# Out:
#                     defensivelinezonePlayers  deepzonePlayers  \
# id
# 2018090600:75:1                            0                1
# 2018090600:146:1                           0                1
# 2018090600:168:1                           0                1
# 2018090600:190:1                           1                0
# 2018090600:320:1                           1                0
# ...                                      ...              ...
# 2018123015:3819:17                         1                0
# 2018123015:3932:17                         0                0
# 2018123015:3969:17                         0                1
# 2018123015:4057:17                         0                0
# 2018123015:4104:17                         0                0
#
#                     hookzonePlayers  curlzonePlayers  flatzonePlayers  \
# id
# 2018090600:75:1                   3                2                1
# ...

# %%
# static_defenses[static_defenses["strongSide"].isnull()]
# Out:
#                     defensivelinezonePlayers  deepzonePlayers  \
# id
# 2018091604:2116:2                          0                1
# 2018092300:3181:3                          0                1
# 2018092303:2747:3                          2                1
# 2018092309:232:3                           1                1
# 2018093000:1247:4                          1                0
# 2018100701:2290:5                          1                1
# 2018101403:1702:6                          0                1
# 2018102109:2802:7                          0                2
# 2018102808:2624:8                          1                0
# 2018111102:58:10                           0                1
# 2018112200:1459:12                         1                1
# 2018112505:930:12                          1                1
# 2018120902:1696:14                         0                0
# 2018120904:2558:14                         0                0
# ...

# %%
scaler = preprocessing.StandardScaler()
states = scaler.fit_transform(df_1)

# %%
pca = PCA ()
X_pca = pca.fit_transform(static_defenses)
X_pca.shape
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-16-c8cbc0c5a473> in <module>
#       1 pca = PCA ()
# ----> 2 X_pca = pca.fit_transform(static_defenses)
#       3 X_pca.shape
#
# ~/.local/lib/python3.9/site-packages/sklearn/decomposition/_pca.py in fit_transform(self, X, y)
#     381         C-ordered array, use 'np.ascontiguousarray'.
#     382         """
# --> 383         U, S, Vt = self._fit(X)
#     384         U = U[:, :self.n_components_]
#     385
#
# ~/.local/lib/python3.9/site-packages/sklearn/decomposition/_pca.py in _fit(self, X)
#     402                             'TruncatedSVD for a possible alternative.')
#     403
# --> 404         X = self._validate_data(X, dtype=[np.float64, np.float32],
#     405                                 ensure_2d=True, copy=self.copy)
#     406
#
# ...
