# %%
import pandas as pd
import pickle
from shapely.geometry import Polygon
from shapely.geometry import MultiPoint #AMBOS HACEN LO MISMO
from scipy.spatial import ConvexHull  #AMBOS HACEN LO MISMO

# %%
pd.set_option('display.max_columns',None)

# %%
all_plays = pd.read_csv("../processed_data/weeks_frame1/frame1_process/all_players_play.csv",index_col=0)
all_plays.head()
# Out:
#                 id      x      y     s     a   dis       o     dir      nflId  \
# 0  2018090600:75:1  91.73  26.67  0.00  0.01  0.02  289.57  240.93      310.0
# 1  2018090600:75:1  88.89  36.47  0.01  0.01  0.01  105.63   66.66    79848.0
# 2  2018090600:75:1  91.35  44.16  0.02  0.03  0.01  290.45   16.86  2495454.0
# 3  2018090600:75:1  86.31  22.01  0.09  0.42  0.01   70.12  168.91  2495613.0
# 4  2018090600:75:1  90.78  36.15  0.00  0.00  0.00  257.61  193.97  2533040.0
#
#        displayName  jerseyNumber position  team playDirection
# 0        Matt Ryan           2.0       QB  away          left
# 1  Malcolm Jenkins          27.0       SS  home          left
# 2      Julio Jones          11.0       WR  away          left
# 3     Corey Graham          24.0       FS  home          left
# 4     Mohamed Sanu          12.0       WR  away          left

# %%
defenses = pd.read_csv("../processed_data/processing_defenses/defense_players_plays_no_rz.csv",index_col=0)
defenses.head()
# Out:
#                 id      x      y     s     a   dis       o     dir      nflId  \
# 1  2018090600:75:1  88.89  36.47  0.01  0.01  0.01  105.63   66.66    79848.0
# 3  2018090600:75:1  86.31  22.01  0.09  0.42  0.01   70.12  168.91  2495613.0
# 5  2018090600:75:1  73.64  28.70  0.03  0.02  0.01  103.05  219.41  2534832.0
# 7  2018090600:75:1  86.48  31.12  0.09  0.03  0.04   95.90   33.36  2552315.0
# 8  2018090600:75:1  82.67  20.53  0.03  0.07  0.01   81.14  174.57  2552689.0
#
#        displayName  jerseyNumber position  team playDirection
# 1  Malcolm Jenkins          27.0       SS  home          left
# 3     Corey Graham          24.0       FS  home          left
# 5    Rodney McLeod          23.0       FS  home          left
# 7     Jordan Hicks          58.0      MLB  home          left
# 8     Ronald Darby          21.0       CB  home          left

# %%
offenses = pd.read_csv("../processed_data/processing_defenses/offense_players_plays_no_rz.csv",index_col=0)
offenses.head()
# Out:
#                  id      x      y     s     a   dis       o     dir  \
# 0   2018090600:75:1  91.73  26.67  0.00  0.01  0.02  289.57  240.93
# 2   2018090600:75:1  91.35  44.16  0.02  0.03  0.01  290.45   16.86
# 4   2018090600:75:1  90.78  36.15  0.00  0.00  0.00  257.61  193.97
# 6   2018090600:75:1  98.25  26.63  0.01  0.01  0.00  265.88  194.51
# 10  2018090600:75:1  91.29  21.83  0.01  0.02  0.01  250.34  151.83
#
#         nflId      displayName  jerseyNumber position  team playDirection
# 0       310.0        Matt Ryan           2.0       QB  away          left
# 2   2495454.0      Julio Jones          11.0       WR  away          left
# 4   2533040.0     Mohamed Sanu          12.0       WR  away          left
# 6   2543583.0  Devonta Freeman          24.0       RB  away          left
# 10  2555415.0    Austin Hooper          81.0       TE  away          left

# %%
plays = pd.read_csv("../processed_data/processing_defenses/plays.csv",index_col=0)
plays.head()
# Out:
#                  id                                    playDescription  \
# 0   2018090600:75:1  (15:00) M.Ryan pass short right to J.Jones pus...
# 1  2018090600:146:1  (13:10) M.Ryan pass incomplete short right to ...
# 2  2018090600:168:1  (13:05) (Shotgun) M.Ryan pass incomplete short...
# 3  2018090600:190:1  (13:01) (Shotgun) M.Ryan pass deep left to J.J...
# 4  2018090600:256:1  (10:59) (Shotgun) M.Ryan pass incomplete short...
#
#    quarter  down  yardsToGo possessionTeam        playType yardlineSide  \
# 0        1     1         15            ATL  play_type_pass          ATL
# 1        1     1         10            ATL  play_type_pass          PHI
# 2        1     2         10            ATL  play_type_pass          PHI
# 3        1     3         10            ATL  play_type_pass          PHI
# 4        1     3          1            ATL  play_type_pass          PHI
#
#    yardlineNumber offenseFormation        personnelO  defendersInTheBox  \
# 0              20           I_FORM  2 RB, 1 TE, 2 WR                7.0
# 1              39       SINGLEBACK  1 RB, 1 TE, 3 WR                7.0
# 2              39          SHOTGUN  2 RB, 1 TE, 2 WR                6.0
# 3              39          SHOTGUN  1 RB, 1 TE, 3 WR                6.0
# 4               1          SHOTGUN  2 RB, 3 TE, 0 WR                8.0
#
#    numberOfPassRushers        personnelD  preSnapVisitorScore  \
# 0                  4.0  4 DL, 2 LB, 5 DB                  0.0
# 1                  4.0  4 DL, 2 LB, 5 DB                  0.0
# 2                  4.0  4 DL, 2 LB, 5 DB                  0.0
# 3                  5.0  4 DL, 1 LB, 6 DB                  0.0
# 4                  6.0  6 DL, 3 LB, 2 DB                  0.0
#
#    preSnapHomeScore gameClock  absoluteYardlineNumber penaltyCodes  \
# 0               0.0  15:00:00                    90.0          NaN
# 1               0.0  13:10:00                    49.0          NaN
# 2               0.0  13:05:00                    49.0          NaN
# 3               0.0  13:01:00                    49.0          NaN
# 4               0.0  10:59:00                    11.0          NaN
#
#   penaltyJerseyNumbers passResult  offensePlayResult  playResult       epa  \
# 0                  NaN          C                 10          10  0.261827
# 1                  NaN          I                  0           0 -0.372360
# 2                  NaN          I                  0           0 -0.702779
# 3                  NaN          C                 33          33  3.047530
# 4                  NaN          I                  0           0 -0.842272
#
#    isDefensivePI  redZone
# 0          False    False
# 1          False    False
# 2          False    False
# 3          False    False
# 4          False     True

# %%
plays_no_rz = plays[plays["redZone"]==False]
plays_no_rz.head()
# Out:
#                  id                                    playDescription  \
# 0   2018090600:75:1  (15:00) M.Ryan pass short right to J.Jones pus...
# 1  2018090600:146:1  (13:10) M.Ryan pass incomplete short right to ...
# 2  2018090600:168:1  (13:05) (Shotgun) M.Ryan pass incomplete short...
# 3  2018090600:190:1  (13:01) (Shotgun) M.Ryan pass deep left to J.J...
# 5  2018090600:320:1  (10:10) (Shotgun) N.Foles pass short left to N...
#
#    quarter  down  yardsToGo possessionTeam        playType yardlineSide  \
# 0        1     1         15            ATL  play_type_pass          ATL
# 1        1     1         10            ATL  play_type_pass          PHI
# 2        1     2         10            ATL  play_type_pass          PHI
# 3        1     3         10            ATL  play_type_pass          PHI
# 5        1     2          8            PHI  play_type_pass          PHI
#
#    yardlineNumber offenseFormation        personnelO  defendersInTheBox  \
# 0              20           I_FORM  2 RB, 1 TE, 2 WR                7.0
# 1              39       SINGLEBACK  1 RB, 1 TE, 3 WR                7.0
# 2              39          SHOTGUN  2 RB, 1 TE, 2 WR                6.0
# 3              39          SHOTGUN  1 RB, 1 TE, 3 WR                6.0
# 5               4          SHOTGUN  1 RB, 1 TE, 3 WR                7.0
#
#    numberOfPassRushers        personnelD  preSnapVisitorScore  \
# 0                  4.0  4 DL, 2 LB, 5 DB                  0.0
# 1                  4.0  4 DL, 2 LB, 5 DB                  0.0
# 2                  4.0  4 DL, 2 LB, 5 DB                  0.0
# 3                  5.0  4 DL, 1 LB, 6 DB                  0.0
# 5                  4.0  3 DL, 3 LB, 5 DB                  0.0
#
#    preSnapHomeScore gameClock  absoluteYardlineNumber penaltyCodes  \
# 0               0.0  15:00:00                    90.0          NaN
# 1               0.0  13:10:00                    49.0          NaN
# 2               0.0  13:05:00                    49.0          NaN
# 3               0.0  13:01:00                    49.0          NaN
# 5               0.0  10:10:00                    14.0          NaN
#
#   penaltyJerseyNumbers passResult  offensePlayResult  playResult       epa  \
# 0                  NaN          C                 10          10  0.261827
# 1                  NaN          I                  0           0 -0.372360
# 2                  NaN          I                  0           0 -0.702779
# 3                  NaN          C                 33          33  3.047530
# 5                  NaN          C                  4           4 -0.344096
#
#    isDefensivePI  redZone
# 0          False    False
# 1          False    False
# 2          False    False
# 3          False    False
# 5          False    False

# %% [markdown]
# Vamos a empezar identificando cuantos jugadores hay en la zona profunda. Esta zona está 10 o 15 yardas más lejos de la línea de scrimmage.

# %%
transf_def = pd.DataFrame(columns = ["id"])

# %%
transf_def["id"] = plays_no_rz["id"]

# %%
def deepzonePlayers(id):
    los = plays_no_rz[plays_no_rz["id"]==id]["absoluteYardlineNumber"].values[0]
    defenders = defenses[defenses["id"]==id]
    playDirection = defenses[defenses["id"]==id]["playDirection"].values[0]
    deepzone = -1
    
    if playDirection == "right":
        deepzone = los + 15
    elif playDirection == "left":
        deepzone = los - 15
    
    number_players=0
    for index,row in defenders.iterrows():
        if row["position"] in ["DL","NT","DT","DE"]: #muy dificil que pase, pero por si acaso
            continue
        player_x = row["x"]
        if playDirection == "right" and player_x >= deepzone:
            number_players+=1
        elif playDirection == "left" and player_x <= deepzone:
            number_players+=1
    return number_players

# %%
def defensivelineZone(id): # desde la y del balón y 7 yardas para arriba y abajo
    los = plays_no_rz[plays_no_rz["id"]==id]["absoluteYardlineNumber"].values[0]
    defenders = defenses[defenses["id"]==id]
    playDirection = defenses[defenses["id"]==id]["playDirection"].values[0]
    yFootball = all_plays[(all_plays["id"]==id)&(all_plays["displayName"]=="Football")]["y"].values[0]
    x_defensiveline = -1
    
    if playDirection == "right":
        x_defensiveline = los + 1.5
    elif playDirection == "left":
        x_defensiveline = los - 1.5
    
    number_players=0
    for index,row in defenders.iterrows():
        if row["position"] in ["DL","NT","DT","DE"]:
            continue
        player_x = row["x"]
        player_y = row["y"]
        if playDirection == "right" and player_x <= x_defensiveline and (player_y >= yFootball -7 and player_y <= yFootball + 7):
            #if row["position"] in 
            number_players+=1
        elif playDirection == "left" and player_x >= x_defensiveline and (player_y >= yFootball -7 and player_y <= yFootball + 7):
            number_players+=1
    return number_players

# %%
def hookzonePlayers(id): # dentro de 23.6 y 29.7 (dar un poco de margen, 2 yardas por lado)
    los = plays_no_rz[plays_no_rz["id"]==id]["absoluteYardlineNumber"].values[0]
    defenders = defenses[defenses["id"]==id]
    playDirection = defenses[defenses["id"]==id]["playDirection"].values[0]
    yFootball = all_plays[(all_plays["id"]==id)&(all_plays["displayName"]=="Football")]["y"].values[0]
    x_hook = -1
    
    if playDirection == "right":
        x_hook = los + 15
    elif playDirection == "left":
        x_hook = los - 15
    
    number_players=0
    for index,row in defenders.iterrows():
        if row["position"] in ["DL","NT","DT","DE"]:
            continue
        player_x = row["x"]
        player_y = row["y"]
        if playDirection == "right" and player_x <= x_hook and (player_y >= 21.6 and player_y <= 31.7):
            if yFootball - 7 < 21.6 and yFootball + 7 > 31.7 and player_x > los + 1.5 :
                number_players+=1
            elif yFootball + 7 >= 31.7 and not(player_x > los and player_x < los + 1.5 and player_y <= 31.7 and player_y >= yFootball -7):
                number_players+=1
            elif yFootball - 7 <= 21.6 and not(player_x > los and player_x < los + 1.5 and player_y >= 21.6 and player_y <= yFootball +7):
                number_players+=1
        elif playDirection == "left" and player_x >= x_hook and (player_y >= 21.6 and player_y <= 31.7):
            if yFootball - 7 < 21.6 and yFootball + 7 > 31.7 and player_x < los - 1.5 :
                number_players+=1
            elif yFootball + 7 >= 31.7 and not(player_x > los - 1.5 and player_x < los and player_y <= 31.7 and player_y >= yFootball - 7):
                number_players+=1
            elif yFootball - 7 <= 21.6 and not(player_x > los - 1.5 and player_x < los and player_y >= 21.6 and player_y <= yFootball + 7):
                number_players+=1
    return number_players

# %% [markdown]
# Vamos a asignar a la zona curl como la zona que está entre las hash marks y los números y la flat la zona fuera de los números

# %%
def curlzonePlayers(id): # está entre la zona hook y los números (12 yd hasta 21.6 yd y 31.7 yd hasta 41.3 yd)
    los = plays_no_rz[plays_no_rz["id"]==id]["absoluteYardlineNumber"].values[0]
    defenders = defenses[defenses["id"]==id]
    playDirection = defenses[defenses["id"]==id]["playDirection"].values[0]
    yFootball = all_plays[(all_plays["id"]==id)&(all_plays["displayName"]=="Football")]["y"].values[0]
    x_curl = -1
    
    if playDirection == "right":
        x_curl = los + 15
    elif playDirection == "left":
        x_curl = los - 15
    
    number_players=0
    for index,row in defenders.iterrows():
        if row["position"] in ["DL","NT","DT","DE"]:
            continue
        player_x = row["x"]
        player_y = row["y"]
        if playDirection == "right" and player_x <= x_curl and ((player_y >= 12 and player_y < 21.6) or (player_y > 31.7 and player_y <= 41.3)):
            if yFootball - 7 < 21.6 and yFootball + 7 > 31.7 and not((player_x > los and player_x < los +1.5 and player_y > 31.7 and player_y <= yFootball + 7) or (player_x > los and player_x < los + 1.5 and player_y < 21.6 and player_y >= yFootball -7)):
                number_players+=1
            elif yFootball + 7 > 31.7 and not(player_x > los and player_x < los + 1.5 and player_y > 31.7 and player_y <= yFootball + 7):
                number_players+=1
            elif yFootball - 7 < 21.6 and not(player_x > los and player_x < los + 1.5 and player_y >= yFootball - 7 and player_y < 21.6):
                number_players+=1
        elif playDirection == "left" and player_x >= x_curl and ((player_y >= 12 and player_y < 21.6) or (player_y > 31.7 and player_y <= 41.3)):
            if yFootball + 7 > 31.7 and yFootball - 7 < 21.6 and not((player_x > los - 1.5 and player_x < los and player_y > 31.7 and player_y <= yFootball + 7) or (player_x > los -1.5 and player_x < los and player_y < 21.6 and player_y >= yFootball - 7)):
                number_players+=1
            elif yFootball + 7 > 31.7 and not(player_x > los -1.5 and player_x < los and player_y > 31.7 and player_y <= yFootball +7):
                number_players+=1
            elif yFootball - 7 < 21.6 and not(player_x > los -1.5 and player_x < los and player_y >= yFootball - 7 and player_y < 21.6):
                number_players+=1
    return number_players

# %%
def flatzonePlayers(id): # está fuera de los números (0 yd hasta 12 yd y 41.3 yd hasta 53.3 yd)
    los = plays_no_rz[plays_no_rz["id"]==id]["absoluteYardlineNumber"].values[0]
    defenders = defenses[defenses["id"]==id]
    playDirection = defenses[defenses["id"]==id]["playDirection"].values[0]
    x_flat = -1
    
    if playDirection == "right":
        x_flat = los + 15
    elif playDirection == "left":
        x_flat = los - 15
    
    number_players=0
    for index,row in defenders.iterrows():
        if row["position"] in ["DL","NT","DT","DE"]:
            continue
        player_x = row["x"]
        player_y = row["y"]
        if playDirection == "right" and player_x <= x_flat and ((player_y > 0 and player_y < 12) or (player_y > 41.3 and player_y < 53.3)):
            number_players+=1
        elif playDirection == "left" and player_x >= x_flat and ((player_y > 0 and player_y < 12) or (player_y > 41.3 and player_y < 53.3)):
            number_players+=1
    return number_players

# %%
transf_def["defensivelinezonePlayers"] = transf_def["id"].apply(defensivelineZone)

# %%
transf_def["deepzonePlayers"] = transf_def["id"].apply(deepzonePlayers)

# %%
transf_def["hookzonePlayers"] = transf_def["id"].apply(hookzonePlayers)

# %%
transf_def["curlzonePlayers"] = transf_def["id"].apply(curlzonePlayers)

# %%
transf_def["flatzonePlayers"] = transf_def["id"].apply(flatzonePlayers)

# %%
transf_def
# Out:
#                        id  defensivelinezonePlayers  deepzonePlayers  \
# 0         2018090600:75:1                         0                1
# 1        2018090600:146:1                         0                1
# 2        2018090600:168:1                         0                1
# 3        2018090600:190:1                         1                0
# 5        2018090600:320:1                         1                0
# ...                   ...                       ...              ...
# 19112  2018123015:3819:17                         0                0
# 19113  2018123015:3932:17                         0                0
# 19114  2018123015:3969:17                         0                1
# 19115  2018123015:4057:17                         0                0
# 19116  2018123015:4104:17                         0                0
#
#        hookzonePlayers  curlzonePlayers  flatzonePlayers
# 0                    3                2                1
# 1                    3                2                1
# 2                    2                2                2
# 3                    2                3                1
# 5                    3                3                1
# ...                ...              ...              ...
# 19112                3                4                0
# 19113                1                4                2
# 19114                1                4                1
# 19115                2                3                2
# 19116                3                2                2
#
# [16498 rows x 6 columns]

# %%
transf_def["defensivelinezonePlayers"].unique()
# Out:
# array([0, 1, 2, 3, 5, 4, 6])

# %%
transf_def[transf_def["hookzonePlayers"]==0]
# Out:
#                        id  defensivelinezonePlayers  deepzonePlayers  \
# 78      2018090600:4207:1                         1                1
# 81      2018090600:4282:1                         0                1
# 144     2018090900:2845:1                         5                1
# 241     2018090901:4495:1                         4                1
# 252     2018090901:5050:1                         2                1
# ...                   ...                       ...              ...
# 18837  2018123011:4044:17                         3                1
# 18850   2018123012:494:17                         3                0
# 18857   2018123012:794:17                         5                1
# 19052   2018123015:322:17                         2                1
# 19063   2018123015:848:17                         2                0
#
#        hookzonePlayers  curlzonePlayers  flatzonePlayers
# 78                   0                3                2
# 81                   0                6                0
# 144                  0                2                2
# 241                  0                2                2
# 252                  0                5                0
# ...                ...              ...              ...
# 18837                0                4                0
# 18850                0                6                1
# 18857                0                1                2
# 19052                0                3                1
# 19063                0                3                2
#
# [635 rows x 6 columns]

# %%
transf_def[transf_def["defensivelinezonePlayers"]==3]
# Out:
#                        id  defensivelinezonePlayers  deepzonePlayers  \
# 96       2018090900:466:1                         3                1
# 98       2018090900:553:1                         3                0
# 116     2018090900:1338:1                         3                0
# 157     2018090900:3748:1                         3                2
# 192     2018090901:1330:1                         3                0
# ...                   ...                       ...              ...
# 18857   2018123012:794:17                         3                1
# 18868  2018123012:1384:17                         3                0
# 18931  2018123013:1199:17                         3                0
# 18936  2018123013:1335:17                         3                1
# 19075  2018123015:1694:17                         3                1
#
#        hookzonePlayers  curlzonePlayers  flatzonePlayers
# 96                   2                3                1
# 98                   2                1                2
# 116                  2                4                0
# 157                  1                2                2
# 192                  1                4                1
# ...                ...              ...              ...
# 18857                0                1                2
# 18868                1                4                1
# 18931                2                4                0
# 18936                1                2                2
# 19075                1                1                1
#
# [646 rows x 6 columns]

# %%
transf_def["deepzonePlayers"].unique()
# Out:
# array([1, 0, 3, 4, 2, 7, 8, 6, 5, 9])

# %%
transf_def["hookzonePlayers"].unique()
# Out:
# array([3, 2, 1, 4, 0, 5, 6])

# %%
transf_def[transf_def["hookzonePlayers"]==6]
# Out:
#                        id  defensivelinezonePlayers  deepzonePlayers  \
# 623     2018090907:2556:1                         3                0
# 1763    2018091607:3075:2                         0                0
# 1929     2018091610:773:2                         1                0
# 2062    2018091611:3005:2                         0                0
# 2393     2018092300:453:3                         0                0
# 2727    2018092304:1197:3                         2                0
# 4021    2018093004:4398:4                         0                0
# 4306     2018093008:725:4                         0                0
# 4646    2018093012:1346:4                         0                0
# 4703    2018093012:3821:4                         1                0
# 5126    2018100703:1436:5                         1                0
# 5409     2018100706:917:5                         0                0
# 8818    2018102807:2512:8                         0                1
# 10026   2018110409:2993:9                         0                0
# 10777   2018111107:653:10                         0                0
# 11146   2018111200:268:10                         1                0
# 11271  2018111500:3087:11                         1                0
# 12127  2018111900:3411:11                         1                0
# 16470  2018121608:1290:15                         0                0
# 16825   2018122200:995:16                         0                0
# 18417   2018123006:788:17                         1                0
#
#        hookzonePlayers  curlzonePlayers  flatzonePlayers
# 623                  6                2                0
# 1763                 6                2                0
# 1929                 6                2                0
# 2062                 6                1                0
# 2393                 6                2                1
# 2727                 6                1                1
# 4021                 6                1                2
# 4306                 6                0                1
# 4646                 6                4                0
# 4703                 6                1                1
# 5126                 6                1                0
# 5409                 6                2                0
# 8818                 6                0                0
# 10026                6                1                0
# 10777                6                1                0
# 11146                6                3                1
# 11271                6                1                0
# 12127                6                1                0
# 16470                6                2                0
# 16825                6                2                0
# 18417                6                1                2

# %%
plays[plays["id"]=="2018090600:839:1"]
# Out:
#                   id                                    playDescription  \
# 14  2018090600:839:1  (1:21) (Shotgun) N.Foles FUMBLES (Aborted) at ...
#
#     quarter  down  yardsToGo possessionTeam        playType yardlineSide  \
# 14        1     3         12            PHI  play_type_sack          PHI
#
#     yardlineNumber offenseFormation        personnelO  defendersInTheBox  \
# 14              41          SHOTGUN  1 RB, 1 TE, 3 WR                6.0
#
#     numberOfPassRushers        personnelD  preSnapVisitorScore  \
# 14                  3.0  3 DL, 3 LB, 5 DB                  3.0
#
#     preSnapHomeScore gameClock  absoluteYardlineNumber penaltyCodes  \
# 14               0.0  01:21:00                    51.0          NaN
#
#    penaltyJerseyNumbers passResult  offensePlayResult  playResult       epa  \
# 14                  NaN          S                 -6          -6 -2.092108
#
#     isDefensivePI  redZone
# 14          False    False

# %%
defenses[defenses["id"]=="2018110410:3640:9"]
# Out:
#                        id      x      y     s     a   dis       o     dir  \
# 861901  2018110410:3640:9  35.87  22.70  0.41  1.21  0.04   87.93  160.16
# 861904  2018110410:3640:9  47.92  18.49  0.02  0.03  0.00   65.52   83.92
# 861906  2018110410:3640:9  42.31  42.54  0.98  0.89  0.10   81.00   58.55
# 861908  2018110410:3640:9  42.66  24.84  0.69  0.77  0.07   91.92  133.94
# 861909  2018110410:3640:9  45.59  24.50  1.81  0.88  0.18   88.98  127.39
# 861910  2018110410:3640:9  31.87  34.83  1.65  0.34  0.17   90.15  290.08
# 861911  2018110410:3640:9  47.11  37.21  1.41  0.57  0.14  107.80   19.31
# 861912  2018110410:3640:9  43.85  16.18  0.89  0.70  0.09   32.24    2.45
#
#             nflId       displayName  jerseyNumber position  team playDirection
# 861901  2506789.0   Tramon Williams          38.0       CB  away          left
# 861904  2533048.0        Nick Perry          53.0      OLB  away          left
# 861906  2543571.0  Bashaud Breeland          26.0       CB  away          left
# 861908  2555160.0  Antonio Morrison          44.0      ILB  away          left
# 861909  2556537.0    Reggie Gilbert          93.0       LB  away          left
# 861910  2558119.0        Josh Jones          27.0       SS  away          left
# 861911  2560755.0      Josh Jackson          37.0       CB  away          left
# 861912  2560952.0   Jaire Alexander          23.0       CB  away          left

# %%
transf_def.head()
# Out:
#                  id  defensivelinezonePlayers  deepzonePlayers  \
# 0   2018090600:75:1                         0                1
# 1  2018090600:146:1                         0                1
# 2  2018090600:168:1                         0                1
# 3  2018090600:190:1                         1                0
# 5  2018090600:320:1                         1                0
#
#    hookzonePlayers  curlzonePlayers  flatzonePlayers
# 0                3                2                1
# 1                3                2                1
# 2                2                2                2
# 3                2                3                1
# 5                3                3                1

# %%
def calculateArea(playId):
    defenders = defenses[defenses["id"]==playId]
    position_players = []
    
    for index,row in defenders.iterrows():
        position_players.append((row["x"],row["y"]))
    
    #print(position_players)
    hull = ConvexHull(position_players)
    ch_area = MultiPoint(position_players).convex_hull.area
    
    #print(ch_area,hull.volume)
    
    return hull.volume

# %%
transf_def["defenseArea"] = transf_def["id"].apply(calculateArea)

# %%
transf_def
# Out:
#                        id  defensivelinezonePlayers  deepzonePlayers  \
# 0         2018090600:75:1                         0                1
# 1        2018090600:146:1                         0                1
# 2        2018090600:168:1                         0                1
# 3        2018090600:190:1                         1                0
# 5        2018090600:320:1                         1                0
# ...                   ...                       ...              ...
# 19112  2018123015:3819:17                         1                0
# 19113  2018123015:3932:17                         0                0
# 19114  2018123015:3969:17                         0                1
# 19115  2018123015:4057:17                         0                0
# 19116  2018123015:4104:17                         0                0
#
#        hookzonePlayers  curlzonePlayers  flatzonePlayers  defenseArea
# 0                    3                2                1    194.31095
# 1                    3                2                1    204.17725
# 2                    2                2                2    277.65495
# 3                    2                3                1    189.16960
# 5                    3                3                1    187.12510
# ...                ...              ...              ...          ...
# 19112                3                4                0    169.30945
# 19113                1                4                2    327.34785
# 19114                1                4                1    293.39745
# 19115                2                3                2    223.81860
# 19116                3                2                2    215.50425
#
# [16498 rows x 7 columns]

# %%
def calculateWidth(id):
    defenders = defenses[defenses["id"]==id]
    
    players_y = []
    
    for index,row in defenders.iterrows():
        players_y.append(row["y"])
        
    return max(players_y) - min(players_y)

# %%
transf_def["width"] = transf_def["id"].apply(calculateWidth)

# %%
def calculateHeight(id):
    defenders = defenses[defenses["id"]==id]
    
    players_x = []
    
    for index,row in defenders.iterrows():
        players_x.append(row["x"])
        
    return abs(max(players_x) - min(players_x))

# %%
transf_def["height"] = transf_def["id"].apply(calculateHeight)

# %%
def calculatePlayDirection(id):
    return defenses[defenses["id"]==id]["playDirection"].values[0]

# %%
transf_def["playDirection"] = transf_def["id"].apply(calculatePlayDirection)

# %%
def calculateNumberTEs(playId):
    offensive_players = offenses[offenses["id"]==playId]
    
    tes = offensive_players[(offensive_players["id"]==playId)&(offensive_players["position"]=="TE")]
    
    return len(tes)

# %%
transf_def["numberTEs"] = transf_def["id"].apply(calculateNumberTEs)

# %%
def calculateNumberRBs(playId):
    offensive_players = offenses[offenses["id"]==playId]
    
    rbs = offensive_players[(offensive_players["id"]==playId)&(offensive_players["position"].isin(["HB","RB"]))]
    
    return len(rbs)

# %%
transf_def["numberRBs"] = transf_def["id"].apply(calculateNumberRBs)

# %%
def calculateNumberFBs(playId):
    offensive_players = offenses[offenses["id"]==playId]
    
    fbs = offensive_players[(offensive_players["id"]==playId)&(offensive_players["position"] == "FB")]
    
    return len(fbs)

# %%
transf_def["numberFBs"] = transf_def["id"].apply(calculateNumberFBs)

# %%
transf_def
# Out:
#                        id  defensivelinezonePlayers  deepzonePlayers  \
# 0         2018090600:75:1                         0                1
# 1        2018090600:146:1                         0                1
# 2        2018090600:168:1                         0                1
# 3        2018090600:190:1                         1                0
# 5        2018090600:320:1                         1                0
# ...                   ...                       ...              ...
# 19112  2018123015:3819:17                         1                0
# 19113  2018123015:3932:17                         0                0
# 19114  2018123015:3969:17                         0                1
# 19115  2018123015:4057:17                         0                0
# 19116  2018123015:4104:17                         0                0
#
#        hookzonePlayers  curlzonePlayers  flatzonePlayers  defenseArea  width  \
# 0                    3                2                1    194.31095  22.96
# 1                    3                2                1    204.17725  29.22
# 2                    2                2                2    277.65495  33.67
# 3                    2                3                1    189.16960  26.42
# 5                    3                3                1    187.12510  27.80
# ...                ...              ...              ...          ...    ...
# 19112                3                4                0    169.30945  23.43
# 19113                1                4                2    327.34785  35.76
# 19114                1                4                1    293.39745  26.24
# 19115                2                3                2    223.81860  36.23
# 19116                3                2                2    215.50425  32.25
#
#        height playDirection  numberTEs  numberRBs  numberFBs
# 0       15.25          left          1          1          1
# 1       12.57          left          1          1          0
# 2       15.21          left          1          2          0
# 3       12.91          left          1          1          0
# 5       13.29         right          1          1          0
# ...       ...           ...        ...        ...        ...
# 19112   12.71          left          2          1          0
# 19113   13.20          left          1          1          0
# 19114   14.67          left          1          1          0
# 19115   11.62         right          1          1          0
# 19116   13.00         right          1          1          0
#
# [16498 rows x 13 columns]

# %%
transf_def[transf_def["numberTEs"]==0]
# Out:
#                        id  defensivelinezonePlayers  deepzonePlayers  \
# 27      2018090600:1546:1                         1                1
# 98       2018090900:553:1                         3                0
# 321     2018090902:2955:1                         0                0
# 377     2018090903:1947:1                         2                1
# 514      2018090906:922:1                         0                0
# ...                   ...                       ...              ...
# 18937  2018123013:1399:17                         1                0
# 18941  2018123013:1723:17                         1                0
# 18942  2018123013:1795:17                         0                1
# 18953  2018123013:2329:17                         1                0
# 18961  2018123013:3000:17                         1                1
#
#        hookzonePlayers  curlzonePlayers  flatzonePlayers  defenseArea  width  \
# 27                   2                1                2    244.93380  33.71
# 98                   2                1                2    226.88915  35.30
# 321                  2                4                1    151.24780  30.24
# 377                  2                2                2    228.79630  31.37
# 514                  2                4                1    137.86460  20.72
# ...                ...              ...              ...          ...    ...
# 18937                3                2                1     60.83355  29.55
# 18941                3                3                0    141.40345  17.57
# 18942                3                3                0    139.40900  21.15
# 18953                4                2                0     59.21600  20.08
# 18961                3                1                1    182.46450  28.89
#
#        height playDirection  numberTEs  numberRBs  numberFBs
# 27      14.16         right          0          2          0
# 98      12.70         right          0          1          0
# 321      9.91          left          0          1          0
# 377     14.89          left          0          2          0
# 514     10.75          left          0          1          1
# ...       ...           ...        ...        ...        ...
# 18937    6.09          left          0          2          0
# 18941   13.37          left          0          2          0
# 18942   13.00          left          0          1          0
# 18953    6.78         right          0          1          0
# 18961   14.72         right          0          2          0
#
# [470 rows x 13 columns]

# %%
pickle_file = open('../resources/processing_defenses/transf_def.pickle','wb')
pickle.dump(transf_def,pickle_file)
pickle_file.close()

# %%
pickle_file_td = open('../resources/processing_defenses/transf_def.pickle','rb')
transf_def = pickle.load(pickle_file_td)
pickle_file_td.close()

# %% [markdown]
# Esto es auxiliar para mi

# %%
def calculateNumberQBs(playId):
    offensive_players = offenses[offenses["id"]==playId]
    
    qbs = offensive_players[(offensive_players["id"]==playId)&(offensive_players["position"] == "QB")]
    
    return len(qbs)

# %%
transf_def["numberQBs"] = transf_def["id"].apply(calculateNumberQBs)

# %%
transf_def
# Out:
#                        id  defensivelinezonePlayers  deepzonePlayers  \
# 0         2018090600:75:1                         0                1
# 1        2018090600:146:1                         0                1
# 2        2018090600:168:1                         0                1
# 3        2018090600:190:1                         1                0
# 5        2018090600:320:1                         1                0
# ...                   ...                       ...              ...
# 19112  2018123015:3819:17                         1                0
# 19113  2018123015:3932:17                         0                0
# 19114  2018123015:3969:17                         0                1
# 19115  2018123015:4057:17                         0                0
# 19116  2018123015:4104:17                         0                0
#
#        hookzonePlayers  curlzonePlayers  flatzonePlayers  defenseArea  width  \
# 0                    3                2                1    194.31095  22.96
# 1                    3                2                1    204.17725  29.22
# 2                    2                2                2    277.65495  33.67
# 3                    2                3                1    189.16960  26.42
# 5                    3                3                1    187.12510  27.80
# ...                ...              ...              ...          ...    ...
# 19112                3                4                0    169.30945  23.43
# 19113                1                4                2    327.34785  35.76
# 19114                1                4                1    293.39745  26.24
# 19115                2                3                2    223.81860  36.23
# 19116                3                2                2    215.50425  32.25
#
#        height playDirection  numberTEs  numberRBs  numberFBs  numberQBs
# 0       15.25          left          1          1          1          1
# 1       12.57          left          1          1          0          1
# 2       15.21          left          1          2          0          1
# 3       12.91          left          1          1          0          1
# 5       13.29         right          1          1          0          1
# ...       ...           ...        ...        ...        ...        ...
# 19112   12.71          left          2          1          0          1
# 19113   13.20          left          1          1          0          1
# 19114   14.67          left          1          1          0          1
# 19115   11.62         right          1          1          0          1
# 19116   13.00         right          1          1          0          1
#
# [16498 rows x 14 columns]

# %%
transf_def[(transf_def["numberTEs"]==4)]
# Out:
#                        id  defensivelinezonePlayers  deepzonePlayers  \
# 14658  2018120901:3291:14                         0                1
#
#        hookzonePlayers  curlzonePlayers  flatzonePlayers  defenseArea  width  \
# 14658                2                2                2      303.888   35.8
#
#        height playDirection  numberTEs  numberRBs  numberFBs  numberQBs
# 14658   16.96          left          4          1          0          1

# %% [markdown]
# Ahora calculamos cual el es el lado fuerte

# %%
def calculateStrongSide(playId,numberTEs,numberFBs,numberRBs,playDirection):
    yFootball = all_plays[(all_plays["id"]==playId)&(all_plays["displayName"]=="Football")]["y"].values[0]
    
    strongSide = ""
    
    if numberTEs == 0:
        
    elif numberTEs == 1:
        te = offensive_players[(offensive_players["id"]==playId)&(offensive_players["position"]=="TE")]["y"].values[0]
        if (playDirection == "left" and te > yFootball) or (playDirection == "right" and te < yFootball):
            strongSide = "right"
        elif (playDirection == "right" and te > yFootball) or (playDirection == "left" and te < yFootball):
            strongSide = "left"
    elif numberTEs == 2:
        te1 = offensive_players[(offensive_players["id"]==playId)&(offensive_players["position"]=="TE")]["y"].values[0]
        te2 = offensive_players[(offensive_players["id"]==playId)&(offensive_players["position"]=="TE")]["y"].values[1]
        
        if (te1 > yFootball and te2 > yFootball) or (te1 < yFootball and te2 < yFootball):
            sameSide = True
        elif (te1 > yFootball and te2 < yFootball) or (te1 < yFootball and te2 > yFootball):
            sameSide = False
        
        if (sameSide and playDirection == "left") or (sameSide and playDirection == "right"):
            strongSide = "right"
        elif (sameSide and playDirection == "right") or (sameSide and playDirection == "left"):
            strongSide = "left"
        elif not(sameSide) and numberFBs == 1:
            fb = offensive_players[(offensive_players["id"]==playId)&(offensive_players["position"]=="FB")]["y"].values[0]
            if (playDirection == "left" and fb < yFootball) or (playDirection == "right" and fb >yFootball):
                strongSide = "left"
            elif (playDirection == "left" and fb > yFootball) or (playDirection == "right" and fb < yFootball):
                strongSide = "right"
                
        elif not(sameSide) and numberFBs == 0 and numberRBs == 1:
            rb = offensive_players[(offensive_players["id"]==playId)&(offensive_players["position"].isin(["RB","HB"]))]["y"].values[0]
            if (playDirection == "left" and rb < yFootball) or (playDirection == "right" and rb >yFootball):
                strongSide = "left"
            elif (playDirection == "left" and rb > yFootball) or (playDirection == "right" and rb < yFootball):
                strongSide = "right"
        elif not(sameSide) and numberFBs == 0 and numberRBs > 1:
            players = offensive_players[offensive_players["id"]==playId]["y"].values[0]
            number_players_fto53 = 0 #number of players from football to the line 53.3
            number_players_0tof = 0 #number of players from line 0 to football
            for index,row in players.iterrows():
                if row["position"] != "QB" and row["y"] < yFootball:
                    number_players_0tof += 1
                elif row["position"] != "QB" and row["y"] > yFootball:
                    number_players_fto53 += 1
            
            if (playDirection == "left" and number_players_fto53 > number_players_0tof) or (playDirection == "right" and number_players_fto53 < number_players_0tof) or number_players_fto53 == number_players_0tof:
                strongSide = "right"
            elif (playDirection == "left" and number_players_fto53 < number_players_0tof) or (playDirection == "right" and number_players_fto53 > number_players_0tof):
                strongSide = "left"
        elif not(sameSide) and numberFBs == 0 and numberFBs == 0:
            players = offensive_players[offensive_players["id"]==playId]["y"].values[0]
            number_players_fto53 = 0 #number of players from football to the line 53.3
            number_players_0tof = 0 #number of players from line 0 to football
            for index,row in players.iterrows():
                if row["position"] != "QB" and row["y"] < yFootball:
                    number_players_0tof += 1
                elif row["position"] != "QB" and row["y"] > yFootball:
                    number_players_fto53 += 1
            
            if (playDirection == "left" and number_players_fto53 > number_players_0tof) or (playDirection == "right" and number_players_fto53 < number_players_0tof) or number_players_fto53 == number_players_0tof:
                strongSide = "right"
            elif (playDirection == "left" and number_players_fto53 < number_players_0tof) or (playDirection == "right" and number_players_fto53 > number_players_0tof):
                strongSide = "left"
    elif numberTEs == 3:
        
    elif numberTEs == 4:
        strongSide = "right"
    
    
    #### lo de aquí abajo no va a servir ###
    number_players_fto53 = 0 #number of players from football to the line 53.3
    number_players_0tof = 0 #number of players from line 0 to football
    
    for index,row in offensive_players.iterrows():
        if row["y"] >= 0 and row["y"] < yFootball:
            number_players_0tof += 1
        elif row["y"] >= yFootball and row["y"] <= 53.3:
            number_players_fto53 += 1
    
    value = ""
    
    
        
    return value

# %%
transf_def["strongSide"] = transf_def["id"].apply(calculateStrongSide)

# %%
transf_def
# Out:
#                        id  defensivelinezonePlayers  deepzonePlayers  \
# 0         2018090600:75:1                         0                1
# 1        2018090600:146:1                         0                1
# 2        2018090600:168:1                         0                1
# 3        2018090600:190:1                         1                0
# 5        2018090600:320:1                         1                0
# ...                   ...                       ...              ...
# 19112  2018123015:3819:17                         1                0
# 19113  2018123015:3932:17                         0                0
# 19114  2018123015:3969:17                         0                1
# 19115  2018123015:4057:17                         0                0
# 19116  2018123015:4104:17                         0                0
#
#        hookzonePlayers  curlzonePlayers  flatzonePlayers  defenseArea  \
# 0                    3                2                1    180.30145
# 1                    3                2                1    197.01345
# 2                    2                2                2    242.28605
# 3                    2                3                1    169.40415
# 5                    3                3                1    143.43090
# ...                ...              ...              ...          ...
# 19112                3                4                0     96.53060
# 19113                1                4                2    184.26885
# 19114                1                4                1    196.48345
# 19115                2                3                2    183.47345
# 19116                3                2                2    173.01540
#
#                                                   points  width  height  \
# 0      [(88.89, 36.47), (86.48, 31.12), (85.63, 26.59...  22.96   15.25
# 1      [(46.03, 35.49), (44.79, 30.69), (45.08, 27.2)...  29.22   12.57
# 2      [(46.79, 44.19), (44.36, 30.92), (44.6, 28.9),...  33.67   15.21
# 3      [(48.3, 27.21), (46.9, 22.13), (47.52, 18.83),...  26.42   12.91
# 5      [(16.16, 38.61), (17.75, 34.45), (18.24, 30.89...  27.80   13.29
# ...                                                  ...    ...     ...
# 19112  [(62.9, 35.83), (62.13, 24.53), (65.73, 20.38)...  23.43   12.71
# 19113  [(41.57, 44.59), (39.9, 19.51), (42.72, 8.83),...  35.76   13.20
# 19114  [(45.87, 43.98), (45.94, 33.42), (43.14, 22.22...  26.24   14.67
# 19115  [(41.39, 45.32), (42.51, 33.78), (41.61, 24.32...  36.23   11.62
# 19116  [(48.89, 42.76), (50.94, 32.56), (51.06, 25.89...  32.25   13.00
#
#       strongSide
# 0           left
# 1           left
# 2           left
# 3           left
# 5           none
# ...          ...
# 19112       none
# 19113       none
# 19114       none
# 19115       left
# 19116       none
#
# [16498 rows x 11 columns]

# %%
def calculateNumberPlayersSS(idPlay,strongSide,playDirection):
    yFootball = all_plays[(all_plays["id"]==idPlay)&(all_plays["displayName"]=="Football")]["y"].values[0]
    defenders = defenses[defenses["id"]==idPlay]
    
    number_players = 0
    for index,row in defenders.iterrows():
        if row["position"] in ["DL","NT","DT","DE"]:
            continue
        
        if (playDirection == "left" and strongSide == "left" and row["y"] >= 0 and row["y"] <= yFootball) or (playDirection == "left" and strongSide == "right" and row["y"] > yFootball and row["y"] <= 53.3) or (playDirection == "right" and strongSide == "left" and row["y"] >= 53.3 and row["y"]<= yFootball) or (playDirection == "right" and strongSide == "left" and row["y"]>=0 and row["y"]<yFootball):
            number_players += 1
    
    return number_players

# %%
transf_def["numberPlayersStrongSide"] = transf_def.apply(lambda x: calculateNumberPlayersSS(x["id"],x["strongSide"],x["playDirection"]),axis=1)

# %%
transf_def
# Out:
#                        id  defensivelinezonePlayers  deepzonePlayers  \
# 0         2018090600:75:1                         0                1
# 1        2018090600:146:1                         0                1
# 2        2018090600:168:1                         0                1
# 3        2018090600:190:1                         1                0
# 5        2018090600:320:1                         1                0
# ...                   ...                       ...              ...
# 19112  2018123015:3819:17                         1                0
# 19113  2018123015:3932:17                         0                0
# 19114  2018123015:3969:17                         0                1
# 19115  2018123015:4057:17                         0                0
# 19116  2018123015:4104:17                         0                0
#
#        hookzonePlayers  curlzonePlayers  flatzonePlayers  defenseArea  \
# 0                    3                2                1    180.30145
# 1                    3                2                1    197.01345
# 2                    2                2                2    242.28605
# 3                    2                3                1    169.40415
# 5                    3                3                1    143.43090
# ...                ...              ...              ...          ...
# 19112                3                4                0     96.53060
# 19113                1                4                2    184.26885
# 19114                1                4                1    196.48345
# 19115                2                3                2    183.47345
# 19116                3                2                2    173.01540
#
#                                                   points  width  height  \
# 0      [(88.89, 36.47), (86.48, 31.12), (85.63, 26.59...  22.96   15.25
# 1      [(46.03, 35.49), (44.79, 30.69), (45.08, 27.2)...  29.22   12.57
# 2      [(46.79, 44.19), (44.36, 30.92), (44.6, 28.9),...  33.67   15.21
# 3      [(48.3, 27.21), (46.9, 22.13), (47.52, 18.83),...  26.42   12.91
# 5      [(16.16, 38.61), (17.75, 34.45), (18.24, 30.89...  27.80   13.29
# ...                                                  ...    ...     ...
# 19112  [(62.9, 35.83), (62.13, 24.53), (65.73, 20.38)...  23.43   12.71
# 19113  [(41.57, 44.59), (39.9, 19.51), (42.72, 8.83),...  35.76   13.20
# 19114  [(45.87, 43.98), (45.94, 33.42), (43.14, 22.22...  26.24   14.67
# 19115  [(41.39, 45.32), (42.51, 33.78), (41.61, 24.32...  36.23   11.62
# 19116  [(48.89, 42.76), (50.94, 32.56), (51.06, 25.89...  32.25   13.00
#
#       strongSide playDirection  numberPlayersStrongSide
# 0           left          left                        3
# 1           left          left                        4
# 2           left          left                        5
# 3           left          left                        5
# 5           none         right                        0
# ...          ...           ...                      ...
# 19112       none          left                        0
# 19113       none          left                        0
# 19114       none          left                        0
# 19115       left         right                        3
# 19116       none         right                        0
#
# [16498 rows x 13 columns]

# %%
def calculateNumberPlayersWS(id):
    yFootball = all_plays[(all_plays["id"]==idPlay)&(all_plays["displayName"]=="Football")]["y"].values[0]
    defenders = defenses[defenses["id"]==idPlay]
    
    number_players = 0
    for index,row in defenders.iterrows():
        if row["position"] in ["DL","NT","DT","DE"]:
            continue
        
        if (playDirection == "left" and strongSide == "left" and row["y"] > yFootball and row["y"] <= 53.3) or (playDirection == "left" and strongSide == "right" and row["y"] >= 0 and row["y"] <= yFootball) or (playDirection == "right" and strongSide == "left" and row["y"] >= 0 and row["y"]< yFootball) or (playDirection == "right" and strongSide == "left" and row["y"]>=yFootball and row["y"]<=53.3):
            number_players += 1
    
    return number_players

# %% [markdown]
# Incluir numero de cbs, lbs, s y de jugadores ofensivos

# %%
transf_def
# Out:
#                        id  defensivelinezonePlayers  deepzonePlayers  \
# 0         2018090600:75:1                         0                1
# 1        2018090600:146:1                         0                1
# 2        2018090600:168:1                         0                1
# 3        2018090600:190:1                         1                0
# 5        2018090600:320:1                         1                0
# ...                   ...                       ...              ...
# 19112  2018123015:3819:17                         1                0
# 19113  2018123015:3932:17                         0                0
# 19114  2018123015:3969:17                         0                1
# 19115  2018123015:4057:17                         0                0
# 19116  2018123015:4104:17                         0                0
#
#        hookzonePlayers  curlzonePlayers  flatzonePlayers  defenseArea  \
# 0                    3                2                1    180.30145
# 1                    3                2                1    197.01345
# 2                    2                2                2    242.28605
# 3                    2                3                1    169.40415
# 5                    3                3                1    143.43090
# ...                ...              ...              ...          ...
# 19112                3                4                0     96.53060
# 19113                1                4                2    184.26885
# 19114                1                4                1    196.48345
# 19115                2                3                2    183.47345
# 19116                3                2                2    173.01540
#
#        defenseArea2  numberTEs  numberRBs  numberFBs
# 0         194.31095          1          1          1
# 1         204.17725          1          1          0
# 2         277.65495          1          2          0
# 3         189.16960          1          1          0
# 5         187.12510          1          1          0
# ...             ...        ...        ...        ...
# 19112     169.30945          2          1          0
# 19113     327.34785          1          1          0
# 19114     293.39745          1          1          0
# 19115     223.81860          1          1          0
# 19116     215.50425          1          1          0
#
# [16498 rows x 11 columns]

# %%
transf_def[transf_def["numberTEs"]==4]
# Out:
#                        id  defensivelinezonePlayers  deepzonePlayers  \
# 14658  2018120901:3291:14                         0                1
#
#        hookzonePlayers  curlzonePlayers  flatzonePlayers  defenseArea  \
# 14658                2                2                2    220.11185
#
#        defenseArea2  numberTEs
# 14658       303.888          4

# %%
Echar un vistazo a la densidad....
