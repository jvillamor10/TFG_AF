# %%
import pandas as pd

# %%
plays = pd.read_csv("processed_data/remove_st_nbt/plays.csv")
plays.head()
# Out:
#    Unnamed: 0  index                id  \
# 0           0      0   2018090600:75:1
# 1           1      1  2018090600:146:1
# 2           2      2  2018090600:168:1
# 3           3      3  2018090600:190:1
# 4           4      4  2018090600:256:1
#
#                                      playDescription  quarter  down  \
# 0  (15:00) M.Ryan pass short right to J.Jones pus...        1     1
# 1  (13:10) M.Ryan pass incomplete short right to ...        1     1
# 2  (13:05) (Shotgun) M.Ryan pass incomplete short...        1     2
# 3  (13:01) (Shotgun) M.Ryan pass deep left to J.J...        1     3
# 4  (10:59) (Shotgun) M.Ryan pass incomplete short...        1     3
#
#    yardsToGo possessionTeam        playType yardlineSide  ...  \
# 0         15            ATL  play_type_pass          ATL  ...
# 1         10            ATL  play_type_pass          PHI  ...
# 2         10            ATL  play_type_pass          PHI  ...
# 3         10            ATL  play_type_pass          PHI  ...
# ...

# %%
plays.isnull().sum()
# Out:
# Unnamed: 0                    0
# index                         0
# id                            0
# playDescription               0
# quarter                       0
# down                          0
# yardsToGo                     0
# possessionTeam                0
# playType                      0
# yardlineSide                253
# yardlineNumber                0
# offenseFormation            125
# personnelO                   29
# defendersInTheBox            46
# numberOfPassRushers         633
# personnelD                   29
# typeDropback                639
# preSnapVisitorScore         639
# preSnapHomeScore            639
# gameClock                   639
# absoluteYardlineNumber      639
# penaltyCodes              17986
# penaltyJerseyNumbers      17986
# passResult                    2
# offensePlayResult             0
# playResult                    0
# epa                           0
# isDefensivePI                 0
# dtype: int64

# %% [markdown]
# Let's start with yardlineSide

# %%
plays[plays["yardlineSide"].isnull()]
# Out:
#        Unnamed: 0  index                  id  \
# 26             26     26   2018090600:1473:1
# 179           179    179    2018090901:613:1
# 180           180    180    2018090901:635:1
# 404           404    404   2018090903:3485:1
# 405           405    405   2018090903:3507:1
# ...           ...    ...                 ...
# 18737       18737  18782  2018123009:2303:17
# 18738       18738  18783  2018123009:2329:17
# 18777       18777  18823   2018123010:516:17
# 18955       18955  19001  2018123012:2350:17
# 19017       19017  19064  2018123013:1861:17
#
#                                          playDescription  quarter  down  \
# 26     (4:20) M.Ryan pass short left to M.Sanu to PHI...        2     2
# 179    (6:24) (Shotgun) B.Roethlisberger pass incompl...        1     1
# 180    (6:19) (No Huddle, Shotgun) B.Roethlisberger p...        1     2
# 404    (8:12) B.Gabbert pass incomplete short right t...        4     2
# ...

# %% [markdown]
# What it seems is that this column is null because the football is just in the middle of the field. Let's check it.

# %%
for index,row in plays[plays["yardlineSide"].isnull()].iterrows():
    print(row)
# Out:
# Unnamed: 0                                                               26
# index                                                                    26
# id                                                        2018090600:1473:1
# playDescription           (4:20) M.Ryan pass short left to M.Sanu to PHI...
# quarter                                                                   2
# down                                                                      2
# yardsToGo                                                                 9
# possessionTeam                                                          ATL
# playType                                                     play_type_pass
# yardlineSide                                                            NaN
# yardlineNumber                                                           50
# offenseFormation                                                 SINGLEBACK
# ...

# %%
#te has quedao aqui

# %% [markdown]
# Now we are going to start with absoluteYardlineNumber

# %%
plays[plays["absoluteYardlineNumber"].isnull()]
# Out:
#        Unnamed: 0  index                  id  \
# 22             22     22   2018090600:1226:1
# 31             31     31   2018090600:1715:1
# 43             43     43   2018090600:2305:1
# 67             67     67   2018090600:3626:1
# 87             87     87   2018090600:4439:1
# ...           ...    ...                 ...
# 19055       19055  19102  2018123013:4238:17
# 19072       19072  19119  2018123014:1212:17
# 19087       19087  19134  2018123014:2022:17
# 19090       19090  19137  2018123014:2170:17
# 19172       19172  19219  2018123015:2742:17
#
#                                          playDescription  quarter  down  \
# 22     (8:23) (Shotgun) N.Foles pass incomplete short...        2     3
# 31     (1:50) (Shotgun) N.Foles pass short right to N...        2     1
# 43     (13:44) (Shotgun) N.Foles pass incomplete shor...        3     1
# 67     (8:31) (Shotgun) N.Foles pass short right to N...        4     3
# ...
