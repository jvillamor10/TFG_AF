# %%
import pandas as pd
import pickle

#Para el área
from shapely.geometry import Polygon
from shapely.geometry import MultiPoint 
from scipy.spatial import ConvexHull
from shapely.geometry import LineString
from shapely.geometry.point import Point

# %%
pd.set_option('display.max_columns',None)

# %%
week1 = pd.read_csv("../processed_data/clean_without_pass_rushers/week1.csv")
week2 = pd.read_csv("../processed_data/clean_without_pass_rushers/week2.csv")
week3 = pd.read_csv("../processed_data/clean_without_pass_rushers/week3.csv")
week4 = pd.read_csv("../processed_data/clean_without_pass_rushers/week4.csv")
week5 = pd.read_csv("../processed_data/clean_without_pass_rushers/week5.csv")
week6 = pd.read_csv("../processed_data/clean_without_pass_rushers/week6.csv")
week7 = pd.read_csv("../processed_data/clean_without_pass_rushers/week7.csv")
week8 = pd.read_csv("../processed_data/clean_without_pass_rushers/week8.csv")
week9 = pd.read_csv("../processed_data/clean_without_pass_rushers/week9.csv")
week10 = pd.read_csv("../processed_data/clean_without_pass_rushers/week10.csv")
week11 = pd.read_csv("../processed_data/clean_without_pass_rushers/week11.csv")
week12 = pd.read_csv("../processed_data/clean_without_pass_rushers/week12.csv")
week13 = pd.read_csv("../processed_data/clean_without_pass_rushers/week13.csv")
week14 = pd.read_csv("../processed_data/clean_without_pass_rushers/week14.csv")
week15 = pd.read_csv("../processed_data/clean_without_pass_rushers/week15.csv")
week16 = pd.read_csv("../processed_data/clean_without_pass_rushers/week16.csv")
week17 = pd.read_csv("../processed_data/clean_without_pass_rushers/week17.csv")
week1.head()
# Out:
#    Unnamed: 0               id                      time      x      y     s  \
# 0           0  2018090600:75:1  2018-09-07T01:07:14.599Z  91.73  26.67  0.00
# 1           1  2018090600:75:1  2018-09-07T01:07:14.599Z  88.89  36.47  0.01
# 2           2  2018090600:75:1  2018-09-07T01:07:14.599Z  91.35  44.16  0.02
# 3           3  2018090600:75:1  2018-09-07T01:07:14.599Z  86.31  22.01  0.09
# 4           4  2018090600:75:1  2018-09-07T01:07:14.599Z  90.78  36.15  0.00
#
#       a   dis       o     dir event      nflId      displayName  jerseyNumber  \
# 0  0.01  0.02  289.57  240.93  None      310.0        Matt Ryan           2.0
# 1  0.01  0.01  105.63   66.66  None    79848.0  Malcolm Jenkins          27.0
# 2  0.03  0.01  290.45   16.86  None  2495454.0      Julio Jones          11.0
# 3  0.42  0.01   70.12  168.91  None  2495613.0     Corey Graham          24.0
# 4  0.00  0.00  257.61  193.97  None  2533040.0     Mohamed Sanu          12.0
#
#   position  frameId  team playDirection  route
# 0       QB        1  away          left    NaN
# 1       SS        1  home          left    NaN
# 2       WR        1  away          left  HITCH
# 3       FS        1  home          left    NaN
# 4       WR        1  away          left  HITCH

# %%
weeks = [week1,week2,week3,week4,week5,week6,week7,week8,week9,week10,week11,week12,week13,week14,week15,week16,week17]

# %%
for week in weeks:
    week.drop(["Unnamed: 0"],axis=1,inplace=True)

# %%
static_defense = pd.read_csv("../transformed_data/static_defenses_yards.csv",index_col=1)
static_defense.head()
# Out:
#                   Unnamed: 0  defensivelinezonePlayers  deepzonePlayers  \
# id
# 2018090600:75:1            0                         0                1
# 2018090600:146:1           1                         0                1
# 2018090600:168:1           2                         0                1
# 2018090600:190:1           3                         1                0
# 2018090600:320:1           5                         1                0
#
#                   hookzonePlayers  curlzonePlayers  flatzonePlayers  \
# id
# 2018090600:75:1                 3                2                1
# 2018090600:146:1                3                2                1
# 2018090600:168:1                2                2                2
# 2018090600:190:1                2                3                1
# 2018090600:320:1                3                3                1
#
#                   defenseArea  defenseAreaCoverDefenders  width  height  \
# id
# 2018090600:75:1     194.31095                  194.31095  22.96   15.25
# 2018090600:146:1    204.17725                  204.17725  29.22   12.57
# 2018090600:168:1    277.65495                  277.65495  33.67   15.21
# 2018090600:190:1    189.16960                  165.05520  26.42   12.91
# 2018090600:320:1    187.12510                  153.20020  27.80   13.29
#
#                   numberQBs  numberWRs  numberTEs  numberRBs  numberFBs  \
# id
# 2018090600:75:1           1          2          1          1          1
# 2018090600:146:1          1          3          1          1          0
# 2018090600:168:1          1          2          1          2          0
# 2018090600:190:1          1          3          1          1          0
# 2018090600:320:1          1          3          1          1          0
#
#                   numberOffensivePlayersAnotherPosition  numberSafeties  \
# id
# 2018090600:75:1                                       0               3
# 2018090600:146:1                                      0               2
# 2018090600:168:1                                      0               2
# 2018090600:190:1                                      0               3
# 2018090600:320:1                                      0               2
#
#                   numberLBs  numberCBs strongSide  \
# id
# 2018090600:75:1           2          2       left
# 2018090600:146:1          2          3      right
# 2018090600:168:1          2          3       left
# 2018090600:190:1          1          3      right
# 2018090600:320:1          3          3       left
#
#                   numberPlayersDefenseStrongSide  \
# id
# 2018090600:75:1                                3
# 2018090600:146:1                               3
# 2018090600:168:1                               5
# 2018090600:190:1                               2
# 2018090600:320:1                               3
#
#                   numberPlayersDefenseWeakSide  \
# id
# 2018090600:75:1                              4
# 2018090600:146:1                             4
# 2018090600:168:1                             2
# 2018090600:190:1                             5
# 2018090600:320:1                             5
#
#                   numberPlayersOffenseStrongSide  \
# id
# 2018090600:75:1                                3
# 2018090600:146:1                               2
# 2018090600:168:1                               4
# 2018090600:190:1                               2
# 2018090600:320:1                               3
#
#                   numberPlayersOffenseWeakSide  \
# id
# 2018090600:75:1                              2
# 2018090600:146:1                             3
# 2018090600:168:1                             1
# 2018090600:190:1                             3
# 2018090600:320:1                             2
#
#                   differenceOffenseVsDefenseWidth  \
# id
# 2018090600:75:1                             -0.63
# 2018090600:146:1                            -1.15
# 2018090600:168:1                             0.71
# 2018090600:190:1                            -3.11
# 2018090600:320:1                            -4.82
#
#                   differenceOffenseVsDefenseStrongSide  \
# id
# 2018090600:75:1                                      0
# 2018090600:146:1                                    -1
# 2018090600:168:1                                    -1
# 2018090600:190:1                                     0
# 2018090600:320:1                                     0
#
#                   differenceOffenseVsDefenseWeakSide  HeightByWeightDeep  \
# id
# 2018090600:75:1                                   -2            0.020227
# 2018090600:146:1                                  -1            0.020227
# 2018090600:168:1                                  -1            0.020227
# 2018090600:190:1                                  -2            0.000000
# 2018090600:320:1                                  -3            0.000000
#
#                   HeightByWeightHook  HeightByWeightCurl  HeightByWeightFlat  \
# id
# 2018090600:75:1             0.018643            0.020066            0.021034
# 2018090600:146:1            0.019228            0.020356            0.020455
# 2018090600:168:1            0.017683            0.020997            0.020745
# 2018090600:190:1            0.020120            0.021193            0.020455
# 2018090600:320:1            0.018995            0.019537            0.021279
#
#                   WeightByArea   density  densityNoLine  densityInsidePoints  \
# id
# 2018090600:75:1       3.376032  0.036025       0.036025             6.974268
# 2018090600:146:1      3.178611  0.034284       0.034284             6.975511
# 2018090600:168:1      2.337434  0.025211       0.025211             6.985594
# 2018090600:190:1      3.192871  0.037004       0.036351             6.973569
# 2018090600:320:1      4.281979  0.042752       0.045692             7.978624
#
#                   densityInsidePointsNoLine  playResult
# id
# 2018090600:75:1                    6.974268          10
# 2018090600:146:1                   6.975511           0
# 2018090600:168:1                   6.985594           0
# 2018090600:190:1                   6.969707          33
# 2018090600:320:1                   7.980418           4

# %%
static_defense.drop(["Unnamed: 0"],axis=1,inplace=True)

# %%
plays = pd.read_csv("../processed_data/clean/plays.csv",index_col=1)
plays.head()
# Out:
#                   Unnamed: 0  \
# id
# 2018090600:75:1            0
# 2018090600:146:1           1
# 2018090600:168:1           2
# 2018090600:190:1           3
# 2018090600:256:1           4
#
#                                                     playDescription  quarter  \
# id
# 2018090600:75:1   (15:00) M.Ryan pass short right to J.Jones pus...        1
# 2018090600:146:1  (13:10) M.Ryan pass incomplete short right to ...        1
# 2018090600:168:1  (13:05) (Shotgun) M.Ryan pass incomplete short...        1
# 2018090600:190:1  (13:01) (Shotgun) M.Ryan pass deep left to J.J...        1
# 2018090600:256:1  (10:59) (Shotgun) M.Ryan pass incomplete short...        1
#
#                   down  yardsToGo possessionTeam        playType yardlineSide  \
# id
# 2018090600:75:1      1         15            ATL  play_type_pass          ATL
# 2018090600:146:1     1         10            ATL  play_type_pass          PHI
# 2018090600:168:1     2         10            ATL  play_type_pass          PHI
# 2018090600:190:1     3         10            ATL  play_type_pass          PHI
# 2018090600:256:1     3          1            ATL  play_type_pass          PHI
#
#                   yardlineNumber offenseFormation        personnelO  \
# id
# 2018090600:75:1               20           I_FORM  2 RB, 1 TE, 2 WR
# 2018090600:146:1              39       SINGLEBACK  1 RB, 1 TE, 3 WR
# 2018090600:168:1              39          SHOTGUN  2 RB, 1 TE, 2 WR
# 2018090600:190:1              39          SHOTGUN  1 RB, 1 TE, 3 WR
# 2018090600:256:1               1          SHOTGUN  2 RB, 3 TE, 0 WR
#
#                   defendersInTheBox  numberOfPassRushers        personnelD  \
# id
# 2018090600:75:1                 7.0                  4.0  4 DL, 2 LB, 5 DB
# 2018090600:146:1                7.0                  4.0  4 DL, 2 LB, 5 DB
# 2018090600:168:1                6.0                  4.0  4 DL, 2 LB, 5 DB
# 2018090600:190:1                6.0                  5.0  4 DL, 1 LB, 6 DB
# 2018090600:256:1                8.0                  6.0  6 DL, 3 LB, 2 DB
#
#                   preSnapVisitorScore  preSnapHomeScore gameClock  \
# id
# 2018090600:75:1                   0.0               0.0  15:00:00
# 2018090600:146:1                  0.0               0.0  13:10:00
# 2018090600:168:1                  0.0               0.0  13:05:00
# 2018090600:190:1                  0.0               0.0  13:01:00
# 2018090600:256:1                  0.0               0.0  10:59:00
#
#                   absoluteYardlineNumber penaltyCodes penaltyJerseyNumbers  \
# id
# 2018090600:75:1                     90.0          NaN                  NaN
# 2018090600:146:1                    49.0          NaN                  NaN
# 2018090600:168:1                    49.0          NaN                  NaN
# 2018090600:190:1                    49.0          NaN                  NaN
# 2018090600:256:1                    11.0          NaN                  NaN
#
#                  passResult  offensePlayResult  playResult       epa  \
# id
# 2018090600:75:1           C                 10          10  0.261827
# 2018090600:146:1          I                  0           0 -0.372360
# 2018090600:168:1          I                  0           0 -0.702779
# 2018090600:190:1          C                 33          33  3.047530
# 2018090600:256:1          I                  0           0 -0.842272
#
#                   isDefensivePI
# id
# 2018090600:75:1           False
# 2018090600:146:1          False
# 2018090600:168:1          False
# 2018090600:190:1          False
# 2018090600:256:1          False

# %%
plays.drop(["Unnamed: 0"],axis=1,inplace=True)

# %%
def obtainDefenseTeam(playId):
    playIdParts = playId.split(":")
    gameId = playIdParts[0]
    visitorTeam = games.loc[int(gameId)]["visitorTeamAbbr"]
    homeTeam = games.loc[int(gameId)]["homeTeamAbbr"]
    possessionTeam = plays.loc[playId]["possessionTeam"]
    
    if possessionTeam == visitorTeam: #si equipo visitante tiene el balón, el equipo local es el que defiende
        value = "home"
    elif possessionTeam == homeTeam:
        value = "away"
    
    return value

# %%
def obtainOffenseTeam(playId):
    playIdParts = playId.split(":")
    gameId = playIdParts[0]
    visitorTeam = games.loc[int(gameId)]["visitorTeamAbbr"]
    homeTeam = games.loc[int(gameId)]["homeTeamAbbr"]
    possessionTeam = plays.loc[playId]["possessionTeam"]
    
    if possessionTeam == visitorTeam: #si equipo visitante tiene el balón, el equipo local es el que defiende
        value = "away"
    elif possessionTeam == homeTeam:
        value = "home"
    
    return value

# %%
games = pd.read_csv("../raw_data/games.csv",index_col=0)
games.head()
# Out:
#               gameDate gameTimeEastern homeTeamAbbr visitorTeamAbbr  week
# gameId
# 2018090600  09/06/2018        20:20:00          PHI             ATL     1
# 2018090901  09/09/2018        13:00:00          CLE             PIT     1
# 2018090902  09/09/2018        13:00:00          IND             CIN     1
# 2018090903  09/09/2018        13:00:00          MIA             TEN     1
# 2018090900  09/09/2018        13:00:00          BAL             BUF     1

# %%
summary = pd.DataFrame()

# %% [markdown]
# # Obtener todas las jugadas de tercer down

# %%
third_down_plays = plays[(plays["down"]==3)&(plays["passResult"]!="S")]
third_down_plays
# Out:
#                                                       playDescription  \
# id
# 2018090600:190:1    (13:01) (Shotgun) M.Ryan pass deep left to J.J...
# 2018090600:256:1    (10:59) (Shotgun) M.Ryan pass incomplete short...
# 2018090600:344:1    (9:24) (Shotgun) N.Foles pass incomplete short...
# 2018090600:636:1    (5:07) (Shotgun) M.Ryan pass incomplete short ...
# 2018090600:949:1    (15:00) (Shotgun) M.Ryan pass short left to D....
# ...                                                               ...
# 2018123015:2373:17  (11:58) (Shotgun) J.Rosen pass incomplete shor...
# 2018123015:2629:17  (7:43) (Shotgun) J.Rosen pass incomplete deep ...
# 2018123015:2998:17  (4:17) (Shotgun) J.Rosen pass short middle to ...
# 2018123015:3180:17  (:24) (Shotgun) R.Wilson pass incomplete short...
# 2018123015:3969:17  (2:00) (Shotgun) J.Rosen pass incomplete deep ...
#
#                     quarter  down  yardsToGo possessionTeam        playType  \
# id
# 2018090600:190:1          1     3         10            ATL  play_type_pass
# 2018090600:256:1          1     3          1            ATL  play_type_pass
# 2018090600:344:1          1     3          4            PHI  play_type_pass
# 2018090600:636:1          1     3          3            ATL  play_type_pass
# 2018090600:949:1          2     3         12            ATL  play_type_pass
# ...                     ...   ...        ...            ...             ...
# 2018123015:2373:17        3     3          2            ARI  play_type_pass
# 2018123015:2629:17        3     3         13            ARI  play_type_pass
# 2018123015:2998:17        3     3         10            ARI  play_type_pass
# 2018123015:3180:17        3     3          5            SEA  play_type_pass
# 2018123015:3969:17        4     3         12            ARI  play_type_pass
#
#                    yardlineSide  yardlineNumber offenseFormation  \
# id
# 2018090600:190:1            PHI              39          SHOTGUN
# 2018090600:256:1            PHI               1          SHOTGUN
# 2018090600:344:1            PHI               8            EMPTY
# 2018090600:636:1            PHI               3          SHOTGUN
# 2018090600:949:1            ATL              18          SHOTGUN
# ...                         ...             ...              ...
# 2018123015:2373:17          ARI              27            EMPTY
# 2018123015:2629:17          SEA              48          SHOTGUN
# 2018123015:2998:17          ARI              30          SHOTGUN
# 2018123015:3180:17          SEA              25            EMPTY
# 2018123015:3969:17          SEA              37          SHOTGUN
#
#                           personnelO  defendersInTheBox  numberOfPassRushers  \
# id
# 2018090600:190:1    1 RB, 1 TE, 3 WR                6.0                  5.0
# 2018090600:256:1    2 RB, 3 TE, 0 WR                8.0                  6.0
# 2018090600:344:1    1 RB, 2 TE, 2 WR                6.0                  4.0
# 2018090600:636:1    1 RB, 2 TE, 2 WR                6.0                  4.0
# 2018090600:949:1    1 RB, 1 TE, 3 WR                4.0                  4.0
# ...                              ...                ...                  ...
# 2018123015:2373:17  1 RB, 1 TE, 3 WR                5.0                  4.0
# 2018123015:2629:17  1 RB, 1 TE, 3 WR                4.0                  4.0
# 2018123015:2998:17  1 RB, 1 TE, 3 WR                5.0                  4.0
# 2018123015:3180:17  1 RB, 1 TE, 3 WR                7.0                  5.0
# 2018123015:3969:17  1 RB, 1 TE, 3 WR                5.0                  4.0
#
#                           personnelD  preSnapVisitorScore  preSnapHomeScore  \
# id
# 2018090600:190:1    4 DL, 1 LB, 6 DB                  0.0               0.0
# 2018090600:256:1    6 DL, 3 LB, 2 DB                  0.0               0.0
# 2018090600:344:1    3 DL, 3 LB, 5 DB                  0.0               0.0
# 2018090600:636:1    4 DL, 2 LB, 5 DB                  0.0               0.0
# 2018090600:949:1    4 DL, 1 LB, 6 DB                  3.0               0.0
# ...                              ...                  ...               ...
# 2018123015:2373:17  4 DL, 2 LB, 5 DB                 13.0              14.0
# 2018123015:2629:17  4 DL, 1 LB, 6 DB                 13.0              14.0
# 2018123015:2998:17  4 DL, 1 LB, 6 DB                 13.0              21.0
# 2018123015:3180:17  4 DL, 2 LB, 5 DB                 13.0              21.0
# 2018123015:3969:17  4 DL, 1 LB, 6 DB                 21.0              24.0
#
#                    gameClock  absoluteYardlineNumber penaltyCodes  \
# id
# 2018090600:190:1    13:01:00                    49.0          NaN
# 2018090600:256:1    10:59:00                    11.0          NaN
# 2018090600:344:1    09:24:00                    18.0          NaN
# 2018090600:636:1    05:07:00                    13.0          NaN
# 2018090600:949:1    15:00:00                    28.0          NaN
# ...                      ...                     ...          ...
# 2018123015:2373:17  11:58:00                    37.0          NaN
# 2018123015:2629:17  07:43:00                    62.0          NaN
# 2018123015:2998:17  04:17:00                    40.0          NaN
# 2018123015:3180:17  00:24:00                    85.0          NaN
# 2018123015:3969:17  02:00:00                    47.0          NaN
#
#                    penaltyJerseyNumbers passResult  offensePlayResult  \
# id
# 2018090600:190:1                    NaN          C                 33
# 2018090600:256:1                    NaN          I                  0
# 2018090600:344:1                    NaN          I                  0
# 2018090600:636:1                    NaN          I                  0
# 2018090600:949:1                    NaN          C                 -7
# ...                                 ...        ...                ...
# 2018123015:2373:17                  NaN          I                  0
# 2018123015:2629:17                  NaN          I                  0
# 2018123015:2998:17                  NaN          C                  9
# 2018123015:3180:17                  NaN          I                  0
# 2018123015:3969:17                  NaN          I                  0
#
#                     playResult       epa  isDefensivePI
# id
# 2018090600:190:1            33  3.047530          False
# 2018090600:256:1             0 -0.842272          False
# 2018090600:344:1             0 -1.192208          False
# 2018090600:636:1             0 -0.874640          False
# 2018090600:949:1            -7 -1.912483          False
# ...                        ...       ...            ...
# 2018123015:2373:17           0 -1.659557          False
# 2018123015:2629:17           0 -1.748119          False
# 2018123015:2998:17           9 -1.153889          False
# 2018123015:3180:17           0 -1.617042          False
# 2018123015:3969:17           0 -0.944168          False
#
# [4555 rows x 24 columns]

# %%
third_down_plays = third_down_plays.sample(frac=0.025)
third_down_plays
# Out:
#                                                       playDescription  \
# id
# 2018093006:2225:4   (:07) (Shotgun) R.Tannehill pass short middle ...
# 2018101500:3701:6   (1:13) (Shotgun) C.Beathard pass deep middle i...
# 2018122300:3525:16  (7:19) (Shotgun) A.Luck pass short middle to T...
# 2018121700:852:15   (:57) (Shotgun) C.Newton pass incomplete short...
# 2018102500:273:8    (11:35) (Shotgun) B.Osweiler pass short left t...
# ...                                                               ...
# 2018100100:2596:4   (6:55) (Shotgun) P.Mahomes pass incomplete dee...
# 2018110400:1702:9   (3:50) (Shotgun) B.Roethlisberger pass short r...
# 2018120202:4144:13  (3:07) (Shotgun) M.Stafford pass incomplete de...
# 2018120300:1513:13  (4:54) (Shotgun) C.Wentz pass short right to N...
# 2018120902:699:14   (3:29) (Shotgun) C.Newton pass short middle to...
#
#                     quarter  down  yardsToGo possessionTeam        playType  \
# id
# 2018093006:2225:4         2     3          1            MIA  play_type_pass
# 2018101500:3701:6         4     3          3             SF  play_type_pass
# 2018122300:3525:16        4     3          5            IND  play_type_pass
# 2018121700:852:15         1     3          1            CAR  play_type_pass
# 2018102500:273:8          1     3         11            MIA  play_type_pass
# ...                     ...   ...        ...            ...             ...
# 2018100100:2596:4         3     3         17             KC  play_type_pass
# 2018110400:1702:9         2     3          2            PIT  play_type_pass
# 2018120202:4144:13        4     3         12            DET  play_type_pass
# 2018120300:1513:13        2     3          8            PHI  play_type_pass
# 2018120902:699:14         1     3         21            CAR  play_type_pass
#
#                    yardlineSide  yardlineNumber offenseFormation  \
# id
# 2018093006:2225:4           MIA              34          SHOTGUN
# 2018101500:3701:6            GB              46          SHOTGUN
# 2018122300:3525:16          IND              41          SHOTGUN
# 2018121700:852:15           CAR              34          SHOTGUN
# 2018102500:273:8            HOU              38          SHOTGUN
# ...                         ...             ...              ...
# 2018100100:2596:4           DEN              44          SHOTGUN
# 2018110400:1702:9           PIT              33          SHOTGUN
# 2018120202:4144:13           LA              17            EMPTY
# 2018120300:1513:13          WAS               8          SHOTGUN
# 2018120902:699:14           CAR              37          SHOTGUN
#
#                           personnelO  defendersInTheBox  numberOfPassRushers  \
# id
# 2018093006:2225:4   1 RB, 0 TE, 4 WR                3.0                  3.0
# 2018101500:3701:6   1 RB, 1 TE, 3 WR                8.0                  6.0
# 2018122300:3525:16  1 RB, 0 TE, 4 WR                6.0                  3.0
# 2018121700:852:15   1 RB, 1 TE, 3 WR                6.0                  5.0
# 2018102500:273:8    1 RB, 1 TE, 3 WR                6.0                  2.0
# ...                              ...                ...                  ...
# 2018100100:2596:4   1 RB, 2 TE, 2 WR                5.0                  4.0
# 2018110400:1702:9   1 RB, 1 TE, 3 WR                7.0                  6.0
# 2018120202:4144:13  0 RB, 1 TE, 4 WR                5.0                  4.0
# 2018120300:1513:13  1 RB, 2 TE, 2 WR                5.0                  4.0
# 2018120902:699:14   1 RB, 1 TE, 3 WR                4.0                  4.0
#
#                           personnelD  preSnapVisitorScore  preSnapHomeScore  \
# id
# 2018093006:2225:4   3 DL, 1 LB, 7 DB                  0.0              24.0
# 2018101500:3701:6   2 DL, 3 LB, 6 DB                 30.0              30.0
# 2018122300:3525:16  1 DL, 5 LB, 5 DB                 27.0              21.0
# 2018121700:852:15   4 DL, 2 LB, 5 DB                  3.0               7.0
# 2018102500:273:8    2 DL, 4 LB, 5 DB                  0.0               0.0
# ...                              ...                  ...               ...
# 2018100100:2596:4   3 DL, 2 LB, 6 DB                 13.0              13.0
# 2018110400:1702:9   2 DL, 4 LB, 5 DB                 14.0               6.0
# 2018120202:4144:13  4 DL, 1 LB, 6 DB                 23.0              13.0
# 2018120300:1513:13  2 DL, 4 LB, 5 DB                 10.0               7.0
# 2018120902:699:14   3 DL, 3 LB, 5 DB                  7.0               7.0
#
#                    gameClock  absoluteYardlineNumber penaltyCodes  \
# id
# 2018093006:2225:4   00:07:00                    76.0          NaN
# 2018101500:3701:6   01:13:00                    56.0          NaN
# 2018122300:3525:16  07:19:00                    51.0          NaN
# 2018121700:852:15   00:57:00                    44.0          NaN
# 2018102500:273:8    11:35:00                    72.0          NaN
# ...                      ...                     ...          ...
# 2018100100:2596:4   06:55:00                    54.0          NaN
# 2018110400:1702:9   03:50:00                    77.0          NaN
# 2018120202:4144:13  03:07:00                    27.0          NaN
# 2018120300:1513:13  04:54:00                   102.0          NaN
# 2018120902:699:14   03:29:00                    73.0          NaN
#
#                    penaltyJerseyNumbers passResult  offensePlayResult  \
# id
# 2018093006:2225:4                   NaN          C                 13
# 2018101500:3701:6                   NaN         IN                  0
# 2018122300:3525:16                  NaN          C                 20
# 2018121700:852:15                   NaN          I                  0
# 2018102500:273:8                    NaN          C                 10
# ...                                 ...        ...                ...
# 2018100100:2596:4                   NaN          I                  0
# 2018110400:1702:9                   NaN          C                  5
# 2018120202:4144:13                  NaN          I                  0
# 2018120300:1513:13                  NaN          C                  7
# 2018120902:699:14                   NaN          C                 12
#
#                     playResult       epa  isDefensivePI
# id
# 2018093006:2225:4           13 -1.771472          False
# 2018101500:3701:6            0 -2.019912          False
# 2018122300:3525:16          20  2.502640          False
# 2018121700:852:15            0 -1.694564          False
# 2018102500:273:8            10 -0.348880          False
# ...                        ...       ...            ...
# 2018100100:2596:4            0 -1.664076          False
# 2018110400:1702:9            5  1.310219          False
# 2018120202:4144:13           0 -0.917791          False
# 2018120300:1513:13           7 -0.334846          False
# 2018120902:699:14           12 -0.938950          False
#
# [114 rows x 24 columns]

# %%
def evaluateDefense(playId):
    yardsToGo = third_down_plays.loc[playId]["yardsToGo"]
    offensePlayResult = third_down_plays.loc[playId]["offensePlayResult"]
    
    if offensePlayResult < yardsToGo:
        value = 1   #defensa exitosa
    else:
        value = 0   #mala defensa
        
    return value

# %%
third_down_plays["defenseValoration"] = third_down_plays.index.map(evaluateDefense)
third_down_plays.head()
# Out:
#                                                       playDescription  \
# id
# 2018093006:2225:4   (:07) (Shotgun) R.Tannehill pass short middle ...
# 2018101500:3701:6   (1:13) (Shotgun) C.Beathard pass deep middle i...
# 2018122300:3525:16  (7:19) (Shotgun) A.Luck pass short middle to T...
# 2018121700:852:15   (:57) (Shotgun) C.Newton pass incomplete short...
# 2018102500:273:8    (11:35) (Shotgun) B.Osweiler pass short left t...
#
#                     quarter  down  yardsToGo possessionTeam        playType  \
# id
# 2018093006:2225:4         2     3          1            MIA  play_type_pass
# 2018101500:3701:6         4     3          3             SF  play_type_pass
# 2018122300:3525:16        4     3          5            IND  play_type_pass
# 2018121700:852:15         1     3          1            CAR  play_type_pass
# 2018102500:273:8          1     3         11            MIA  play_type_pass
#
#                    yardlineSide  yardlineNumber offenseFormation  \
# id
# 2018093006:2225:4           MIA              34          SHOTGUN
# 2018101500:3701:6            GB              46          SHOTGUN
# 2018122300:3525:16          IND              41          SHOTGUN
# 2018121700:852:15           CAR              34          SHOTGUN
# 2018102500:273:8            HOU              38          SHOTGUN
#
#                           personnelO  defendersInTheBox  numberOfPassRushers  \
# id
# 2018093006:2225:4   1 RB, 0 TE, 4 WR                3.0                  3.0
# 2018101500:3701:6   1 RB, 1 TE, 3 WR                8.0                  6.0
# 2018122300:3525:16  1 RB, 0 TE, 4 WR                6.0                  3.0
# 2018121700:852:15   1 RB, 1 TE, 3 WR                6.0                  5.0
# 2018102500:273:8    1 RB, 1 TE, 3 WR                6.0                  2.0
#
#                           personnelD  preSnapVisitorScore  preSnapHomeScore  \
# id
# 2018093006:2225:4   3 DL, 1 LB, 7 DB                  0.0              24.0
# 2018101500:3701:6   2 DL, 3 LB, 6 DB                 30.0              30.0
# 2018122300:3525:16  1 DL, 5 LB, 5 DB                 27.0              21.0
# 2018121700:852:15   4 DL, 2 LB, 5 DB                  3.0               7.0
# 2018102500:273:8    2 DL, 4 LB, 5 DB                  0.0               0.0
#
#                    gameClock  absoluteYardlineNumber penaltyCodes  \
# id
# 2018093006:2225:4   00:07:00                    76.0          NaN
# 2018101500:3701:6   01:13:00                    56.0          NaN
# 2018122300:3525:16  07:19:00                    51.0          NaN
# 2018121700:852:15   00:57:00                    44.0          NaN
# 2018102500:273:8    11:35:00                    72.0          NaN
#
#                    penaltyJerseyNumbers passResult  offensePlayResult  \
# id
# 2018093006:2225:4                   NaN          C                 13
# 2018101500:3701:6                   NaN         IN                  0
# 2018122300:3525:16                  NaN          C                 20
# 2018121700:852:15                   NaN          I                  0
# 2018102500:273:8                    NaN          C                 10
#
#                     playResult       epa  isDefensivePI  defenseValoration
# id
# 2018093006:2225:4           13 -1.771472          False                  0
# 2018101500:3701:6            0 -2.019912          False                  1
# 2018122300:3525:16          20  2.502640          False                  0
# 2018121700:852:15            0 -1.694564          False                  1
# 2018102500:273:8            10 -0.348880          False                  1

# %%
len(third_down_plays[third_down_plays["defenseValoration"]==0])
# Out:
# 48

# %%
len(third_down_plays[third_down_plays["defenseValoration"]==1])
# Out:
# 66

# %%
week1[(week1["id"]=="2018090900:1869:1")&(week1["frameId"]==1)&(week1["team"]==obtainDefenseTeam("2018090900:1869:1"))]
# Out:
#                        id                      time      x      y     s     a  \
# 110087  2018090900:1869:1  2018-09-09T18:19:07.599Z  28.65  10.32  0.00  0.00
# 110090  2018090900:1869:1  2018-09-09T18:19:07.599Z  41.21  30.66  0.70  0.90
# 110091  2018090900:1869:1  2018-09-09T18:19:07.599Z  33.82  18.26  0.45  0.75
# 110094  2018090900:1869:1  2018-09-09T18:19:07.599Z  28.55  18.95  0.34  0.66
# 110096  2018090900:1869:1  2018-09-09T18:19:07.599Z  35.16  43.51  0.04  0.05
# 110097  2018090900:1869:1  2018-09-09T18:19:07.599Z  32.46  23.12  0.54  1.74
#
#          dis       o     dir event      nflId      displayName  jerseyNumber  \
# 110087  0.00  292.57    7.76  None     4365.0     Brandon Carr          24.0
# 110090  0.06  247.99  316.80  None  2495775.0      Eric Weddle          32.0
# 110091  0.04  295.26   35.27  None  2540164.0   Tony Jefferson          23.0
# 110094  0.03  269.93  230.71  None  2557841.0     Tim Williams          56.0
# 110096  0.01  244.12  227.59  None  2558067.0  Marlon Humphrey          29.0
# 110097  0.05  265.73  331.39  None  2558166.0      Tyus Bowser          54.0
#
#        position  frameId  team playDirection route
# 110087       CB        1  home         right   NaN
# 110090       FS        1  home         right   NaN
# 110091       SS        1  home         right   NaN
# 110094      OLB        1  home         right   NaN
# 110096       CB        1  home         right   NaN
# 110097      OLB        1  home         right   NaN

# %% [markdown]
# Tan solo están los jugadores que van a defender el pase

# %%
summary["playerId"] = ""

# %%
summary["playId"]=""

# %%
for play in third_down_plays.index:
    idParts = play.split(":")
    idWeek = idParts[2]
    week = weeks[int(idWeek)-1]
    #summary.append(week[(week["id"]==play)&(week["team"]==obtainDefenseTeam(play))]["nflId"].unique())
    for player in week[(week["id"]==play)&(week["team"]==obtainDefenseTeam(play))]["nflId"].unique():
        summary = summary.append({"playerId":player,"playId":play},ignore_index=True)

# %%
summary
# Out:
#       playerId             playId
# 0      71251.0  2018093006:2225:4
# 1      89756.0  2018093006:2225:4
# 2     494287.0  2018093006:2225:4
# 3    2533062.0  2018093006:2225:4
# 4    2541243.0  2018093006:2225:4
# ..         ...                ...
# 752  2550164.0  2018120902:699:14
# 753  2552389.0  2018120902:699:14
# 754  2555166.0  2018120902:699:14
# 755  2555540.0  2018120902:699:14
# 756  2556475.0  2018120902:699:14
#
# [757 rows x 2 columns]

# %%
#save dataset
pickle_file = open('../resources/summary.pickle','wb')
pickle.dump(summary,pickle_file)
pickle_file.close()

# %%
#load dataset
pickle_file = open('../resources/summary.pickle','rb')
summary = pickle.load(pickle_file)
pickle_file.close()

# %% [markdown]
# Obtener los jugadores defensivos de esa jugada:

# %% [markdown]
# # Individual Actions Data (p): consideramos que el jugador ejecuta una acción en toda la jugada de la acción, hay que sacar por tanto una acción resumen de todas      para cada jugador p_i (i = a ... j) tenemos una serie de m características {p_i1, p_i2, ..., p_im}

# %%
#### Esto luego no servirá
week1_fpf = week1[week1["event"]=="pass_forward"]
week1_fpf.head()
# Out:
#                                      time      x      y     s     a   dis  \
# id
# 2018090600:75:1  2018-09-07T01:07:18.099Z  96.43  26.78  0.84  2.05  0.08
# 2018090600:75:1  2018-09-07T01:07:18.099Z  84.82  38.33  5.53  4.30  0.54
# 2018090600:75:1  2018-09-07T01:07:18.099Z  80.69  44.91  3.11  6.67  0.34
# 2018090600:75:1  2018-09-07T01:07:18.099Z  86.02  18.64  3.52  0.69  0.35
# 2018090600:75:1  2018-09-07T01:07:18.099Z  82.65  34.56  6.35  1.21  0.64
#
#                       o     dir         event      nflId      displayName  \
# id
# 2018090600:75:1  356.40  333.39  pass_forward      310.0        Matt Ryan
# 2018090600:75:1  295.34  318.58  pass_forward    79848.0  Malcolm Jenkins
# 2018090600:75:1  155.11  297.88  pass_forward  2495454.0      Julio Jones
# 2018090600:75:1   28.19  216.15  pass_forward  2495613.0     Corey Graham
# 2018090600:75:1  262.06  272.78  pass_forward  2533040.0     Mohamed Sanu
#
#                  jerseyNumber position  frameId  team playDirection  route
# id
# 2018090600:75:1           2.0       QB       36  away          left    NaN
# 2018090600:75:1          27.0       SS       36  home          left    NaN
# 2018090600:75:1          11.0       WR       36  away          left  HITCH
# 2018090600:75:1          24.0       FS       36  home          left    NaN
# 2018090600:75:1          12.0       WR       36  away          left  HITCH

# %%
defense_fpf = week1_fpf[week1_fpf.index.isin([selected_play]) & (week1_fpf["team"]==obtainDefenseTeam(selected_play))]
defense_fpf
# Out:
#                                       time      x      y     s     a   dis  \
# id
# 2018090905:313:1  2018-09-09T17:14:25.200Z  70.13  15.61  7.97  0.21  0.82
# 2018090905:313:1  2018-09-09T17:14:25.200Z  58.68  35.90  5.63  0.92  0.56
# 2018090905:313:1  2018-09-09T17:14:25.200Z  60.94  15.63  5.59  3.56  0.56
# 2018090905:313:1  2018-09-09T17:14:25.200Z  71.74   3.42  1.22  1.97  0.12
# 2018090905:313:1  2018-09-09T17:14:25.200Z  60.70  12.93  4.42  3.73  0.44
# 2018090905:313:1  2018-09-09T17:14:25.200Z  92.51  39.99  7.70  1.27  0.77
# 2018090905:313:1  2018-09-09T17:14:25.200Z  74.00  47.21  4.31  3.62  0.44
# 2018090905:313:1  2018-09-09T17:14:25.200Z  68.22  51.49  3.01  2.70  0.31
#
#                        o     dir         event      nflId       displayName  \
# id
# 2018090905:313:1  345.12  345.09  pass_forward    71251.0     Patrick Chung
# 2018090905:313:1   26.60  350.99  pass_forward   494287.0    Devin McCourty
# 2018090905:313:1  313.89  307.53  pass_forward  2533057.0  Dont'a Hightower
# 2018090905:313:1  115.75  260.62  pass_forward  2533062.0   Stephon Gilmore
# 2018090905:313:1   12.95  340.10  pass_forward  2541243.0      Duron Harmon
# 2018090905:313:1    8.60   11.76  pass_forward  2543699.0      Kyle Van Noy
# 2018090905:313:1   38.15  345.06  pass_forward  2552255.0         Eric Rowe
# 2018090905:313:1  349.57  298.95  pass_forward  2561143.0  Ja'Whaun Bentley
#
#                   jerseyNumber position  frameId  team playDirection route
# id
# 2018090905:313:1          23.0       SS       67  home          left   NaN
# 2018090905:313:1          32.0       FS       67  home          left   NaN
# 2018090905:313:1          54.0      MLB       67  home          left   NaN
# 2018090905:313:1          24.0       CB       67  home          left   NaN
# 2018090905:313:1          21.0       FS       67  home          left   NaN
# 2018090905:313:1          53.0      OLB       67  home          left   NaN
# 2018090905:313:1          25.0       CB       67  home          left   NaN
# 2018090905:313:1          51.0       LB       67  home          left   NaN

# %%
week1[week1["event"].isin(["pass_forward"])]
# Out:
#                        id                      time      x      y     s     a  \
# 490       2018090600:75:1  2018-09-07T01:07:18.099Z  96.43  26.78  0.84  2.05
# 491       2018090600:75:1  2018-09-07T01:07:18.099Z  84.82  38.33  5.53  4.30
# 492       2018090600:75:1  2018-09-07T01:07:18.099Z  80.69  44.91  3.11  6.67
# 493       2018090600:75:1  2018-09-07T01:07:18.099Z  86.02  18.64  3.52  0.69
# 494       2018090600:75:1  2018-09-07T01:07:18.099Z  82.65  34.56  6.35  1.21
# ...                   ...                       ...    ...    ...   ...   ...
# 921155  2018091001:4192:1  2018-09-11T05:29:36.000Z  35.19  25.58  2.14  1.38
# 921156  2018091001:4192:1  2018-09-11T05:29:36.000Z  35.85  38.20  2.68  1.33
# 921157  2018091001:4192:1  2018-09-11T05:29:36.000Z  40.85  46.18  0.92  4.07
# 921158  2018091001:4192:1  2018-09-11T05:29:36.000Z  28.48  36.19  0.93  2.26
# 921159  2018091001:4192:1  2018-09-11T05:29:36.000Z  47.63  29.64  2.16  3.90
#
#          dis       o     dir         event      nflId       displayName  \
# 490     0.08  356.40  333.39  pass_forward      310.0         Matt Ryan
# 491     0.54  295.34  318.58  pass_forward    79848.0   Malcolm Jenkins
# 492     0.34  155.11  297.88  pass_forward  2495454.0       Julio Jones
# 493     0.35   28.19  216.15  pass_forward  2495613.0      Corey Graham
# 494     0.64  262.06  272.78  pass_forward  2533040.0      Mohamed Sanu
# ...      ...     ...     ...           ...        ...               ...
# 921155  0.22   91.21  333.38  pass_forward  2556277.0  Marqui Christian
# 921156  0.26   79.60  343.60  pass_forward  2556593.0    Cory Littleton
# 921157  0.08  156.73  134.27  pass_forward  2556885.0     Jalen Richard
# 921158  0.09   79.63   27.26  pass_forward  2558183.0      John Johnson
# 921159  0.23     NaN     NaN  pass_forward        NaN          Football
#
#         jerseyNumber position  frameId      team playDirection   route
# 490              2.0       QB       36      away          left     NaN
# 491             27.0       SS       36      home          left     NaN
# 492             11.0       WR       36      away          left   HITCH
# 493             24.0       FS       36      home          left     NaN
# 494             12.0       WR       36      away          left   HITCH
# ...              ...      ...      ...       ...           ...     ...
# 921155          41.0       SS       26      away          left     NaN
# 921156          58.0      ILB       26      away          left     NaN
# 921157          30.0       RB       26      home          left  SCREEN
# 921158          43.0       SS       26      away          left     NaN
# 921159           NaN      NaN       26  football          left     NaN
#
# [13204 rows x 18 columns]

# %%
week1.loc[selected_play]["event"].unique()
# Out:
# array(['None', 'ball_snap', 'pass_forward', 'pass_arrived',
#        'pass_outcome_caught', 'out_of_bounds'], dtype=object)

# %%
week1_pa = week1[week1["event"]=="pass_arrived"]
week1_pa
# Out:
#                                        time      x      y     s     a   dis  \
# id
# 2018090600:75:1    2018-09-07T01:07:19.200Z  96.30  27.52  0.59  0.51  0.06
# 2018090600:75:1    2018-09-07T01:07:19.200Z  82.34  45.18  7.57  1.72  0.75
# 2018090600:75:1    2018-09-07T01:07:19.200Z  81.11  47.87  4.23  1.63  0.42
# 2018090600:75:1    2018-09-07T01:07:19.200Z  82.90  17.62  3.64  4.01  0.36
# 2018090600:75:1    2018-09-07T01:07:19.200Z  77.66  35.52  2.99  3.53  0.31
# ...                                     ...    ...    ...   ...   ...   ...
# 2018091001:4192:1  2018-09-11T05:29:36.799Z  34.72  28.43  4.96  3.17  0.48
# 2018091001:4192:1  2018-09-11T05:29:36.799Z  36.04  40.58  3.47  1.27  0.35
# 2018091001:4192:1  2018-09-11T05:29:36.799Z  41.88  45.46  1.32  2.35  0.14
# 2018091001:4192:1  2018-09-11T05:29:36.799Z  30.16  37.51  4.18  2.09  0.41
# 2018091001:4192:1  2018-09-11T05:29:36.799Z  42.60  45.22  2.84  0.36  0.51
#
#                         o     dir         event      nflId       displayName  \
# id
# 2018090600:75:1    333.07    1.23  pass_arrived      310.0         Matt Ryan
# 2018090600:75:1    354.68  353.52  pass_arrived    79848.0   Malcolm Jenkins
# 2018090600:75:1     53.31   22.58  pass_arrived  2495454.0       Julio Jones
# 2018090600:75:1     13.28  299.37  pass_arrived  2495613.0      Corey Graham
# 2018090600:75:1     78.88  305.48  pass_arrived  2533040.0      Mohamed Sanu
# ...                   ...     ...           ...        ...               ...
# 2018091001:4192:1   44.27  359.68  pass_arrived  2556277.0  Marqui Christian
# 2018091001:4192:1   86.95   16.47  pass_arrived  2556593.0    Cory Littleton
# 2018091001:4192:1  178.51  139.94  pass_arrived  2556885.0     Jalen Richard
# 2018091001:4192:1   69.48   54.34  pass_arrived  2558183.0      John Johnson
# 2018091001:4192:1     NaN     NaN  pass_arrived        NaN          Football
#
#                    jerseyNumber position  frameId      team playDirection  \
# id
# 2018090600:75:1             2.0       QB       47      away          left
# 2018090600:75:1            27.0       SS       47      home          left
# 2018090600:75:1            11.0       WR       47      away          left
# 2018090600:75:1            24.0       FS       47      home          left
# 2018090600:75:1            12.0       WR       47      away          left
# ...                         ...      ...      ...       ...           ...
# 2018091001:4192:1          41.0       SS       34      away          left
# 2018091001:4192:1          58.0      ILB       34      away          left
# 2018091001:4192:1          30.0       RB       34      home          left
# 2018091001:4192:1          43.0       SS       34      away          left
# 2018091001:4192:1           NaN      NaN       34  football          left
#
#                     route
# id
# 2018090600:75:1       NaN
# 2018090600:75:1       NaN
# 2018090600:75:1     HITCH
# 2018090600:75:1       NaN
# 2018090600:75:1     HITCH
# ...                   ...
# 2018091001:4192:1     NaN
# 2018091001:4192:1     NaN
# 2018091001:4192:1  SCREEN
# 2018091001:4192:1     NaN
# 2018091001:4192:1     NaN
#
# [11428 rows x 17 columns]

# %%
defense_pa = week1_pa[week1_pa.index.isin([selected_play]) & (week1_pa["team"]==obtainDefenseTeam(selected_play))]
defense_pa
# Out:
#                                       time      x      y     s     a   dis  \
# id
# 2018090905:313:1  2018-09-09T17:14:26.000Z  68.53  22.08  8.51  0.72  0.85
# 2018090905:313:1  2018-09-09T17:14:26.000Z  58.67  40.16  4.92  2.55  0.50
# 2018090905:313:1  2018-09-09T17:14:26.000Z  58.07  19.20  5.70  1.62  0.57
# 2018090905:313:1  2018-09-09T17:14:26.000Z  70.59   3.03  1.55  0.63  0.16
# 2018090905:313:1  2018-09-09T17:14:26.000Z  60.76  16.34  4.23  2.10  0.43
# 2018090905:313:1  2018-09-09T17:14:26.000Z  93.09  45.67  6.40  3.26  0.65
# 2018090905:313:1  2018-09-09T17:14:26.000Z  75.14  50.37  4.91  1.54  0.49
# 2018090905:313:1  2018-09-09T17:14:26.000Z  66.27  52.44  2.32  1.05  0.24
#
#                        o     dir         event      nflId       displayName  \
# id
# 2018090905:313:1  342.57  347.10  pass_arrived    71251.0     Patrick Chung
# 2018090905:313:1   23.22   10.87  pass_arrived   494287.0    Devin McCourty
# 2018090905:313:1  350.71  330.09  pass_arrived  2533057.0  Dont'a Hightower
# 2018090905:313:1   48.19  254.13  pass_arrived  2533062.0   Stephon Gilmore
# 2018090905:313:1   22.74   17.47  pass_arrived  2541243.0      Duron Harmon
# 2018090905:313:1  345.15  357.52  pass_arrived  2543699.0      Kyle Van Noy
# 2018090905:313:1   42.61   37.09  pass_arrived  2552255.0         Eric Rowe
# 2018090905:313:1   41.47  293.89  pass_arrived  2561143.0  Ja'Whaun Bentley
#
#                   jerseyNumber position  frameId  team playDirection route
# id
# 2018090905:313:1          23.0       SS       75  home          left   NaN
# 2018090905:313:1          32.0       FS       75  home          left   NaN
# 2018090905:313:1          54.0      MLB       75  home          left   NaN
# 2018090905:313:1          24.0       CB       75  home          left   NaN
# 2018090905:313:1          21.0       FS       75  home          left   NaN
# 2018090905:313:1          53.0      OLB       75  home          left   NaN
# 2018090905:313:1          25.0       CB       75  home          left   NaN
# 2018090905:313:1          51.0       LB       75  home          left   NaN

# %%
ball_snap = week1[week1.index.isin([selected_play]) & (week1["event"]=="ball_snap")]["frameId"].values[0]
ball_snap
# Out:
# 11

# %%
fpf_number = defense_fpf["frameId"].values[0]
fpf_number
# Out:
# 67

# %%
fpa = defense_pa["frameId"].values[0]
fpa
# Out:
# 75

# %% [markdown]
# Por cada jugador, ver el jugador más cercano rival y ver su distancia euclidea

# %%
def obtainMeanDistance(playerId,playId):
    idParts = playId.split(":")
    idWeek = idParts[2]
    week = weeks[int(idWeek)-1]
    print(playId)
    
    ball_snap = week[(week["id"]==playId) & (week["event"]=="ball_snap")]["frameId"].values[0]
    try:
        fpf_number = week[(week["id"]==playId) & (week["event"]=="pass_forward")]["frameId"].values[0]
    except:
        fpf_number = week[(week["id"]==playId) & (week["event"]=="pass_shovel")]["frameId"].values[0]
    #print(playId,ball_snap,fpf_number)
    mean_distances = []
    for frame in range(ball_snap,fpf_number+1):
        players = week[(week["frameId"]==frame)&(week["team"]==obtainOffenseTeam(playId))&(week["id"]==playId)]
        x = week[(week["frameId"]==frame)&(week["nflId"]==playerId)&(week["id"] == playId)]["x"].values[0]
        #x = week1[(week1["frameId"]==frame)&(week1["team"]==obtainOffenseTeam("2018090600:1037:1"))&(week1["route"].notnull())]
        y = week[(week["frameId"]==frame)&(week["nflId"]==playerId)&(week["id"]==playId)]["y"].values[0]
        #y = week1[(week1["playerId"]==playerId)]["y"].values[0]
        distances = []
        for index,row in players.iterrows():
            x_value = row["x"]
            y_value = row["y"]
            line = LineString([(x, y), (x_value, y_value)]) #distancia euclidea
            distances.append(line.length) #habría que tener en cuenta el jugador???
        #print(min(distances))
        mean_distances.append(min(distances))
    return sum(mean_distances)/len(mean_distances)

# %%
summary["meanDistance"] = summary.apply(lambda x: obtainMeanDistance(x["playerId"],x["playId"]),axis=1)

# %%
#save dataset
pickle_file = open('../resources/summary.pickle','wb')
pickle.dump(summary,pickle_file)
pickle_file.close()

# %%
summary
# Out:
#       playerId             playId  meanDistance
# 0      71251.0  2018093006:2225:4     10.568907
# 1      89756.0  2018093006:2225:4     10.946105
# 2     494287.0  2018093006:2225:4     31.074778
# 3    2533062.0  2018093006:2225:4     22.644911
# 4    2541243.0  2018093006:2225:4     24.893454
# ..         ...                ...           ...
# 752  2550164.0  2018120902:699:14      8.330134
# 753  2552389.0  2018120902:699:14     17.275020
# 754  2555166.0  2018120902:699:14     10.335948
# 755  2555540.0  2018120902:699:14     15.836416
# 756  2556475.0  2018120902:699:14     10.893971
#
# [756 rows x 3 columns]

# %%
def obtainMeanDistanceAfterPass(playerId,playId):
    idParts = playId.split(":")
    idWeek = idParts[2]
    week = weeks[int(idWeek)-1]
    print(playId)
    
    try:
        fpf_number = week[(week["id"]==playId) & (week["event"]=="pass_forward")]["frameId"].values[0]
    except:
        fpf_number = week[(week["id"]==playId) & (week["event"]=="pass_shovel")]["frameId"].values[0]
        
    try:
        fpa = week[(week["id"]==playId) & (week["event"]=="pass_arrived")]["frameId"].values[0]
    except:
        try:
            fpa = week[(week["id"]==playId) & (week["event"]=="pass_outcome_incomplete")]["frameId"].values[0]
        except:
            fpa = week[(week["id"]==playId) & (week["event"]=="pass_outcome_interception")]["frameId"].values[0]
    mean_distances = []
    for frame in range(fpf_number+1,fpa+1):
        players = week[(week["frameId"]==frame)&(week["team"]==obtainOffenseTeam(playId))&(week["id"]==playId)]
        x = week[(week["frameId"]==frame)&(week["nflId"]==playerId)&(week["id"] == playId)]["x"].values[0]
        #x = week1[(week1["frameId"]==frame)&(week1["team"]==obtainOffenseTeam("2018090600:1037:1"))&(week1["route"].notnull())]
        y = week[(week["frameId"]==frame)&(week["nflId"]==playerId)&(week["id"]==playId)]["y"].values[0]
        #y = week1[(week1["playerId"]==playerId)]["y"].values[0]
        distances = []
        for index,row in players.iterrows():
            x_value = row["x"]
            y_value = row["y"]
            line = LineString([(x, y), (x_value, y_value)]) #distancia euclidea
            distances.append(line.length) #habría que tener en cuenta el jugador???
        mean_distances.append(min(distances))
    return sum(mean_distances)/len(mean_distances)

# %%
summary["meanDistanceAfterPass"] = summary.apply(lambda x: obtainMeanDistanceAfterPass(x["playerId"],x["playId"]),axis=1)

# %%
summary
# Out:
#       playerId             playId  meanDistance  meanDistanceAfterPass
# 0      71251.0  2018093006:2225:4     10.568907              11.791571
# 1      89756.0  2018093006:2225:4     10.946105               4.581272
# 2     494287.0  2018093006:2225:4     31.074778              19.611594
# 3    2533062.0  2018093006:2225:4     22.644911              19.288428
# 4    2541243.0  2018093006:2225:4     24.893454              14.407899
# ..         ...                ...           ...                    ...
# 752  2550164.0  2018120902:699:14      8.330134               4.746337
# 753  2552389.0  2018120902:699:14     17.275020               3.427559
# 754  2555166.0  2018120902:699:14     10.335948               4.058543
# 755  2555540.0  2018120902:699:14     15.836416               8.746987
# 756  2556475.0  2018120902:699:14     10.893971               8.198164
#
# [756 rows x 4 columns]

# %%
#save dataset
pickle_file = open('../resources/summary.pickle','wb')
pickle.dump(summary,pickle_file)
pickle_file.close()

# %%
def obtainMeanPlayers(playerId,playId):
    idParts = playId.split(":")
    idWeek = idParts[2]
    week = weeks[int(idWeek)-1]
    
    try:
        fpa = week[(week["id"]==playId) & (week["event"]=="pass_arrived")]["frameId"].values[0]
    except:
        fpa = week[(week["id"]==playId) & (week["event"]=="pass_outcome_incomplete")]["frameId"].values[0]
    
    mean_number_players = []
    for frame in range(ball_snap,fpf_number+1):
        players = week[(week["frameId"]==frame)&(week["team"]==obtainOffenseTeam(playId))&(week["id"]==playId)]
        x = week[(week["frameId"]==frame)&(week["nflId"]==playerId)&(week["id"] == playId)]["x"].values[0]
        y = week[(week["frameId"]==frame)&(week["nflId"]==playerId)&(week["id"]==playId)]["y"].values[0]
        p = Point(x, y)
        circle = p.buffer(5.0)
        number_players = 0
        for index,row in players.iterrows():
            x_value = row["x"]
            y_value = row["y"]
            point = Point(x_value,y_value)
            if circle.contains(point):
                number_players += 1
        mean_number_players.append(number_players)
    return sum(mean_number_players)/len(mean_number_players)

# %%
summary["numberPlayers5yds"] = summary.apply(lambda x: obtainMeanPlayers(x["playerId"],x["playId"]),axis=1)

# %%
def obtainMeanPlayersAfterPass(playerId,playId):
    idParts = playId.split(":")
    idWeek = idParts[2]
    week = weeks[int(idWeek)-1]
    
    try:
        fpf_number = week[(week["id"]==playId) & (week["event"]=="pass_forward")]["frameId"].values[0]
    except:
        fpf_number = week[(week["id"]==playId) & (week["event"]=="pass_shovel")]["frameId"].values[0]
        
    try:
        fpa = week[(week["id"]==playId) & (week["event"]=="pass_arrived")]["frameId"].values[0]
    except:
        try:
            fpa = week[(week["id"]==playId) & (week["event"]=="pass_outcome_incomplete")]["frameId"].values[0]
        except:
            fpa = week[(week["id"]==playId) & (week["event"]=="pass_outcome_interception")]["frameId"].values[0]
    
    print(playId)
    mean_number_players = []
    for frame in range(fpf_number+1,fpa+1):
        players = week[(week["frameId"]==frame)&(week["team"]==obtainOffenseTeam(playId))&(week["id"]==playId)]
        x = week[(week["frameId"]==frame)&(week["nflId"]==playerId)&(week["id"] == playId)]["x"].values[0]
        y = week[(week["frameId"]==frame)&(week["nflId"]==playerId)&(week["id"]==playId)]["y"].values[0]
        p = Point(x, y)
        circle = p.buffer(5.0)
        number_players = 0
        for index,row in players.iterrows():
            x_value = row["x"]
            y_value = row["y"]
            point = Point(x_value,y_value)
            if circle.contains(point):
                number_players += 1
        mean_number_players.append(number_players)
    return sum(mean_number_players)/len(mean_number_players)

# %%
summary["numberPlayers5ydsAfterPass"] = summary.apply(lambda x: obtainMeanPlayersAfterPass(x["playerId"],x["playId"]),axis=1)

# %%
summary
# Out:
#       playerId             playId  meanDistance  meanDistanceAfterPass  \
# 0      71251.0  2018093006:2225:4     10.568907              11.791571
# 1      89756.0  2018093006:2225:4     10.946105               4.581272
# 2     494287.0  2018093006:2225:4     31.074778              19.611594
# 3    2533062.0  2018093006:2225:4     22.644911              19.288428
# 4    2541243.0  2018093006:2225:4     24.893454              14.407899
# ..         ...                ...           ...                    ...
# 752  2550164.0  2018120902:699:14      8.330134               4.746337
# 753  2552389.0  2018120902:699:14     17.275020               3.427559
# 754  2555166.0  2018120902:699:14     10.335948               4.058543
# 755  2555540.0  2018120902:699:14     15.836416               8.746987
# 756  2556475.0  2018120902:699:14     10.893971               8.198164
#
#      numberPlayers5ydsAfterPass
# 0                           0.0
# 1                           0.8
# 2                           0.0
# 3                           0.0
# 4                           0.0
# ..                          ...
# 752                         0.7
# 753                         0.7
# 754                         0.7
# 755                         0.0
# 756                         0.0
#
# [756 rows x 5 columns]

# %% [markdown]
# # Complex Features (c): Características dinámicas de la acción en general. Posiblemente podría ser cosas como variación de la superficie cubierta, variación de densidad, defensores en la zona del pase, ....

# %%
def obtainAreaDefense(playId):
    idParts = playId.split(":")
    idWeek = idParts[2]
    week = weeks[int(idWeek)-1]
    
    try:
        fpf_number = week[(week["id"]==playId) & (week["event"]=="pass_forward")]["frameId"].values[0]
    except:
        fpf_number = week[(week["id"]==playId) & (week["event"]=="pass_shovel")]["frameId"].values[0]
    print(playId)
    defenders = week[(week["team"]==obtainDefenseTeam(playId))&(week["id"]==playId)&(week["frameId"]==fpf_number)]
    position_players = []
    playDirection = defenders["playDirection"].values[0]
    los = plays.loc[playId]["absoluteYardlineNumber"]
    
    for index,row in defenders.iterrows():
        if row["position"] in ["DL","NT","DT","DE"]:
            continue
        
        if playDirection == "right" and row["x"] < los:
            continue
        elif playDirection == "left" and row["x"] > los:
            continue
        
        position_players.append((row["x"],row["y"]))
        
    hull = ConvexHull(position_players)
    
    return hull.volume

# %%
summary["areaDifference"] = summary["playId"].apply(obtainAreaDefense)

# %%
summary
# Out:
#       playerId             playId  meanDistance  meanDistanceAfterPass  \
# 0      71251.0  2018093006:2225:4     10.568907              11.791571
# 1      89756.0  2018093006:2225:4     10.946105               4.581272
# 2     494287.0  2018093006:2225:4     31.074778              19.611594
# 3    2533062.0  2018093006:2225:4     22.644911              19.288428
# 4    2541243.0  2018093006:2225:4     24.893454              14.407899
# ..         ...                ...           ...                    ...
# 752  2550164.0  2018120902:699:14      8.330134               4.746337
# 753  2552389.0  2018120902:699:14     17.275020               3.427559
# 754  2555166.0  2018120902:699:14     10.335948               4.058543
# 755  2555540.0  2018120902:699:14     15.836416               8.746987
# 756  2556475.0  2018120902:699:14     10.893971               8.198164
#
#      numberPlayers5ydsAfterPass  areaDifference
# 0                           0.0        576.9978
# 1                           0.8        576.9978
# 2                           0.0        576.9978
# 3                           0.0        576.9978
# 4                           0.0        576.9978
# ..                          ...             ...
# 752                         0.7        224.9864
# 753                         0.7        224.9864
# 754                         0.7        224.9864
# 755                         0.0        224.9864
# 756                         0.0        224.9864
#
# [583 rows x 6 columns]

# %%
dif = list(set(summary["playId"].unique()) - set(static_defense[static_defense.index.isin(summary["playId"].unique())].index))
dif
# Out:
# ['2018123007:2078:17',
#  '2018100708:831:5',
#  '2018091610:2230:2',
#  '2018121610:3201:15',
#  '2018122305:1078:16',
#  '2018111200:2880:10',
#  '2018102803:2323:8',
#  '2018102111:471:7',
#  '2018120202:4144:13',
#  '2018121605:907:15',
#  '2018102800:2332:8',
#  '2018123012:2548:17',
#  '2018091613:3423:2',
#  '2018092308:2471:3',
#  '2018111104:1195:10',
#  '2018112506:2739:12',
#  '2018102103:3152:7',
#  '2018120206:1789:13',
#  '2018090909:1772:1',
#  '2018102200:4121:7',
#  '2018111103:3385:10',
#  '2018101100:382:6',
#  '2018121601:1838:15',
#  '2018091603:733:2',
#  '2018120300:1513:13',
#  '2018101100:1536:6']

# %%
summary.drop(summary[summary["playId"].isin(dif)].index,inplace=True)

# %%
def obtainAreaDefenseDifference(playerId,playId):
    idParts = playId.split(":")
    idWeek = idParts[2]
    week = weeks[int(idWeek)-1]
    
    area1 = summary[(summary["playId"]==playId)&(summary["playerId"]==playerId)]["areaDifference"].values[0]
    area2 = static_defense.loc[playId]["defenseArea"]
    
    return area1 - area2

# %%
summary["areaDifference"] = summary.apply(lambda x: obtainAreaDefenseDifference(x["playerId"],x["playId"]),axis=1)

# %%
summary
# Out:
#       playerId             playId  meanDistance  meanDistanceAfterPass  \
# 0      71251.0  2018093006:2225:4     10.568907              11.791571
# 1      89756.0  2018093006:2225:4     10.946105               4.581272
# 2     494287.0  2018093006:2225:4     31.074778              19.611594
# 3    2533062.0  2018093006:2225:4     22.644911              19.288428
# 4    2541243.0  2018093006:2225:4     24.893454              14.407899
# ..         ...                ...           ...                    ...
# 752  2550164.0  2018120902:699:14      8.330134               4.746337
# 753  2552389.0  2018120902:699:14     17.275020               3.427559
# 754  2555166.0  2018120902:699:14     10.335948               4.058543
# 755  2555540.0  2018120902:699:14     15.836416               8.746987
# 756  2556475.0  2018120902:699:14     10.893971               8.198164
#
#      numberPlayers5ydsAfterPass  areaDifference
# 0                           0.0        44.67445
# 1                           0.8        44.67445
# 2                           0.0        44.67445
# 3                           0.0        44.67445
# 4                           0.0        44.67445
# ..                          ...             ...
# 752                         0.7      -172.00910
# 753                         0.7      -172.00910
# 754                         0.7      -172.00910
# 755                         0.0      -172.00910
# 756                         0.0      -172.00910
#
# [583 rows x 6 columns]

# %%
def calculateNumberDeepPlayers(playId):
    idParts = playId.split(":")
    idWeek = idParts[2]
    week = weeks[int(idWeek)-1]
    
    los = plays.loc[playId]["absoluteYardlineNumber"]
    try:
        fpf_number = week[(week["id"]==playId) & (week["event"]=="pass_forward")]["frameId"].values[0]
    except:
        fpf_number = week[(week["id"]==playId) & (week["event"]=="pass_shovel")]["frameId"].values[0]
        
    defenders = week[(week["team"]==obtainDefenseTeam(playId))&(week["id"]==playId)&(week["frameId"]==fpf_number)]
    playDirection = defenders["playDirection"].values[0]
    deepzone = -1
    
    if playDirection == "right":
        deepzone = los + 15
    elif playDirection == "left":
        deepzone = los - 15
        
    number_players=0
    for index,row in defenders.iterrows():
        if row["position"] in ["DL","NT","DT","DE"]: #muy dificil que pase, pero por si acaso
            continue
        player_x = row["x"]
        if playDirection == "right" and player_x > deepzone:
            number_players+=1
        elif playDirection == "left" and player_x < deepzone:
            number_players+=1
            
    return number_players

# %%
summary["numberPlayersDeep"] = summary["playId"].apply(calculateNumberDeepPlayers)

# %%
def obtainDeepDifference(playerId,playId):
    idParts = playId.split(":")
    idWeek = idParts[2]
    week = weeks[int(idWeek)-1]
    
    deep1 = summary[(summary["playId"]==playId)&(summary["playerId"]==playerId)]["numberPlayersDeep"].values[0]
    deep2 = static_defense.loc[playId]["deepzonePlayers"]
    
    return deep1 - deep2

# %%
summary
# Out:
#       playerId             playId  meanDistance  meanDistanceAfterPass  \
# 0      71251.0  2018093006:2225:4     10.568907              11.791571
# 1      89756.0  2018093006:2225:4     10.946105               4.581272
# 2     494287.0  2018093006:2225:4     31.074778              19.611594
# 3    2533062.0  2018093006:2225:4     22.644911              19.288428
# 4    2541243.0  2018093006:2225:4     24.893454              14.407899
# ..         ...                ...           ...                    ...
# 752  2550164.0  2018120902:699:14      8.330134               4.746337
# 753  2552389.0  2018120902:699:14     17.275020               3.427559
# 754  2555166.0  2018120902:699:14     10.335948               4.058543
# 755  2555540.0  2018120902:699:14     15.836416               8.746987
# 756  2556475.0  2018120902:699:14     10.893971               8.198164
#
#      numberPlayers5ydsAfterPass  areaDifference  numberPlayersDeep  \
# 0                           0.0        44.67445                  5
# 1                           0.8        44.67445                  5
# 2                           0.0        44.67445                  5
# 3                           0.0        44.67445                  5
# 4                           0.0        44.67445                  5
# ..                          ...             ...                ...
# 752                         0.7      -172.00910                  5
# 753                         0.7      -172.00910                  5
# 754                         0.7      -172.00910                  5
# 755                         0.0      -172.00910                  5
# 756                         0.0      -172.00910                  5
#
#      numberPlayersDeepDifference
# 0                      -487.6489
# 1                      -487.6489
# 2                      -487.6489
# 3                      -487.6489
# 4                      -487.6489
# ..                           ...
# 752                    -569.0046
# 753                    -569.0046
# 754                    -569.0046
# 755                    -569.0046
# 756                    -569.0046
#
# [583 rows x 8 columns]

# %%
summary["numberPlayersDeepDifference"] =  summary.apply(lambda x: obtainDeepDifference(x["playerId"],x["playId"]),axis=1)

# %%
summary
# Out:
#       playerId             playId  meanDistance  meanDistanceAfterPass  \
# 0      71251.0  2018093006:2225:4     10.568907              11.791571
# 1      89756.0  2018093006:2225:4     10.946105               4.581272
# 2     494287.0  2018093006:2225:4     31.074778              19.611594
# 3    2533062.0  2018093006:2225:4     22.644911              19.288428
# 4    2541243.0  2018093006:2225:4     24.893454              14.407899
# ..         ...                ...           ...                    ...
# 752  2550164.0  2018120902:699:14      8.330134               4.746337
# 753  2552389.0  2018120902:699:14     17.275020               3.427559
# 754  2555166.0  2018120902:699:14     10.335948               4.058543
# 755  2555540.0  2018120902:699:14     15.836416               8.746987
# 756  2556475.0  2018120902:699:14     10.893971               8.198164
#
#      numberPlayers5ydsAfterPass  areaDifference  numberPlayersDeep  \
# 0                           0.0        44.67445                  5
# 1                           0.8        44.67445                  5
# 2                           0.0        44.67445                  5
# 3                           0.0        44.67445                  5
# 4                           0.0        44.67445                  5
# ..                          ...             ...                ...
# 752                         0.7      -172.00910                  5
# 753                         0.7      -172.00910                  5
# 754                         0.7      -172.00910                  5
# 755                         0.0      -172.00910                  5
# 756                         0.0      -172.00910                  5
#
#      numberPlayersDeepDifference
# 0                              0
# 1                              0
# 2                              0
# 3                              0
# 4                              0
# ..                           ...
# 752                            4
# 753                            4
# 754                            4
# 755                            4
# 756                            4
#
# [583 rows x 8 columns]

# %%
def calculateNumberUnderneath(playId):
    idParts = playId.split(":")
    idWeek = idParts[2]
    week = weeks[int(idWeek)-1]
    
    los = plays.loc[playId]["absoluteYardlineNumber"]
    try:
        fpf_number = week[(week["id"]==playId) & (week["event"]=="pass_forward")]["frameId"].values[0]
    except:
        fpf_number = week[(week["id"]==playId) & (week["event"]=="pass_shovel")]["frameId"].values[0]
        
    defenders = week[(week["team"]==obtainDefenseTeam(playId))&(week["id"]==playId)&(week["frameId"]==fpf_number)]
    playDirection = defenders["playDirection"].values[0]
    deepzone = -1
    
    if playDirection == "right":
        deepzone = los + 15
    elif playDirection == "left":
        deepzone = los - 15
        
    number_players=0
    for index,row in defenders.iterrows():
        if row["position"] in ["DL","NT","DT","DE"]: #muy dificil que pase, pero por si acaso
            continue
        player_x = row["x"]
        if playDirection == "right" and player_x < deepzone and player_x > los:
            number_players+=1
        elif playDirection == "left" and player_x > deepzone and player_x < los:
            number_players+=1
            
    return number_players

# %%
summary["numberPlayersUnderneath"] = summary["playId"].apply(calculateNumberUnderneath)

# %%
summary
# Out:
#       playerId             playId  meanDistance  meanDistanceAfterPass  \
# 0      71251.0  2018093006:2225:4     10.568907              11.791571
# 1      89756.0  2018093006:2225:4     10.946105               4.581272
# 2     494287.0  2018093006:2225:4     31.074778              19.611594
# 3    2533062.0  2018093006:2225:4     22.644911              19.288428
# 4    2541243.0  2018093006:2225:4     24.893454              14.407899
# ..         ...                ...           ...                    ...
# 752  2550164.0  2018120902:699:14      8.330134               4.746337
# 753  2552389.0  2018120902:699:14     17.275020               3.427559
# 754  2555166.0  2018120902:699:14     10.335948               4.058543
# 755  2555540.0  2018120902:699:14     15.836416               8.746987
# 756  2556475.0  2018120902:699:14     10.893971               8.198164
#
#      numberPlayers5ydsAfterPass  areaDifference  numberPlayersDeep  \
# 0                           0.0        44.67445                  5
# 1                           0.8        44.67445                  5
# 2                           0.0        44.67445                  5
# 3                           0.0        44.67445                  5
# 4                           0.0        44.67445                  5
# ..                          ...             ...                ...
# 752                         0.7      -172.00910                  5
# 753                         0.7      -172.00910                  5
# 754                         0.7      -172.00910                  5
# 755                         0.0      -172.00910                  5
# 756                         0.0      -172.00910                  5
#
#      numberPlayersDeepDifference  numberPlayersUnderneath
# 0                              0                        3
# 1                              0                        3
# 2                              0                        3
# 3                              0                        3
# 4                              0                        3
# ..                           ...                      ...
# 752                            4                        2
# 753                            4                        2
# 754                            4                        2
# 755                            4                        2
# 756                            4                        2
#
# [583 rows x 9 columns]

# %%
summary["densityDifference"] = (summary["numberPlayersDeep"] + summary["numberPlayersUnderneath"])/summary["areaDifference"]

# %%
summary
# Out:
#       playerId             playId  meanDistance  meanDistanceAfterPass  \
# 0      71251.0  2018093006:2225:4     10.568907              11.791571
# 1      89756.0  2018093006:2225:4     10.946105               4.581272
# 2     494287.0  2018093006:2225:4     31.074778              19.611594
# 3    2533062.0  2018093006:2225:4     22.644911              19.288428
# 4    2541243.0  2018093006:2225:4     24.893454              14.407899
# ..         ...                ...           ...                    ...
# 752  2550164.0  2018120902:699:14      8.330134               4.746337
# 753  2552389.0  2018120902:699:14     17.275020               3.427559
# 754  2555166.0  2018120902:699:14     10.335948               4.058543
# 755  2555540.0  2018120902:699:14     15.836416               8.746987
# 756  2556475.0  2018120902:699:14     10.893971               8.198164
#
#      numberPlayers5ydsAfterPass  areaDifference  numberPlayersDeep  \
# 0                           0.0        44.67445                  5
# 1                           0.8        44.67445                  5
# 2                           0.0        44.67445                  5
# 3                           0.0        44.67445                  5
# 4                           0.0        44.67445                  5
# ..                          ...             ...                ...
# 752                         0.7      -172.00910                  5
# 753                         0.7      -172.00910                  5
# 754                         0.7      -172.00910                  5
# 755                         0.0      -172.00910                  5
# 756                         0.0      -172.00910                  5
#
#      numberPlayersDeepDifference  numberPlayersUnderneath  densityDifference
# 0                              0                        3           0.179073
# 1                              0                        3           0.179073
# 2                              0                        3           0.179073
# 3                              0                        3           0.179073
# 4                              0                        3           0.179073
# ..                           ...                      ...                ...
# 752                            4                        2          -0.040696
# 753                            4                        2          -0.040696
# 754                            4                        2          -0.040696
# 755                            4                        2          -0.040696
# 756                            4                        2          -0.040696
#
# [583 rows x 10 columns]

# %%
def calculateHeight(playId):
    idParts = playId.split(":")
    idWeek = idParts[2]
    week = weeks[int(idWeek)-1]
    
    try:
        fpf_number = week[(week["id"]==playId) & (week["event"]=="pass_forward")]["frameId"].values[0]
    except:
        fpf_number = week[(week["id"]==playId) & (week["event"]=="pass_shovel")]["frameId"].values[0]
        
    defenders = week[(week["team"]==obtainDefenseTeam(playId))&(week["id"]==playId)&(week["frameId"]==fpf_number)]
    playDirection = defenders["playDirection"].values[0]
    los = plays.loc[playId]["absoluteYardlineNumber"]
    
    players_x = []
    
    for index,row in defenders.iterrows():
        if playDirection == "right" and los < row["x"]:
            players_x.append(row["x"])
        elif playDirection == "left" and los > row["x"]:
            players_x.append(row["x"])
        
    return abs(max(players_x) - min(players_x))

# %%
summary["heightDifference"] = summary["playId"].apply(calculateHeight)

# %%
summary
# Out:
#       playerId             playId  meanDistance  meanDistanceAfterPass  \
# 0      71251.0  2018093006:2225:4     10.568907              11.791571
# 1      89756.0  2018093006:2225:4     10.946105               4.581272
# 2     494287.0  2018093006:2225:4     31.074778              19.611594
# 3    2533062.0  2018093006:2225:4     22.644911              19.288428
# 4    2541243.0  2018093006:2225:4     24.893454              14.407899
# ..         ...                ...           ...                    ...
# 752  2550164.0  2018120902:699:14      8.330134               4.746337
# 753  2552389.0  2018120902:699:14     17.275020               3.427559
# 754  2555166.0  2018120902:699:14     10.335948               4.058543
# 755  2555540.0  2018120902:699:14     15.836416               8.746987
# 756  2556475.0  2018120902:699:14     10.893971               8.198164
#
#      numberPlayers5ydsAfterPass  areaDifference  numberPlayersDeep  \
# 0                           0.0        44.67445                  5
# 1                           0.8        44.67445                  5
# 2                           0.0        44.67445                  5
# 3                           0.0        44.67445                  5
# 4                           0.0        44.67445                  5
# ..                          ...             ...                ...
# 752                         0.7      -172.00910                  5
# 753                         0.7      -172.00910                  5
# 754                         0.7      -172.00910                  5
# 755                         0.0      -172.00910                  5
# 756                         0.0      -172.00910                  5
#
#      numberPlayersDeepDifference  numberPlayersUnderneath  densityDifference  \
# 0                              0                        3           0.179073
# 1                              0                        3           0.179073
# 2                              0                        3           0.179073
# 3                              0                        3           0.179073
# 4                              0                        3           0.179073
# ..                           ...                      ...                ...
# 752                            4                        2          -0.040696
# 753                            4                        2          -0.040696
# 754                            4                        2          -0.040696
# 755                            4                        2          -0.040696
# 756                            4                        2          -0.040696
#
#      heightDifference  widthDifference
# 0               28.77           -41.73
# 1               28.77           -41.73
# 2               28.77           -41.73
# 3               28.77           -41.73
# 4               28.77           -41.73
# ..                ...              ...
# 752             12.11           -55.60
# 753             12.11           -55.60
# 754             12.11           -55.60
# 755             12.11           -55.60
# 756             12.11           -55.60
#
# [583 rows x 12 columns]

# %%
def obtainHeightDifference(playerId,playId):
    idParts = playId.split(":")
    idWeek = idParts[2]
    week = weeks[int(idWeek)-1]
    
    height1 = summary[(summary["playId"]==playId)&(summary["playerId"]==playerId)]["heightDifference"].values[0]
    height2 = static_defense.loc[playId]["height"]
    
    return height1 - height2

# %%
summary["heightDifference"] =  summary.apply(lambda x: obtainHeightDifference(x["playerId"],x["playId"]),axis=1)

# %%
summary
# Out:
#       playerId             playId  meanDistance  meanDistanceAfterPass  \
# 0      71251.0  2018093006:2225:4     10.568907              11.791571
# 1      89756.0  2018093006:2225:4     10.946105               4.581272
# 2     494287.0  2018093006:2225:4     31.074778              19.611594
# 3    2533062.0  2018093006:2225:4     22.644911              19.288428
# 4    2541243.0  2018093006:2225:4     24.893454              14.407899
# ..         ...                ...           ...                    ...
# 752  2550164.0  2018120902:699:14      8.330134               4.746337
# 753  2552389.0  2018120902:699:14     17.275020               3.427559
# 754  2555166.0  2018120902:699:14     10.335948               4.058543
# 755  2555540.0  2018120902:699:14     15.836416               8.746987
# 756  2556475.0  2018120902:699:14     10.893971               8.198164
#
#      numberPlayers5ydsAfterPass  areaDifference  numberPlayersDeep  \
# 0                           0.0        44.67445                  5
# 1                           0.8        44.67445                  5
# 2                           0.0        44.67445                  5
# 3                           0.0        44.67445                  5
# 4                           0.0        44.67445                  5
# ..                          ...             ...                ...
# 752                         0.7      -172.00910                  5
# 753                         0.7      -172.00910                  5
# 754                         0.7      -172.00910                  5
# 755                         0.0      -172.00910                  5
# 756                         0.0      -172.00910                  5
#
#      numberPlayersDeepDifference  numberPlayersUnderneath  densityDifference  \
# 0                              0                        3           0.179073
# 1                              0                        3           0.179073
# 2                              0                        3           0.179073
# 3                              0                        3           0.179073
# 4                              0                        3           0.179073
# ..                           ...                      ...                ...
# 752                            4                        2          -0.040696
# 753                            4                        2          -0.040696
# 754                            4                        2          -0.040696
# 755                            4                        2          -0.040696
# 756                            4                        2          -0.040696
#
#      heightDifference  widthDifference
# 0                5.27           -41.73
# 1                5.27           -41.73
# 2                5.27           -41.73
# 3                5.27           -41.73
# 4                5.27           -41.73
# ..                ...              ...
# 752            -10.46           -55.60
# 753            -10.46           -55.60
# 754            -10.46           -55.60
# 755            -10.46           -55.60
# 756            -10.46           -55.60
#
# [583 rows x 12 columns]

# %%
def calculateWidth(playId):
    idParts = playId.split(":")
    idWeek = idParts[2]
    week = weeks[int(idWeek)-1]
    
    try:
        fpf_number = week[(week["id"]==playId) & (week["event"]=="pass_forward")]["frameId"].values[0]
    except:
        fpf_number = week[(week["id"]==playId) & (week["event"]=="pass_shovel")]["frameId"].values[0]
        
    defenders = week[(week["team"]==obtainDefenseTeam(playId))&(week["id"]==playId)&(week["frameId"]==fpf_number)]
    playDirection = defenders["playDirection"].values[0]
    los = plays.loc[playId]["absoluteYardlineNumber"]
    
    players_y = []
    
    for index,row in defenders.iterrows():
        if playDirection == "right" and los < row["x"]:
            players_y.append(row["y"])
        elif playDirection == "left" and los > row["x"]:
            players_y.append(row["y"])
        
    return max(players_y) - min(players_y)

# %%
summary["widthDifference"] = summary["playId"].apply(calculateWidth)

# %%
summary
# Out:
#       playerId             playId  meanDistance  meanDistanceAfterPass  \
# 0      71251.0  2018093006:2225:4     10.568907              11.791571
# 1      89756.0  2018093006:2225:4     10.946105               4.581272
# 2     494287.0  2018093006:2225:4     31.074778              19.611594
# 3    2533062.0  2018093006:2225:4     22.644911              19.288428
# 4    2541243.0  2018093006:2225:4     24.893454              14.407899
# ..         ...                ...           ...                    ...
# 752  2550164.0  2018120902:699:14      8.330134               4.746337
# 753  2552389.0  2018120902:699:14     17.275020               3.427559
# 754  2555166.0  2018120902:699:14     10.335948               4.058543
# 755  2555540.0  2018120902:699:14     15.836416               8.746987
# 756  2556475.0  2018120902:699:14     10.893971               8.198164
#
#      numberPlayers5ydsAfterPass  areaDifference  numberPlayersDeep  \
# 0                           0.0        44.67445                  5
# 1                           0.8        44.67445                  5
# 2                           0.0        44.67445                  5
# 3                           0.0        44.67445                  5
# 4                           0.0        44.67445                  5
# ..                          ...             ...                ...
# 752                         0.7      -172.00910                  5
# 753                         0.7      -172.00910                  5
# 754                         0.7      -172.00910                  5
# 755                         0.0      -172.00910                  5
# 756                         0.0      -172.00910                  5
#
#      numberPlayersDeepDifference  numberPlayersUnderneath  densityDifference  \
# 0                              0                        3           0.179073
# 1                              0                        3           0.179073
# 2                              0                        3           0.179073
# 3                              0                        3           0.179073
# 4                              0                        3           0.179073
# ..                           ...                      ...                ...
# 752                            4                        2          -0.040696
# 753                            4                        2          -0.040696
# 754                            4                        2          -0.040696
# 755                            4                        2          -0.040696
# 756                            4                        2          -0.040696
#
#      heightDifference  widthDifference
# 0                5.27            32.79
# 1                5.27            32.79
# 2                5.27            32.79
# 3                5.27            32.79
# 4                5.27            32.79
# ..                ...              ...
# 752            -10.46            35.54
# 753            -10.46            35.54
# 754            -10.46            35.54
# 755            -10.46            35.54
# 756            -10.46            35.54
#
# [583 rows x 12 columns]

# %%
def obtainWidthDifference(playerId,playId):
    idParts = playId.split(":")
    idWeek = idParts[2]
    week = weeks[int(idWeek)-1]
    
    width1 = summary[(summary["playId"]==playId)&(summary["playerId"]==playerId)]["widthDifference"].values[0]
    width2 = static_defense.loc[playId]["width"]
    
    return width1 - width2

# %%
summary["widthDifference"] =  summary.apply(lambda x: obtainHeightDifference(x["playerId"],x["playId"]),axis=1)

# %%
summary
# Out:
#       playerId             playId  meanDistance  meanDistanceAfterPass  \
# 0      71251.0  2018093006:2225:4     10.568907              11.791571
# 1      89756.0  2018093006:2225:4     10.946105               4.581272
# 2     494287.0  2018093006:2225:4     31.074778              19.611594
# 3    2533062.0  2018093006:2225:4     22.644911              19.288428
# 4    2541243.0  2018093006:2225:4     24.893454              14.407899
# ..         ...                ...           ...                    ...
# 752  2550164.0  2018120902:699:14      8.330134               4.746337
# 753  2552389.0  2018120902:699:14     17.275020               3.427559
# 754  2555166.0  2018120902:699:14     10.335948               4.058543
# 755  2555540.0  2018120902:699:14     15.836416               8.746987
# 756  2556475.0  2018120902:699:14     10.893971               8.198164
#
#      numberPlayers5ydsAfterPass  areaDifference  numberPlayersDeep  \
# 0                           0.0        44.67445                  5
# 1                           0.8        44.67445                  5
# 2                           0.0        44.67445                  5
# 3                           0.0        44.67445                  5
# 4                           0.0        44.67445                  5
# ..                          ...             ...                ...
# 752                         0.7      -172.00910                  5
# 753                         0.7      -172.00910                  5
# 754                         0.7      -172.00910                  5
# 755                         0.0      -172.00910                  5
# 756                         0.0      -172.00910                  5
#
#      numberPlayersDeepDifference  numberPlayersUnderneath  densityDifference  \
# 0                              0                        3           0.179073
# 1                              0                        3           0.179073
# 2                              0                        3           0.179073
# 3                              0                        3           0.179073
# 4                              0                        3           0.179073
# ..                           ...                      ...                ...
# 752                            4                        2          -0.040696
# 753                            4                        2          -0.040696
# 754                            4                        2          -0.040696
# 755                            4                        2          -0.040696
# 756                            4                        2          -0.040696
#
#      heightDifference  widthDifference
# 0              -18.23           -41.73
# 1              -18.23           -41.73
# 2              -18.23           -41.73
# 3              -18.23           -41.73
# 4              -18.23           -41.73
# ..                ...              ...
# 752            -33.03           -55.60
# 753            -33.03           -55.60
# 754            -33.03           -55.60
# 755            -33.03           -55.60
# 756            -33.03           -55.60
#
# [583 rows x 12 columns]

# %% [markdown]
# # se pueden añadir las características estáticas del comienzo o el cluster.

# %%
clusters = pd.read_csv("../unsupervised_datasets/kmeans/static_defenses_rs_kmeans_without_outliers.csv",index_col="id")
clusters.head()
# Out:
#                   defensivelinezonePlayers  deepzonePlayers  hookzonePlayers  \
# id
# 2018090600:75:1                          0                1                3
# 2018090600:146:1                         0                1                3
# 2018090600:168:1                         0                1                2
# 2018090600:190:1                         1                0                2
# 2018090600:320:1                         1                0                3
#
#                   curlzonePlayers  flatzonePlayers  defenseArea  \
# id
# 2018090600:75:1                 2                1    194.31095
# 2018090600:146:1                2                1    204.17725
# 2018090600:168:1                2                2    277.65495
# 2018090600:190:1                3                1    189.16960
# 2018090600:320:1                3                1    187.12510
#
#                   defenseAreaCoverDefenders  width  height  numberQBs  \
# id
# 2018090600:75:1                   194.31095  22.96   15.25          1
# 2018090600:146:1                  204.17725  29.22   12.57          1
# 2018090600:168:1                  277.65495  33.67   15.21          1
# 2018090600:190:1                  165.05520  26.42   12.91          1
# 2018090600:320:1                  153.20020  27.80   13.29          1
#
#                   numberWRs  numberTEs  numberRBs  numberFBs  \
# id
# 2018090600:75:1           2          1          1          1
# 2018090600:146:1          3          1          1          0
# 2018090600:168:1          2          1          2          0
# 2018090600:190:1          3          1          1          0
# 2018090600:320:1          3          1          1          0
#
#                   numberOffensivePlayersAnotherPosition  numberSafeties  \
# id
# 2018090600:75:1                                       0               3
# 2018090600:146:1                                      0               2
# 2018090600:168:1                                      0               2
# 2018090600:190:1                                      0               3
# 2018090600:320:1                                      0               2
#
#                   numberLBs  numberCBs  strongSide  \
# id
# 2018090600:75:1           2          2           1
# 2018090600:146:1          2          3           0
# 2018090600:168:1          2          3           1
# 2018090600:190:1          1          3           0
# 2018090600:320:1          3          3           1
#
#                   numberPlayersDefenseStrongSide  \
# id
# 2018090600:75:1                                3
# 2018090600:146:1                               3
# 2018090600:168:1                               5
# 2018090600:190:1                               2
# 2018090600:320:1                               3
#
#                   numberPlayersDefenseWeakSide  \
# id
# 2018090600:75:1                              4
# 2018090600:146:1                             4
# 2018090600:168:1                             2
# 2018090600:190:1                             5
# 2018090600:320:1                             5
#
#                   numberPlayersOffenseStrongSide  \
# id
# 2018090600:75:1                                3
# 2018090600:146:1                               2
# 2018090600:168:1                               4
# 2018090600:190:1                               2
# 2018090600:320:1                               3
#
#                   numberPlayersOffenseWeakSide  \
# id
# 2018090600:75:1                              2
# 2018090600:146:1                             3
# 2018090600:168:1                             1
# 2018090600:190:1                             3
# 2018090600:320:1                             2
#
#                   differenceOffenseVsDefenseWidth  \
# id
# 2018090600:75:1                             -0.63
# 2018090600:146:1                            -1.15
# 2018090600:168:1                             0.71
# 2018090600:190:1                            -3.11
# 2018090600:320:1                            -4.82
#
#                   differenceOffenseVsDefenseStrongSide  \
# id
# 2018090600:75:1                                      0
# 2018090600:146:1                                    -1
# 2018090600:168:1                                    -1
# 2018090600:190:1                                     0
# 2018090600:320:1                                     0
#
#                   differenceOffenseVsDefenseWeakSide  HeightByWeightDeep  \
# id
# 2018090600:75:1                                   -2            0.020227
# 2018090600:146:1                                  -1            0.020227
# 2018090600:168:1                                  -1            0.020227
# 2018090600:190:1                                  -2            0.000000
# 2018090600:320:1                                  -3            0.000000
#
#                   HeightByWeightHook  HeightByWeightCurl  HeightByWeightFlat  \
# id
# 2018090600:75:1             0.018643            0.020066            0.021034
# 2018090600:146:1            0.019228            0.020356            0.020455
# 2018090600:168:1            0.017683            0.020997            0.020745
# 2018090600:190:1            0.020120            0.021193            0.020455
# 2018090600:320:1            0.018995            0.019537            0.021279
#
#                   WeightByArea   density  densityNoLine  densityInsidePoints  \
# id
# 2018090600:75:1       3.376032  0.036025       0.036025             6.974268
# 2018090600:146:1      3.178611  0.034284       0.034284             6.975511
# 2018090600:168:1      2.337434  0.025211       0.025211             6.985594
# 2018090600:190:1      3.192871  0.037004       0.036351             6.973569
# 2018090600:320:1      4.281979  0.042752       0.045692             7.978624
#
#                   densityInsidePointsNoLine  cluster
# id
# 2018090600:75:1                    6.974268        0
# 2018090600:146:1                   6.975511        0
# 2018090600:168:1                   6.985594        0
# 2018090600:190:1                   6.969707        0
# 2018090600:320:1                   7.980418        0

# %%
clusters["cluster"].unique()
# Out:
# array([0, 1, 2])

# %%
def obtainCluster(playId):
    idParts = playId.split(":")
    idWeek = idParts[2]
    week = weeks[int(idWeek)-1]
    
    return clusters.loc[playId]["cluster"]

# %%
summary["cluster"] = summary["playId"].apply(obtainCluster)

# %%
summary
# Out:
#       playerId             playId  meanDistance  meanDistanceAfterPass  \
# 0      71251.0  2018093006:2225:4     10.568907              11.791571
# 1      89756.0  2018093006:2225:4     10.946105               4.581272
# 2     494287.0  2018093006:2225:4     31.074778              19.611594
# 3    2533062.0  2018093006:2225:4     22.644911              19.288428
# 4    2541243.0  2018093006:2225:4     24.893454              14.407899
# ..         ...                ...           ...                    ...
# 752  2550164.0  2018120902:699:14      8.330134               4.746337
# 753  2552389.0  2018120902:699:14     17.275020               3.427559
# 754  2555166.0  2018120902:699:14     10.335948               4.058543
# 755  2555540.0  2018120902:699:14     15.836416               8.746987
# 756  2556475.0  2018120902:699:14     10.893971               8.198164
#
#      numberPlayers5ydsAfterPass  areaDifference  numberPlayersDeep  \
# 0                           0.0        44.67445                  5
# 1                           0.8        44.67445                  5
# 2                           0.0        44.67445                  5
# 3                           0.0        44.67445                  5
# 4                           0.0        44.67445                  5
# ..                          ...             ...                ...
# 752                         0.7      -172.00910                  5
# 753                         0.7      -172.00910                  5
# 754                         0.7      -172.00910                  5
# 755                         0.0      -172.00910                  5
# 756                         0.0      -172.00910                  5
#
#      numberPlayersDeepDifference  numberPlayersUnderneath  densityDifference  \
# 0                              0                        3           0.179073
# 1                              0                        3           0.179073
# 2                              0                        3           0.179073
# 3                              0                        3           0.179073
# 4                              0                        3           0.179073
# ..                           ...                      ...                ...
# 752                            4                        2          -0.040696
# 753                            4                        2          -0.040696
# 754                            4                        2          -0.040696
# 755                            4                        2          -0.040696
# 756                            4                        2          -0.040696
#
#      heightDifference  widthDifference  cluster
# 0                5.27           -41.73      2.0
# 1                5.27           -41.73      2.0
# 2                5.27           -41.73      2.0
# 3                5.27           -41.73      2.0
# 4                5.27           -41.73      2.0
# ..                ...              ...      ...
# 752            -10.46           -55.60      0.0
# 753            -10.46           -55.60      0.0
# 754            -10.46           -55.60      0.0
# 755            -10.46           -55.60      0.0
# 756            -10.46           -55.60      0.0
#
# [583 rows x 13 columns]

# %% [markdown]
# # Game context features(g): down, score ...

# %%
def obtainHomeScore(playId):
    idParts = playId.split(":")
    idWeek = idParts[2]
    week = weeks[int(idWeek)-1]
    
    return plays.loc[playId]["preSnapHomeScore"]

# %%
summary["homeScore"] = summary["playId"].apply(obtainHomeScore)

# %%
def obtainVisitorScore(playId):
    idParts = playId.split(":")
    idWeek = idParts[2]
    week = weeks[int(idWeek)-1]
    
    return plays.loc[playId]["preSnapVisitorScore"]

# %%
summary["visitorScore"] = summary["playId"].apply(obtainVisitorScore)

# %%
def obtainDown(playId):
    idParts = playId.split(":")
    idWeek = idParts[2]
    week = weeks[int(idWeek)-1]
    
    return plays.loc[playId]["down"]

# %%
summary["down"] = summary["playId"].apply(obtainDown)

# %%
def obtainQuarter(playId):
    idParts = playId.split(":")
    idWeek = idParts[2]
    week = weeks[int(idWeek)-1]
    
    return plays.loc[playId]["quarter"]

# %%
summary["quarter"] = summary["playId"].apply(obtainQuarter)

# %%
def obtainYardsToGo(playId):
    idParts = playId.split(":")
    idWeek = idParts[2]
    week = weeks[int(idWeek)-1]
    
    return plays.loc[playId]["yardsToGo"]

# %%
summary["yardsToGo"] = summary["playId"].apply(obtainYardsToGo)

# %%
def obtainYardsToEndZone(playId):
    idParts = playId.split(":")
    idWeek = idParts[2]
    week = weeks[int(idWeek)-1]
    absoluteYard = plays.loc[playId]["absoluteYardlineNumber"]
    defense = week[(week["team"]==obtainDefenseTeam(playId))&(week["id"]==playId)]
    direction = defense["playDirection"].values[0]
    
    if direction == "right":
        value = 120 - absoluteYard
    elif direction == "left":
        value = absoluteYard - 10
        
    return value

# %%
summary["yardsToEndZone"] = summary["playId"].apply(obtainYardsToEndZone)

# %%
def obtainGameClock(playId):
    idParts = playId.split(":")
    idWeek = idParts[2]
    week = weeks[int(idWeek)-1]
    
    return plays.loc[playId]["gameClock"]

# %%
summary["gameClock"] = summary["playId"].apply(obtainGameClock)

# %%
summary
# Out:
#       playerId             playId  meanDistance  meanDistanceAfterPass  \
# 0      71251.0  2018093006:2225:4     10.568907              11.791571
# 1      89756.0  2018093006:2225:4     10.946105               4.581272
# 2     494287.0  2018093006:2225:4     31.074778              19.611594
# 3    2533062.0  2018093006:2225:4     22.644911              19.288428
# 4    2541243.0  2018093006:2225:4     24.893454              14.407899
# ..         ...                ...           ...                    ...
# 752  2550164.0  2018120902:699:14      8.330134               4.746337
# 753  2552389.0  2018120902:699:14     17.275020               3.427559
# 754  2555166.0  2018120902:699:14     10.335948               4.058543
# 755  2555540.0  2018120902:699:14     15.836416               8.746987
# 756  2556475.0  2018120902:699:14     10.893971               8.198164
#
#      numberPlayers5ydsAfterPass  areaDifference  numberPlayersDeep  \
# 0                           0.0        44.67445                  5
# 1                           0.8        44.67445                  5
# 2                           0.0        44.67445                  5
# 3                           0.0        44.67445                  5
# 4                           0.0        44.67445                  5
# ..                          ...             ...                ...
# 752                         0.7      -172.00910                  5
# 753                         0.7      -172.00910                  5
# 754                         0.7      -172.00910                  5
# 755                         0.0      -172.00910                  5
# 756                         0.0      -172.00910                  5
#
#      numberPlayersDeepDifference  numberPlayersUnderneath  densityDifference  \
# 0                              0                        3           0.179073
# 1                              0                        3           0.179073
# 2                              0                        3           0.179073
# 3                              0                        3           0.179073
# 4                              0                        3           0.179073
# ..                           ...                      ...                ...
# 752                            4                        2          -0.040696
# 753                            4                        2          -0.040696
# 754                            4                        2          -0.040696
# 755                            4                        2          -0.040696
# 756                            4                        2          -0.040696
#
#      heightDifference  widthDifference  cluster  homeScore  visitorScore  \
# 0                5.27           -41.73      2.0       24.0           0.0
# 1                5.27           -41.73      2.0       24.0           0.0
# 2                5.27           -41.73      2.0       24.0           0.0
# 3                5.27           -41.73      2.0       24.0           0.0
# 4                5.27           -41.73      2.0       24.0           0.0
# ..                ...              ...      ...        ...           ...
# 752            -10.46           -55.60      0.0        7.0           7.0
# 753            -10.46           -55.60      0.0        7.0           7.0
# 754            -10.46           -55.60      0.0        7.0           7.0
# 755            -10.46           -55.60      0.0        7.0           7.0
# 756            -10.46           -55.60      0.0        7.0           7.0
#
#      down  quarter  yardsToGo  yardsToEndZone gameClock
# 0       3        2          1            66.0  00:07:00
# 1       3        2          1            66.0  00:07:00
# 2       3        2          1            66.0  00:07:00
# 3       3        2          1            66.0  00:07:00
# 4       3        2          1            66.0  00:07:00
# ..    ...      ...        ...             ...       ...
# 752     3        1         21            63.0  03:29:00
# 753     3        1         21            63.0  03:29:00
# 754     3        1         21            63.0  03:29:00
# 755     3        1         21            63.0  03:29:00
# 756     3        1         21            63.0  03:29:00
#
# [583 rows x 20 columns]

# %%
#load dataset
pickle_file = open('../resources/summary_2.pickle','rb')
summary_aux = pickle.load(pickle_file)
pickle_file.close()

# %%
summary_aux
# Out:
#       playerId             playId  meanDistance  numberPlayers5yds
# 0      71251.0  2018093006:2225:4     10.568907           0.000000
# 1      89756.0  2018093006:2225:4     10.946105           0.264706
# 2     494287.0  2018093006:2225:4     31.074778           0.000000
# 3    2533062.0  2018093006:2225:4     22.644911           0.000000
# 4    2541243.0  2018093006:2225:4     24.893454           0.000000
# ..         ...                ...           ...                ...
# 752  2550164.0  2018120902:699:14      8.330134           0.148148
# 753  2552389.0  2018120902:699:14     17.275020           0.000000
# 754  2555166.0  2018120902:699:14     10.335948           0.000000
# 755  2555540.0  2018120902:699:14     15.836416           0.000000
# 756  2556475.0  2018120902:699:14     10.893971           0.000000
#
# [756 rows x 4 columns]

# %%
summary_aux.drop(summary_aux[summary_aux["playId"].isin(dif)].index,inplace=True)

# %%
summary_aux
# Out:
#       playerId             playId  meanDistance  numberPlayers5yds
# 0      71251.0  2018093006:2225:4     10.568907           0.000000
# 1      89756.0  2018093006:2225:4     10.946105           0.264706
# 2     494287.0  2018093006:2225:4     31.074778           0.000000
# 3    2533062.0  2018093006:2225:4     22.644911           0.000000
# 4    2541243.0  2018093006:2225:4     24.893454           0.000000
# ..         ...                ...           ...                ...
# 752  2550164.0  2018120902:699:14      8.330134           0.148148
# 753  2552389.0  2018120902:699:14     17.275020           0.000000
# 754  2555166.0  2018120902:699:14     10.335948           0.000000
# 755  2555540.0  2018120902:699:14     15.836416           0.000000
# 756  2556475.0  2018120902:699:14     10.893971           0.000000
#
# [583 rows x 4 columns]

# %%
summary["numberPlayers5yds"] = summary_aux["numberPlayers5yds"]

# %%
summary.columns
# Out:
# Index(['playerId', 'playId', 'meanDistance', 'meanDistanceAfterPass',
#        'numberPlayers5ydsAfterPass', 'areaDifference', 'numberPlayersDeep',
#        'numberPlayersDeepDifference', 'numberPlayersUnderneath',
#        'densityDifference', 'heightDifference', 'widthDifference', 'cluster',
#        'homeScore', 'visitorScore', 'down', 'quarter', 'yardsToGo',
#        'yardsToEndZone', 'gameClock', 'numberPlayers5yds'],
#       dtype='object')

# %%
summary = summary.reindex(columns=['playerId','playId','meanDistance','meanDistanceAfterPass','numberPlayers5yds','numberPlayers5ydsAfterPass', 'areaDifference', 'numberPlayersDeep',
       'numberPlayersDeepDifference', 'numberPlayersUnderneath',
       'densityDifference', 'heightDifference', 'widthDifference', 'cluster',
       'homeScore', 'visitorScore', 'down', 'quarter', 'yardsToGo',
       'yardsToEndZone', 'gameClock'])

# %%
summary.to_csv("summary.csv")

# %%
df = pd.read_csv("single_summary_20180905_313_1.csv",index_col=0)
df
# Out:
#                    playerId  meanDistance  meanDistanceAfterPass  \
# id
# 2018090905:313:1    71251.0      1.949711               2.831581
# 2018090905:313:1   494287.0     13.515905              16.519959
# 2018090905:313:1  2533057.0      2.793890               2.652474
# 2018090905:313:1  2533062.0      3.299615               1.724586
# 2018090905:313:1  2541243.0      8.609330               5.575882
# 2018090905:313:1  2543699.0     13.628398              17.829817
# 2018090905:313:1  2552255.0      2.598084               2.634874
# 2018090905:313:1  2561143.0      2.976865               0.422223
#
#                   numberPlayers5yds  numberPlayers5ydsAfterPass  \
# id
# 2018090905:313:1           1.754386                         1.0
# 2018090905:313:1           0.000000                         0.0
# 2018090905:313:1           0.859649                         1.0
# 2018090905:313:1           1.000000                         1.0
# 2018090905:313:1           0.228070                         0.0
# 2018090905:313:1           0.333333                         0.0
# 2018090905:313:1           0.824561                         1.0
# 2018090905:313:1           0.754386                         1.0
#
#                   areaDifference  numberPlayersDeep  \
# id
# 2018090905:313:1        224.9914                  3
# 2018090905:313:1        224.9914                  3
# 2018090905:313:1        224.9914                  3
# 2018090905:313:1        224.9914                  3
# 2018090905:313:1        224.9914                  3
# 2018090905:313:1        224.9914                  3
# 2018090905:313:1        224.9914                  3
# 2018090905:313:1        224.9914                  3
#
#                   numberPlayersDeepDifference  numberPlayersUnderneath  \
# id
# 2018090905:313:1                            3                        4
# 2018090905:313:1                            3                        4
# 2018090905:313:1                            3                        4
# 2018090905:313:1                            3                        4
# 2018090905:313:1                            3                        4
# 2018090905:313:1                            3                        4
# 2018090905:313:1                            3                        4
# 2018090905:313:1                            3                        4
#
#                   densityDifference  heightDifference  widthDifference  \
# id
# 2018090905:313:1           0.031112              3.18            14.08
# 2018090905:313:1           0.031112              3.18            14.08
# 2018090905:313:1           0.031112              3.18            14.08
# 2018090905:313:1           0.031112              3.18            14.08
# 2018090905:313:1           0.031112              3.18            14.08
# 2018090905:313:1           0.031112              3.18            14.08
# 2018090905:313:1           0.031112              3.18            14.08
# 2018090905:313:1           0.031112              3.18            14.08
#
#                   cluster  homeScore  visitorScore  down  quarter  yardsToGo  \
# id
# 2018090905:313:1      0.0        7.0           0.0     2        1          9
# 2018090905:313:1      0.0        7.0           0.0     2        1          9
# 2018090905:313:1      0.0        7.0           0.0     2        1          9
# 2018090905:313:1      0.0        7.0           0.0     2        1          9
# 2018090905:313:1      0.0        7.0           0.0     2        1          9
# 2018090905:313:1      0.0        7.0           0.0     2        1          9
# 2018090905:313:1      0.0        7.0           0.0     2        1          9
# 2018090905:313:1      0.0        7.0           0.0     2        1          9
#
#                   yardsToEndZone gameClock
# id
# 2018090905:313:1            72.0  11:07:00
# 2018090905:313:1            72.0  11:07:00
# 2018090905:313:1            72.0  11:07:00
# 2018090905:313:1            72.0  11:07:00
# 2018090905:313:1            72.0  11:07:00
# 2018090905:313:1            72.0  11:07:00
# 2018090905:313:1            72.0  11:07:00
# 2018090905:313:1            72.0  11:07:00

# %% [markdown]
# Tres etiquetas:
# - mala: no ha defendido bien
# - buena: ha defendido bien en toda la jugada
# - regular: ha defendido bien un tramo pero ha perdido la marca

# %%
valorations = ["regular","regular","regular","buena","mala","mala","mala","buena"] #para mi el mejor es Ja'Whaun Bentley

# %%
df["subjective_evaluation"] = valorations

# %%
df
# Out:
#                    playerId  meanDistance  meanDistanceAfterPass  \
# id
# 2018090905:313:1    71251.0      1.949711               2.831581
# 2018090905:313:1   494287.0     13.515905              16.519959
# 2018090905:313:1  2533057.0      2.793890               2.652474
# 2018090905:313:1  2533062.0      3.299615               1.724586
# 2018090905:313:1  2541243.0      8.609330               5.575882
# 2018090905:313:1  2543699.0     13.628398              17.829817
# 2018090905:313:1  2552255.0      2.598084               2.634874
# 2018090905:313:1  2561143.0      2.976865               0.422223
#
#                   numberPlayers5yds  numberPlayers5ydsAfterPass  \
# id
# 2018090905:313:1           1.754386                         1.0
# 2018090905:313:1           0.000000                         0.0
# 2018090905:313:1           0.859649                         1.0
# 2018090905:313:1           1.000000                         1.0
# 2018090905:313:1           0.228070                         0.0
# 2018090905:313:1           0.333333                         0.0
# 2018090905:313:1           0.824561                         1.0
# 2018090905:313:1           0.754386                         1.0
#
#                   areaDifference  numberPlayersDeep  \
# id
# 2018090905:313:1        224.9914                  3
# 2018090905:313:1        224.9914                  3
# 2018090905:313:1        224.9914                  3
# 2018090905:313:1        224.9914                  3
# 2018090905:313:1        224.9914                  3
# 2018090905:313:1        224.9914                  3
# 2018090905:313:1        224.9914                  3
# 2018090905:313:1        224.9914                  3
#
#                   numberPlayersDeepDifference  numberPlayersUnderneath  \
# id
# 2018090905:313:1                            3                        4
# 2018090905:313:1                            3                        4
# 2018090905:313:1                            3                        4
# 2018090905:313:1                            3                        4
# 2018090905:313:1                            3                        4
# 2018090905:313:1                            3                        4
# 2018090905:313:1                            3                        4
# 2018090905:313:1                            3                        4
#
#                   densityDifference  ...  widthDifference  cluster  homeScore  \
# id                                   ...
# 2018090905:313:1           0.031112  ...            14.08      0.0        7.0
# 2018090905:313:1           0.031112  ...            14.08      0.0        7.0
# 2018090905:313:1           0.031112  ...            14.08      0.0        7.0
# 2018090905:313:1           0.031112  ...            14.08      0.0        7.0
# 2018090905:313:1           0.031112  ...            14.08      0.0        7.0
# 2018090905:313:1           0.031112  ...            14.08      0.0        7.0
# 2018090905:313:1           0.031112  ...            14.08      0.0        7.0
# 2018090905:313:1           0.031112  ...            14.08      0.0        7.0
#
#                   visitorScore  down  quarter  yardsToGo  yardsToEndZone  \
# id
# 2018090905:313:1           0.0     2        1          9            72.0
# 2018090905:313:1           0.0     2        1          9            72.0
# 2018090905:313:1           0.0     2        1          9            72.0
# 2018090905:313:1           0.0     2        1          9            72.0
# 2018090905:313:1           0.0     2        1          9            72.0
# 2018090905:313:1           0.0     2        1          9            72.0
# 2018090905:313:1           0.0     2        1          9            72.0
# 2018090905:313:1           0.0     2        1          9            72.0
#
#                   gameClock subjective_evaluation
# id
# 2018090905:313:1   11:07:00               regular
# 2018090905:313:1   11:07:00               regular
# 2018090905:313:1   11:07:00               regular
# 2018090905:313:1   11:07:00                 buena
# 2018090905:313:1   11:07:00                  mala
# 2018090905:313:1   11:07:00                  mala
# 2018090905:313:1   11:07:00                  mala
# 2018090905:313:1   11:07:00                 buena
#
# [8 rows x 21 columns]
