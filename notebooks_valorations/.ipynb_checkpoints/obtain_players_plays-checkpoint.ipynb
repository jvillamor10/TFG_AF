# %%
import pandas as pd
import pickle

# %%
pd.set_option('display.max_columns',None)

# %%
week1 = pd.read_csv("../processed_data/clean_without_pass_rushers/week1.csv")
week2 = pd.read_csv("../processed_data/clean_without_pass_rushers/week2.csv")
week3 = pd.read_csv("../processed_data/clean_without_pass_rushers/week3.csv")
week4 = pd.read_csv("../processed_data/clean_without_pass_rushers/week4.csv")
week5 = pd.read_csv("../processed_data/clean_without_pass_rushers/week5.csv")
week6 = pd.read_csv("../processed_data/clean_without_pass_rushers/week6.csv")
week7 = pd.read_csv("../processed_data/clean_without_pass_rushers/week7.csv")
week8 = pd.read_csv("../processed_data/clean_without_pass_rushers/week8.csv")
week9 = pd.read_csv("../processed_data/clean_without_pass_rushers/week9.csv")
week10 = pd.read_csv("../processed_data/clean_without_pass_rushers/week10.csv")
week11 = pd.read_csv("../processed_data/clean_without_pass_rushers/week11.csv")
week12 = pd.read_csv("../processed_data/clean_without_pass_rushers/week12.csv")
week13 = pd.read_csv("../processed_data/clean_without_pass_rushers/week13.csv")
week14 = pd.read_csv("../processed_data/clean_without_pass_rushers/week14.csv")
week15 = pd.read_csv("../processed_data/clean_without_pass_rushers/week15.csv")
week16 = pd.read_csv("../processed_data/clean_without_pass_rushers/week16.csv")
week17 = pd.read_csv("../processed_data/clean_without_pass_rushers/week17.csv")
week1.head()
# Out:
#    Unnamed: 0               id                      time      x      y     s  \
# 0           0  2018090600:75:1  2018-09-07T01:07:14.599Z  91.73  26.67  0.00
# 1           1  2018090600:75:1  2018-09-07T01:07:14.599Z  88.89  36.47  0.01
# 2           2  2018090600:75:1  2018-09-07T01:07:14.599Z  91.35  44.16  0.02
# 3           3  2018090600:75:1  2018-09-07T01:07:14.599Z  86.31  22.01  0.09
# 4           4  2018090600:75:1  2018-09-07T01:07:14.599Z  90.78  36.15  0.00
#
#       a   dis       o     dir event      nflId      displayName  jerseyNumber  \
# 0  0.01  0.02  289.57  240.93  None      310.0        Matt Ryan           2.0
# 1  0.01  0.01  105.63   66.66  None    79848.0  Malcolm Jenkins          27.0
# 2  0.03  0.01  290.45   16.86  None  2495454.0      Julio Jones          11.0
# 3  0.42  0.01   70.12  168.91  None  2495613.0     Corey Graham          24.0
# 4  0.00  0.00  257.61  193.97  None  2533040.0     Mohamed Sanu          12.0
#
#   position  frameId  team playDirection  route
# 0       QB        1  away          left    NaN
# 1       SS        1  home          left    NaN
# 2       WR        1  away          left  HITCH
# 3       FS        1  home          left    NaN
# 4       WR        1  away          left  HITCH

# %%
weeks = [week1,week2,week3,week4,week5,week6,week7,week8,week9,week10,week11,week12,week13,week14,week15,week16,week17]

# %%
for week in weeks:
    week.drop(["Unnamed: 0"],axis=1,inplace=True)

# %%
plays = pd.read_csv("../processed_data/clean/plays.csv",index_col=0)
plays.head()
# Out:
#                  id                                    playDescription  \
# 0   2018090600:75:1  (15:00) M.Ryan pass short right to J.Jones pus...
# 1  2018090600:146:1  (13:10) M.Ryan pass incomplete short right to ...
# 2  2018090600:168:1  (13:05) (Shotgun) M.Ryan pass incomplete short...
# 3  2018090600:190:1  (13:01) (Shotgun) M.Ryan pass deep left to J.J...
# 4  2018090600:256:1  (10:59) (Shotgun) M.Ryan pass incomplete short...
#
#    quarter  down  yardsToGo possessionTeam        playType yardlineSide  \
# 0        1     1         15            ATL  play_type_pass          ATL
# 1        1     1         10            ATL  play_type_pass          PHI
# 2        1     2         10            ATL  play_type_pass          PHI
# 3        1     3         10            ATL  play_type_pass          PHI
# 4        1     3          1            ATL  play_type_pass          PHI
#
#    yardlineNumber offenseFormation        personnelO  defendersInTheBox  \
# 0              20           I_FORM  2 RB, 1 TE, 2 WR                7.0
# 1              39       SINGLEBACK  1 RB, 1 TE, 3 WR                7.0
# 2              39          SHOTGUN  2 RB, 1 TE, 2 WR                6.0
# 3              39          SHOTGUN  1 RB, 1 TE, 3 WR                6.0
# 4               1          SHOTGUN  2 RB, 3 TE, 0 WR                8.0
#
#    numberOfPassRushers        personnelD  preSnapVisitorScore  \
# 0                  4.0  4 DL, 2 LB, 5 DB                  0.0
# 1                  4.0  4 DL, 2 LB, 5 DB                  0.0
# 2                  4.0  4 DL, 2 LB, 5 DB                  0.0
# 3                  5.0  4 DL, 1 LB, 6 DB                  0.0
# 4                  6.0  6 DL, 3 LB, 2 DB                  0.0
#
#    preSnapHomeScore gameClock  absoluteYardlineNumber penaltyCodes  \
# 0               0.0  15:00:00                    90.0          NaN
# 1               0.0  13:10:00                    49.0          NaN
# 2               0.0  13:05:00                    49.0          NaN
# 3               0.0  13:01:00                    49.0          NaN
# 4               0.0  10:59:00                    11.0          NaN
#
#   penaltyJerseyNumbers passResult  offensePlayResult  playResult       epa  \
# 0                  NaN          C                 10          10  0.261827
# 1                  NaN          I                  0           0 -0.372360
# 2                  NaN          I                  0           0 -0.702779
# 3                  NaN          C                 33          33  3.047530
# 4                  NaN          I                  0           0 -0.842272
#
#    isDefensivePI
# 0          False
# 1          False
# 2          False
# 3          False
# 4          False

# %%
players = pd.read_csv("../processed_data/clean/players.csv",index_col=0)
players.head()
# Out:
#          height  weight   birthDate             collegeName position  \
# nflId
# 2539334    1.83      86  1990-09-10              Washington       CB
# 2539653    1.78      84  1988-11-01  Southeastern Louisiana       CB
# 2543850    1.75      84  1991-12-18                  Purdue       SS
# 2555162    1.85     103  1994-11-04         Louisiana State      MLB
# 2555255    1.91     105  1993-07-01               Minnesota      OLB
#
#                 displayName
# nflId
# 2539334     Desmond Trufant
# 2539653       Robert Alford
# 2543850       Ricardo Allen
# 2555162         Deion Jones
# 2555255  De'Vondre Campbell

# %%
games = pd.read_csv("../raw_data/games.csv",index_col=0)
games.head()
# Out:
#               gameDate gameTimeEastern homeTeamAbbr visitorTeamAbbr  week
# gameId
# 2018090600  09/06/2018        20:20:00          PHI             ATL     1
# 2018090901  09/09/2018        13:00:00          CLE             PIT     1
# 2018090902  09/09/2018        13:00:00          IND             CIN     1
# 2018090903  09/09/2018        13:00:00          MIA             TEN     1
# 2018090900  09/09/2018        13:00:00          BAL             BUF     1

# %%
static_defense = pd.read_csv("../transformed_data/static_defenses_yards.csv",index_col=0)
static_defense.head()
# Out:
#                  id  defensivelinezonePlayers  deepzonePlayers  \
# 0   2018090600:75:1                         0                1
# 1  2018090600:146:1                         0                1
# 2  2018090600:168:1                         0                1
# 3  2018090600:190:1                         1                0
# 5  2018090600:320:1                         1                0
#
#    hookzonePlayers  curlzonePlayers  flatzonePlayers  defenseArea  \
# 0                3                2                1    194.31095
# 1                3                2                1    204.17725
# 2                2                2                2    277.65495
# 3                2                3                1    189.16960
# 5                3                3                1    187.12510
#
#    defenseAreaCoverDefenders  width  height  numberQBs  numberWRs  numberTEs  \
# 0                  194.31095  22.96   15.25          1          2          1
# 1                  204.17725  29.22   12.57          1          3          1
# 2                  277.65495  33.67   15.21          1          2          1
# 3                  165.05520  26.42   12.91          1          3          1
# 5                  153.20020  27.80   13.29          1          3          1
#
#    numberRBs  numberFBs  numberOffensivePlayersAnotherPosition  \
# 0          1          1                                      0
# 1          1          0                                      0
# 2          2          0                                      0
# 3          1          0                                      0
# 5          1          0                                      0
#
#    numberSafeties  numberLBs  numberCBs strongSide  \
# 0               3          2          2       left
# 1               2          2          3      right
# 2               2          2          3       left
# 3               3          1          3      right
# 5               2          3          3       left
#
#    numberPlayersDefenseStrongSide  numberPlayersDefenseWeakSide  \
# 0                               3                             4
# 1                               3                             4
# 2                               5                             2
# 3                               2                             5
# 5                               3                             5
#
#    numberPlayersOffenseStrongSide  numberPlayersOffenseWeakSide  \
# 0                               3                             2
# 1                               2                             3
# 2                               4                             1
# 3                               2                             3
# 5                               3                             2
#
#    differenceOffenseVsDefenseWidth  differenceOffenseVsDefenseStrongSide  \
# 0                            -0.63                                     0
# 1                            -1.15                                    -1
# 2                             0.71                                    -1
# 3                            -3.11                                     0
# 5                            -4.82                                     0
#
#    differenceOffenseVsDefenseWeakSide  HeightByWeightDeep  HeightByWeightHook  \
# 0                                  -2            0.020227            0.018643
# 1                                  -1            0.020227            0.019228
# 2                                  -1            0.020227            0.017683
# 3                                  -2            0.000000            0.020120
# 5                                  -3            0.000000            0.018995
#
#    HeightByWeightCurl  HeightByWeightFlat  WeightByArea   density  \
# 0            0.020066            0.021034      3.376032  0.036025
# 1            0.020356            0.020455      3.178611  0.034284
# 2            0.020997            0.020745      2.337434  0.025211
# 3            0.021193            0.020455      3.192871  0.037004
# 5            0.019537            0.021279      4.281979  0.042752
#
#    densityNoLine  densityInsidePoints  densityInsidePointsNoLine  playResult
# 0       0.036025             6.974268                   6.974268          10
# 1       0.034284             6.975511                   6.975511           0
# 2       0.025211             6.985594                   6.985594           0
# 3       0.036351             6.973569                   6.969707          33
# 5       0.045692             7.978624                   7.980418           4

# %%
plays = plays[plays["id"].isin(static_defense["id"])]
plays
# Out:
#                        id                                    playDescription  \
# 0         2018090600:75:1  (15:00) M.Ryan pass short right to J.Jones pus...
# 1        2018090600:146:1  (13:10) M.Ryan pass incomplete short right to ...
# 2        2018090600:168:1  (13:05) (Shotgun) M.Ryan pass incomplete short...
# 3        2018090600:190:1  (13:01) (Shotgun) M.Ryan pass deep left to J.J...
# 5        2018090600:320:1  (10:10) (Shotgun) N.Foles pass short left to N...
# ...                   ...                                                ...
# 19112  2018123015:3819:17  (5:42) J.Rosen pass short middle to C.Williams...
# 19113  2018123015:3932:17  (2:27) (Shotgun) J.Rosen sacked at SEA 37 for ...
# 19114  2018123015:3969:17  (2:00) (Shotgun) J.Rosen pass incomplete deep ...
# 19115  2018123015:4057:17  (1:29) (No Huddle, Shotgun) R.Wilson pass shor...
# 19116  2018123015:4104:17  (1:02) (No Huddle, Shotgun) R.Wilson pass deep...
#
#        quarter  down  yardsToGo possessionTeam        playType yardlineSide  \
# 0            1     1         15            ATL  play_type_pass          ATL
# 1            1     1         10            ATL  play_type_pass          PHI
# 2            1     2         10            ATL  play_type_pass          PHI
# 3            1     3         10            ATL  play_type_pass          PHI
# 5            1     2          8            PHI  play_type_pass          PHI
# ...        ...   ...        ...            ...             ...          ...
# 19112        4     1         10            ARI  play_type_pass          ARI
# 19113        4     2          9            ARI  play_type_sack          SEA
# 19114        4     3         12            ARI  play_type_pass          SEA
# 19115        4     2          6            SEA  play_type_pass          SEA
# 19116        4     1         10            SEA  play_type_pass          SEA
#
#        yardlineNumber offenseFormation        personnelO  defendersInTheBox  \
# 0                  20           I_FORM  2 RB, 1 TE, 2 WR                7.0
# 1                  39       SINGLEBACK  1 RB, 1 TE, 3 WR                7.0
# 2                  39          SHOTGUN  2 RB, 1 TE, 2 WR                6.0
# 3                  39          SHOTGUN  1 RB, 1 TE, 3 WR                6.0
# 5                   4          SHOTGUN  1 RB, 1 TE, 3 WR                7.0
# ...               ...              ...               ...                ...
# 19112              43       SINGLEBACK  1 RB, 2 TE, 2 WR                7.0
# 19113              34          SHOTGUN  1 RB, 1 TE, 3 WR                6.0
# 19114              37          SHOTGUN  1 RB, 1 TE, 3 WR                5.0
# 19115              29          SHOTGUN  1 RB, 1 TE, 3 WR                7.0
# 19116              38          SHOTGUN  1 RB, 1 TE, 3 WR                7.0
#
#        numberOfPassRushers        personnelD  preSnapVisitorScore  \
# 0                      4.0  4 DL, 2 LB, 5 DB                  0.0
# 1                      4.0  4 DL, 2 LB, 5 DB                  0.0
# 2                      4.0  4 DL, 2 LB, 5 DB                  0.0
# 3                      5.0  4 DL, 1 LB, 6 DB                  0.0
# 5                      4.0  3 DL, 3 LB, 5 DB                  0.0
# ...                    ...               ...                  ...
# 19112                  4.0  4 DL, 3 LB, 4 DB                 21.0
# 19113                  4.0  4 DL, 2 LB, 5 DB                 21.0
# 19114                  4.0  4 DL, 1 LB, 6 DB                 21.0
# 19115                  5.0  4 DL, 2 LB, 5 DB                 24.0
# 19116                  5.0  4 DL, 2 LB, 5 DB                 24.0
#
#        preSnapHomeScore gameClock  absoluteYardlineNumber penaltyCodes  \
# 0                   0.0  15:00:00                    90.0          NaN
# 1                   0.0  13:10:00                    49.0          NaN
# 2                   0.0  13:05:00                    49.0          NaN
# 3                   0.0  13:01:00                    49.0          NaN
# 5                   0.0  10:10:00                    14.0          NaN
# ...                 ...       ...                     ...          ...
# 19112              24.0  05:42:00                    67.0          NaN
# 19113              24.0  02:27:00                    44.0          NaN
# 19114              24.0  02:00:00                    47.0          NaN
# 19115              24.0  01:29:00                    39.0          NaN
# 19116              24.0  01:02:00                    48.0          NaN
#
#       penaltyJerseyNumbers passResult  offensePlayResult  playResult  \
# 0                      NaN          C                 10          10
# 1                      NaN          I                  0           0
# 2                      NaN          I                  0           0
# 3                      NaN          C                 33          33
# 5                      NaN          C                  4           4
# ...                    ...        ...                ...         ...
# 19112                  NaN          C                 12          12
# 19113                  NaN          S                 -3          -3
# 19114                  NaN          I                  0           0
# 19115                  NaN          C                  5           5
# 19116                  NaN          C                 37          37
#
#             epa  isDefensivePI
# 0      0.261827          False
# 1     -0.372360          False
# 2     -0.702779          False
# 3      3.047530          False
# 5     -0.344096          False
# ...         ...            ...
# 19112  0.732852          False
# 19113 -0.750672          False
# 19114 -0.944168          False
# 19115 -0.254137          False
# 19116  1.827072          False
#
# [16498 rows x 25 columns]

# %%
third_down_plays = plays[(plays["down"]==3)&(plays["passResult"]!="S")]
third_down_plays
# Out:
#                        id                                    playDescription  \
# 3        2018090600:190:1  (13:01) (Shotgun) M.Ryan pass deep left to J.J...
# 6        2018090600:344:1  (9:24) (Shotgun) N.Foles pass incomplete short...
# 16       2018090600:949:1  (15:00) (Shotgun) M.Ryan pass short left to D....
# 18      2018090600:1037:1  (12:53) (Shotgun) N.Foles pass short left to N...
# 34      2018090600:1801:1  (1:35) (Shotgun) N.Foles pass incomplete short...
# ...                   ...                                                ...
# 19090  2018123015:2373:17  (11:58) (Shotgun) J.Rosen pass incomplete shor...
# 19096  2018123015:2629:17  (7:43) (Shotgun) J.Rosen pass incomplete deep ...
# 19101  2018123015:2998:17  (4:17) (Shotgun) J.Rosen pass short middle to ...
# 19104  2018123015:3180:17  (:24) (Shotgun) R.Wilson pass incomplete short...
# 19114  2018123015:3969:17  (2:00) (Shotgun) J.Rosen pass incomplete deep ...
#
#        quarter  down  yardsToGo possessionTeam        playType yardlineSide  \
# 3            1     3         10            ATL  play_type_pass          PHI
# 6            1     3          4            PHI  play_type_pass          PHI
# 16           2     3         12            ATL  play_type_pass          ATL
# 18           2     3          7            PHI  play_type_pass          PHI
# 34           2     3          3            PHI  play_type_pass          PHI
# ...        ...   ...        ...            ...             ...          ...
# 19090        3     3          2            ARI  play_type_pass          ARI
# 19096        3     3         13            ARI  play_type_pass          SEA
# 19101        3     3         10            ARI  play_type_pass          ARI
# 19104        3     3          5            SEA  play_type_pass          SEA
# 19114        4     3         12            ARI  play_type_pass          SEA
#
#        yardlineNumber offenseFormation        personnelO  defendersInTheBox  \
# 3                  39          SHOTGUN  1 RB, 1 TE, 3 WR                6.0
# 6                   8            EMPTY  1 RB, 2 TE, 2 WR                6.0
# 16                 18          SHOTGUN  1 RB, 1 TE, 3 WR                4.0
# 18                 43          SHOTGUN  1 RB, 1 TE, 3 WR                6.0
# 34                 36          SHOTGUN  1 RB, 1 TE, 3 WR                7.0
# ...               ...              ...               ...                ...
# 19090              27            EMPTY  1 RB, 1 TE, 3 WR                5.0
# 19096              48          SHOTGUN  1 RB, 1 TE, 3 WR                4.0
# 19101              30          SHOTGUN  1 RB, 1 TE, 3 WR                5.0
# 19104              25            EMPTY  1 RB, 1 TE, 3 WR                7.0
# 19114              37          SHOTGUN  1 RB, 1 TE, 3 WR                5.0
#
#        numberOfPassRushers        personnelD  preSnapVisitorScore  \
# 3                      5.0  4 DL, 1 LB, 6 DB                  0.0
# 6                      4.0  3 DL, 3 LB, 5 DB                  0.0
# 16                     4.0  4 DL, 1 LB, 6 DB                  3.0
# 18                     5.0  4 DL, 2 LB, 5 DB                  3.0
# 34                     4.0  4 DL, 2 LB, 5 DB                  6.0
# ...                    ...               ...                  ...
# 19090                  4.0  4 DL, 2 LB, 5 DB                 13.0
# 19096                  4.0  4 DL, 1 LB, 6 DB                 13.0
# 19101                  4.0  4 DL, 1 LB, 6 DB                 13.0
# 19104                  5.0  4 DL, 2 LB, 5 DB                 13.0
# 19114                  4.0  4 DL, 1 LB, 6 DB                 21.0
#
#        preSnapHomeScore gameClock  absoluteYardlineNumber penaltyCodes  \
# 3                   0.0  13:01:00                    49.0          NaN
# 6                   0.0  09:24:00                    18.0          NaN
# 16                  0.0  15:00:00                    28.0          NaN
# 18                  0.0  12:53:00                    67.0          NaN
# 34                  3.0  01:35:00                    74.0          NaN
# ...                 ...       ...                     ...          ...
# 19090              14.0  11:58:00                    37.0          NaN
# 19096              14.0  07:43:00                    62.0          NaN
# 19101              21.0  04:17:00                    40.0          NaN
# 19104              21.0  00:24:00                    85.0          NaN
# 19114              24.0  02:00:00                    47.0          NaN
#
#       penaltyJerseyNumbers passResult  offensePlayResult  playResult  \
# 3                      NaN          C                 33          33
# 6                      NaN          I                  0           0
# 16                     NaN          C                 -7          -7
# 18                     NaN          C                 10          10
# 34                     NaN          I                  0           0
# ...                    ...        ...                ...         ...
# 19090                  NaN          I                  0           0
# 19096                  NaN          I                  0           0
# 19101                  NaN          C                  9           9
# 19104                  NaN          I                  0           0
# 19114                  NaN          I                  0           0
#
#             epa  isDefensivePI
# 3      3.047530          False
# 6     -1.192208          False
# 16    -1.912483          False
# 18     2.044063          False
# 34    -0.782217          False
# ...         ...            ...
# 19090 -1.659557          False
# 19096 -1.748119          False
# 19101 -1.153889          False
# 19104 -1.617042          False
# 19114 -0.944168          False
#
# [3851 rows x 25 columns]

# %%
plays = plays.set_index("id")

# %%
third_down_plays = third_down_plays.set_index("id")

# %%
def evaluateDefense(playId):
    yardsToGo = third_down_plays.loc[playId]["yardsToGo"]
    offensePlayResult = third_down_plays.loc[playId]["offensePlayResult"]
    
    if offensePlayResult < yardsToGo:
        value = 1   #defensa exitosa
    else:
        value = 0   #mala defensa
        
    return value

# %%
third_down_plays["defenseValoration"] = third_down_plays.index.map(evaluateDefense)
third_down_plays.head()
# Out:
#                                                      playDescription  quarter  \
# id
# 2018090600:190:1   (13:01) (Shotgun) M.Ryan pass deep left to J.J...        1
# 2018090600:344:1   (9:24) (Shotgun) N.Foles pass incomplete short...        1
# 2018090600:949:1   (15:00) (Shotgun) M.Ryan pass short left to D....        2
# 2018090600:1037:1  (12:53) (Shotgun) N.Foles pass short left to N...        2
# 2018090600:1801:1  (1:35) (Shotgun) N.Foles pass incomplete short...        2
#
#                    down  yardsToGo possessionTeam        playType  \
# id
# 2018090600:190:1      3         10            ATL  play_type_pass
# 2018090600:344:1      3          4            PHI  play_type_pass
# 2018090600:949:1      3         12            ATL  play_type_pass
# 2018090600:1037:1     3          7            PHI  play_type_pass
# 2018090600:1801:1     3          3            PHI  play_type_pass
#
#                   yardlineSide  yardlineNumber offenseFormation  \
# id
# 2018090600:190:1           PHI              39          SHOTGUN
# 2018090600:344:1           PHI               8            EMPTY
# 2018090600:949:1           ATL              18          SHOTGUN
# 2018090600:1037:1          PHI              43          SHOTGUN
# 2018090600:1801:1          PHI              36          SHOTGUN
#
#                          personnelO  defendersInTheBox  numberOfPassRushers  \
# id
# 2018090600:190:1   1 RB, 1 TE, 3 WR                6.0                  5.0
# 2018090600:344:1   1 RB, 2 TE, 2 WR                6.0                  4.0
# 2018090600:949:1   1 RB, 1 TE, 3 WR                4.0                  4.0
# 2018090600:1037:1  1 RB, 1 TE, 3 WR                6.0                  5.0
# 2018090600:1801:1  1 RB, 1 TE, 3 WR                7.0                  4.0
#
#                          personnelD  preSnapVisitorScore  preSnapHomeScore  \
# id
# 2018090600:190:1   4 DL, 1 LB, 6 DB                  0.0               0.0
# 2018090600:344:1   3 DL, 3 LB, 5 DB                  0.0               0.0
# 2018090600:949:1   4 DL, 1 LB, 6 DB                  3.0               0.0
# 2018090600:1037:1  4 DL, 2 LB, 5 DB                  3.0               0.0
# 2018090600:1801:1  4 DL, 2 LB, 5 DB                  6.0               3.0
#
#                   gameClock  absoluteYardlineNumber penaltyCodes  \
# id
# 2018090600:190:1   13:01:00                    49.0          NaN
# 2018090600:344:1   09:24:00                    18.0          NaN
# 2018090600:949:1   15:00:00                    28.0          NaN
# 2018090600:1037:1  12:53:00                    67.0          NaN
# 2018090600:1801:1  01:35:00                    74.0          NaN
#
#                   penaltyJerseyNumbers passResult  offensePlayResult  \
# id
# 2018090600:190:1                   NaN          C                 33
# 2018090600:344:1                   NaN          I                  0
# 2018090600:949:1                   NaN          C                 -7
# 2018090600:1037:1                  NaN          C                 10
# 2018090600:1801:1                  NaN          I                  0
#
#                    playResult       epa  isDefensivePI  defenseValoration
# id
# 2018090600:190:1           33  3.047530          False                  0
# 2018090600:344:1            0 -1.192208          False                  1
# 2018090600:949:1           -7 -1.912483          False                  1
# 2018090600:1037:1          10  2.044063          False                  0
# 2018090600:1801:1           0 -0.782217          False                  1

# %%
week1_f1 = week1[week1["frameId"]==1]
week2_f1 = week2[week2["frameId"]==1]
week3_f1 = week3[week3["frameId"]==1]
week4_f1 = week4[week4["frameId"]==1]
week5_f1 = week5[week5["frameId"]==1]
week6_f1 = week6[week6["frameId"]==1]
week7_f1 = week7[week7["frameId"]==1]
week8_f1 = week8[week8["frameId"]==1]
week9_f1 = week9[week9["frameId"]==1]
week10_f1 = week10[week10["frameId"]==1]
week11_f1 = week11[week11["frameId"]==1]
week12_f1 = week12[week12["frameId"]==1]
week13_f1 = week13[week13["frameId"]==1]
week14_f1 = week14[week14["frameId"]==1]
week15_f1 = week15[week15["frameId"]==1]
week16_f1 = week16[week16["frameId"]==1]
week17_f1 = week17[week17["frameId"]==1]
week1_f1
# Out:
#                        id                      time      x      y     s     a  \
# 0         2018090600:75:1  2018-09-07T01:07:14.599Z  91.73  26.67  0.00  0.01
# 1         2018090600:75:1  2018-09-07T01:07:14.599Z  88.89  36.47  0.01  0.01
# 2         2018090600:75:1  2018-09-07T01:07:14.599Z  91.35  44.16  0.02  0.03
# 3         2018090600:75:1  2018-09-07T01:07:14.599Z  86.31  22.01  0.09  0.42
# 4         2018090600:75:1  2018-09-07T01:07:14.599Z  90.78  36.15  0.00  0.00
# ...                   ...                       ...    ...    ...   ...   ...
# 920805  2018091001:4192:1  2018-09-11T05:29:33.500Z  35.90  24.39  0.00  0.00
# 920806  2018091001:4192:1  2018-09-11T05:29:33.500Z  36.93  36.39  0.02  0.02
# 920807  2018091001:4192:1  2018-09-11T05:29:33.500Z  42.53  46.29  0.00  0.00
# 920808  2018091001:4192:1  2018-09-11T05:29:33.500Z  29.08  35.13  0.02  0.02
# 920809  2018091001:4192:1  2018-09-11T05:29:33.500Z  41.00  29.62  0.00  0.00
#
#          dis       o     dir event      nflId       displayName  jerseyNumber  \
# 0       0.02  289.57  240.93  None      310.0         Matt Ryan           2.0
# 1       0.01  105.63   66.66  None    79848.0   Malcolm Jenkins          27.0
# 2       0.01  290.45   16.86  None  2495454.0       Julio Jones          11.0
# 3       0.01   70.12  168.91  None  2495613.0      Corey Graham          24.0
# 4       0.00  257.61  193.97  None  2533040.0      Mohamed Sanu          12.0
# ...      ...     ...     ...   ...        ...               ...           ...
# 920805  0.00   97.08  258.63  None  2556277.0  Marqui Christian          41.0
# 920806  0.01   95.57  111.48  None  2556593.0    Cory Littleton          58.0
# 920807  0.00  266.37  339.77  None  2556885.0     Jalen Richard          30.0
# 920808  0.01  104.77  290.71  None  2558183.0      John Johnson          43.0
# 920809  0.00     NaN     NaN  None        NaN          Football           NaN
#
#        position  frameId      team playDirection   route
# 0            QB        1      away          left     NaN
# 1            SS        1      home          left     NaN
# 2            WR        1      away          left   HITCH
# 3            FS        1      home          left     NaN
# 4            WR        1      away          left   HITCH
# ...         ...      ...       ...           ...     ...
# 920805       SS        1      away          left     NaN
# 920806      ILB        1      away          left     NaN
# 920807       RB        1      home          left  SCREEN
# 920808       SS        1      away          left     NaN
# 920809      NaN        1  football          left     NaN
#
# [14245 rows x 18 columns]

# %%
weeks_f1 = [week1_f1,week2_f1,week3_f1,week4_f1,week5_f1,week6_f1,week7_f1,week8_f1,week9_f1,week10_f1,week11_f1,week12_f1,week13_f1,week14_f1,week15_f1,week16_f1,week17_f1]

# %%
week1_f1[(week1_f1["nflId"]==310) & (week1_f1["id"].isin(third_down_plays.index))]
# Out:
#                       id                      time       x      y     s     a  \
# 2184    2018090600:190:1  2018-09-07T01:10:34.599Z   54.30  29.58  0.18  0.11
# 13135   2018090600:949:1  2018-09-07T01:45:51.799Z   23.12  30.25  0.00  0.00
# 31322  2018090600:1940:1  2018-09-07T02:24:51.500Z   35.74  24.23  0.00  0.00
# 41123  2018090600:2575:1  2018-09-07T03:01:42.500Z   24.84  30.22  0.00  0.00
# 48262  2018090600:3004:1  2018-09-07T03:22:17.099Z   44.94  24.01  0.11  0.07
# 51331  2018090600:3203:1  2018-09-07T03:28:52.799Z   34.86  24.07  0.00  0.00
# 59694  2018090600:3844:1  2018-09-07T04:00:33.400Z  100.81  23.52  0.22  0.11
# 68473  2018090600:4258:1  2018-09-07T04:17:54.500Z   54.89  24.00  0.17  0.16
#
#         dis       o     dir event  nflId displayName  jerseyNumber position  \
# 2184   0.02  285.29  254.04  None  310.0   Matt Ryan           2.0       QB
# 13135  0.00  100.88   79.70  None  310.0   Matt Ryan           2.0       QB
# 31322  0.01  103.25   63.82  None  310.0   Matt Ryan           2.0       QB
# 41123  0.00  106.54   83.69  None  310.0   Matt Ryan           2.0       QB
# 48262  0.01  104.48  105.32  None  310.0   Matt Ryan           2.0       QB
# 51331  0.00  100.11   89.73  None  310.0   Matt Ryan           2.0       QB
# 59694  0.02  284.05  288.15  None  310.0   Matt Ryan           2.0       QB
# 68473  0.01  286.69  272.76  None  310.0   Matt Ryan           2.0       QB
#
#        frameId  team playDirection route
# 2184         1  away          left   NaN
# 13135        1  away         right   NaN
# 31322        1  away         right   NaN
# 41123        1  away         right   NaN
# 48262        1  away         right   NaN
# 51331        1  away         right   NaN
# 59694        1  away          left   NaN
# 68473        1  away          left   NaN

# %%
def obtainDefenseTeam(playId):
    playIdParts = playId.split(":")
    gameId = playIdParts[0]
    visitorTeam = games.loc[int(gameId)]["visitorTeamAbbr"]
    homeTeam = games.loc[int(gameId)]["homeTeamAbbr"]
    possessionTeam = plays.loc[playId]["possessionTeam"]
    
    if possessionTeam == visitorTeam: #si equipo visitante tiene el balón, el equipo local es el que defiende
        value = "home"
    elif possessionTeam == homeTeam:
        value = "away"
    
    return value

# %%
len(week1_f1[week1_f1["id"].isin(third_down_plays.index)]["id"].unique())
# Out:
# 211

# %%
week1_f1[week1_f1["id"].isin(third_down_plays.index)]
# Out:
#                        id                      time      x      y     s     a  \
# 2184     2018090600:190:1  2018-09-07T01:10:34.599Z  54.30  29.58  0.18  0.11
# 2185     2018090600:190:1  2018-09-07T01:10:34.599Z  46.90  22.13  1.03  0.52
# 2186     2018090600:190:1  2018-09-07T01:10:34.599Z  50.41  21.58  0.01  0.01
# 2187     2018090600:190:1  2018-09-07T01:10:34.599Z  35.39  24.49  1.45  0.94
# 2188     2018090600:190:1  2018-09-07T01:10:34.599Z  51.20  18.21  0.00  0.00
# ...                   ...                       ...    ...    ...   ...   ...
# 918425  2018091001:4123:1  2018-09-11T05:27:40.000Z  71.57  23.25  0.11  0.13
# 918426  2018091001:4123:1  2018-09-11T05:27:40.000Z  71.64  29.38  0.04  0.03
# 918427  2018091001:4123:1  2018-09-11T05:27:40.000Z  80.78  28.95  0.00  0.00
# 918428  2018091001:4123:1  2018-09-11T05:27:40.000Z  59.73  26.09  1.21  0.22
# 918429  2018091001:4123:1  2018-09-11T05:27:40.000Z  77.01  26.51  0.00  0.00
#
#          dis       o     dir event      nflId       displayName  jerseyNumber  \
# 2184    0.02  285.29  254.04  None      310.0         Matt Ryan           2.0
# 2185    0.10  103.25  273.82  None    79848.0   Malcolm Jenkins          27.0
# 2186    0.00  259.09  154.62  None  2495454.0       Julio Jones          11.0
# 2187    0.14   97.59  221.61  None  2495613.0      Corey Graham          24.0
# 2188    0.00  279.07  115.13  None  2533040.0      Mohamed Sanu          12.0
# ...      ...     ...     ...   ...        ...               ...           ...
# 918425  0.01   93.45  198.60  None  2556277.0  Marqui Christian          41.0
# 918426  0.01   98.94  214.18  None  2556593.0    Cory Littleton          58.0
# 918427  0.00  263.89  308.96  None  2556885.0     Jalen Richard          30.0
# 918428  0.12   94.42  287.59  None  2558183.0      John Johnson          43.0
# 918429  0.00     NaN     NaN  None        NaN          Football           NaN
#
#        position  frameId      team playDirection   route
# 2184         QB        1      away          left     NaN
# 2185         SS        1      home          left     NaN
# 2186         WR        1      away          left  CORNER
# 2187         FS        1      home          left     NaN
# 2188         WR        1      away          left      IN
# ...         ...      ...       ...           ...     ...
# 918425       SS        1      away          left     NaN
# 918426      ILB        1      away          left     NaN
# 918427       RB        1      home          left   ANGLE
# 918428       SS        1      away          left     NaN
# 918429      NaN        1  football          left     NaN
#
# [2884 rows x 18 columns]

# %%
for index,row in players.iterrows():
    print(index)

# %%
players_defense = []
player_name = []
player_good_defense = []
player_bad_defense = [] ##???
for index,row in players.iterrows():
    if row["position"] in ["LB","ILB","MLB","OLB","CB","DB","SS","FS","S"]:
        players_defense.append(index)
        player_name.append(row["displayName"])
        plays_player = []
        for week in weeks_f1:
            for play in week[week["nflId"]==index]["id"].values:
                plays_player.append(play)
        
        counter_good = 0
        counter_bad = 0
        for play in plays_player:
            try:
                if third_down_plays.loc[play]["defenseValoration"] == 1:
                    counter_good += 1
                elif third_down_plays.loc[play]["defenseValoration"] == 0:
                    counter_bad += 1
            except KeyError:
                pass
        player_good_defense.append(counter_good)
        player_bad_defense.append(counter_bad)

# %%
defense_part = pd.DataFrame()

# %%
len(player_good_defense)
# Out:
# 605

# %%
len(player_bad_defense)
# Out:
# 605

# %%
defense_part["id"] = players_defense

# %%
defense_part["displayName"] = player_name

# %%
defense_part["good"] = player_good_defense

# %%
defense_part["bad"] = player_bad_defense

# %%
defense_part
# Out:
#           id         displayName  good  bad
# 0    2539334     Desmond Trufant    57   44
# 1    2539653       Robert Alford    47   42
# 2    2543850       Ricardo Allen    15    8
# 3    2555162         Deion Jones    22   16
# 4    2555255  De'Vondre Campbell    41   29
# ..       ...                 ...   ...  ...
# 600  2550647       Kasim Edebali     0    0
# 601   496843   Jason Pierre-Paul     0    0
# 602  2561394       Jeremy Reaves     0    0
# 603  2543725        Marcus Smith     0    0
# 604  2561469    Darious Williams     0    0
#
# [605 rows x 4 columns]

# %%
defense_part[defense_part["displayName"]=="Stephon Gilmore"]
# Out:
#           id      displayName  good  bad
# 129  2533062  Stephon Gilmore    74   47

# %%
defense_part = defense_part.set_index("id")
defense_part
# Out:
#                 displayName  good  bad
# id
# 2539334     Desmond Trufant    57   44
# 2539653       Robert Alford    47   42
# 2543850       Ricardo Allen    15    8
# 2555162         Deion Jones    22   16
# 2555255  De'Vondre Campbell    41   29
# ...                     ...   ...  ...
# 2550647       Kasim Edebali     0    0
# 496843    Jason Pierre-Paul     0    0
# 2561394       Jeremy Reaves     0    0
# 2543725        Marcus Smith     0    0
# 2561469    Darious Williams     0    0
#
# [605 rows x 3 columns]

# %%
defense_part = pd.read_csv("all_players_plays.csv",index_col=0)
defense_part
# Out:
#                 displayName  good  bad
# id
# 2539334     Desmond Trufant    57   44
# 2539653       Robert Alford    47   42
# 2543850       Ricardo Allen    15    8
# 2555162         Deion Jones    22   16
# 2555255  De'Vondre Campbell    41   29
# ...                     ...   ...  ...
# 2550647       Kasim Edebali     0    0
# 496843    Jason Pierre-Paul     0    0
# 2561394       Jeremy Reaves     0    0
# 2543725        Marcus Smith     0    0
# 2561469    Darious Williams     0    0
#
# [605 rows x 3 columns]

# %%
defense_part["total_plays"] = defense_part["good"] + defense_part["bad"]
defense_part
# Out:
#                 displayName  good  bad  total_plays
# id
# 2539334     Desmond Trufant    57   44          101
# 2539653       Robert Alford    47   42           89
# 2543850       Ricardo Allen    15    8           23
# 2555162         Deion Jones    22   16           38
# 2555255  De'Vondre Campbell    41   29           70
# ...                     ...   ...  ...          ...
# 2550647       Kasim Edebali     0    0            0
# 496843    Jason Pierre-Paul     0    0            0
# 2561394       Jeremy Reaves     0    0            0
# 2543725        Marcus Smith     0    0            0
# 2561469    Darious Williams     0    0            0
#
# [605 rows x 4 columns]

# %%
defense_part = defense_part.sort_values("total_plays",ascending=False)
defense_part
# Out:
#               displayName  good  bad  total_plays
# id
# 2543681       Kyle Fuller    95   48          143
# 2552385       Adrian Amos    94   48          142
# 2560851       Justin Reid    75   60          135
# 2540180    Tyrann Mathieu    77   56          133
# 496735     Kareem Jackson    76   57          133
# ...                   ...   ...  ...          ...
# 2560948      Trevon Young     0    0            0
# 2555307      Devante Bond     0    0            0
# 2561022        Jack Cichy     0    0            0
# 2507948       Frank Zombo     0    0            0
# 2561469  Darious Williams     0    0            0
#
# [605 rows x 4 columns]

# %%
defense_part.to_csv("all_players_plays.csv")

# %%
def obtainName(playerId):
    return players.loc[playerId]["displayName"]

# %%
player_good_defense = {}
player_bad_defense = {}
for week in weeks_f1:
    week_f1 = week[week["id"].isin(third_down_plays.index)]
    for play in week_f1["id"].unique():
        defense = week_f1[(week_f1["team"]==obtainDefenseTeam(play))]
        for player in defense["nflId"]:
            if third_down_plays.loc[play]["defenseValoration"] == 1:
                try:
                    player_good_defense[player] += 1
                except KeyError:
                    player_good_defense[player] = 1
                #player_good_defense[]
            elif third_down_plays.loc[play]["defenseValoration"] == 0:
                try:
                    player_bad_defense[player] += 1
                except KeyError:
                    player_bad_defense[player] = 1
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-21-ffa9a9e12c00> in <module>
#       6         defense = week_f1[(week_f1["team"]==obtainDefenseTeam(play))]
#       7         for player in defense["nflId"]:
# ----> 8             if third_down_plays.loc[play]["defenseValoration"] == 1:
#       9                 try:
#      10                     player_good_defense[player] += 1
#
# ~/.local/lib/python3.9/site-packages/pandas/core/indexing.py in __getitem__(self, key)
#     893
#     894             maybe_callable = com.apply_if_callable(key, self.obj)
# --> 895             return self._getitem_axis(maybe_callable, axis=axis)
#     896
#     897     def _is_scalar_access(self, key: Tuple):
#
# ~/.local/lib/python3.9/site-packages/pandas/core/indexing.py in _getitem_axis(self, key, axis)
#    1122         # fall thru to straight lookup
#    1123         self._validate_key(key, axis)
# -> 1124         return self._get_label(key, axis=axis)
#    1125
#    1126     def _get_slice_axis(self, slice_obj: slice, axis: int):
#
# ~/.local/lib/python3.9/site-packages/pandas/core/indexing.py in _get_label(self, label, axis)
#    1071     def _get_label(self, label, axis: int):
#    1072         # GH#5667 this will fail if the label is not present in the axis.
# -> 1073         return self.obj.xs(label, axis=axis)
#    1074
#    1075     def _handle_lowerdim_multi_index_axis0(self, tup: Tuple):
#
# ~/.local/lib/python3.9/site-packages/pandas/core/generic.py in xs(self, key, axis, level, drop_level)
#    3759             new_values = self._mgr.fast_xs(loc)
#    3760
# -> 3761             result = self._constructor_sliced(
#    3762                 new_values,
#    3763                 index=self.columns,
#
# ~/.local/lib/python3.9/site-packages/pandas/core/series.py in __init__(self, data, index, dtype, name, copy, fastpath)
#     364                 data = sanitize_array(data, index, dtype, copy, raise_cast_failure=True)
#     365
# --> 366                 data = SingleBlockManager.from_array(data, index)
#     367
#     368         generic.NDFrame.__init__(self, data)
#
# ~/.local/lib/python3.9/site-packages/pandas/core/internals/managers.py in from_array(cls, array, index)
#    1580         Constructor for if we have an array that is not yet a Block.
#    1581         """
# -> 1582         block = make_block(array, placement=slice(0, len(index)), ndim=1)
#    1583         return cls(block, index)
#    1584
#
# ~/.local/lib/python3.9/site-packages/pandas/core/internals/blocks.py in make_block(values, placement, klass, ndim, dtype)
#    2723     if klass is None:
#    2724         dtype = dtype or values.dtype
# -> 2725         klass = get_block_type(values, dtype)
#    2726
#    2727     elif klass is DatetimeTZBlock and not is_datetime64tz_dtype(values.dtype):
#
# ~/.local/lib/python3.9/site-packages/pandas/core/internals/blocks.py in get_block_type(values, dtype)
#    2686         assert not is_datetime64tz_dtype(values.dtype)
#    2687         cls = DatetimeBlock
# -> 2688     elif is_datetime64tz_dtype(values.dtype):
#    2689         cls = DatetimeTZBlock
#    2690     elif is_interval_dtype(dtype) or is_period_dtype(dtype):
#
# ~/.local/lib/python3.9/site-packages/pandas/core/dtypes/common.py in is_datetime64tz_dtype(arr_or_dtype)
#     424     if arr_or_dtype is None:
#     425         return False
# --> 426     return DatetimeTZDtype.is_dtype(arr_or_dtype)
#     427
#     428
#
# KeyboardInterrupt:

# %%
len(player_bad_defense)

# %%
len(player_good_defense)
# Out:
# 1111

# %%
defense_part = pd.DataFrame()

# %%
player_good_defense.keys()
# Out:
# dict_keys([310.0, 2495454.0, 2533040.0, 2543583.0, 2555415.0, 2560854.0, 2539334.0, 2539653.0, 2543850.0, 2555162.0, 2555255.0, 2555543.0, 2556445.0, 2558184.0, 2559109.0, 2552453.0, 2558023.0, 2557034.0, 2552301.0, 2539240.0, 2543851.0, 2557867.0, 2560713.0, 2560766.0, 79607.0, 2495139.0, 2495189.0, 2543471.0, 2557863.0, 2558191.0, 2539290.0, 2557969.0, 2507817.0, 2495453.0, 2552647.0, 2559159.0, 2507999.0, 2543767.0, 2560955.0, 2560729.0, 2506109.0, 2508061.0, 2540151.0, 2552633.0, 2557978.0, 2558149.0, 496727.0, 496733.0, 2540221.0, 2555344.0, 2555386.0, 2556559.0, 2558064.0, 2560712.0, 2557960.0, 2552289.0, 2558849.0, 2560920.0, 2495143.0, 2495450.0, 2540148.0, 2555466.0, 2557976.0, 2558010.0, 2533060.0, 2539233.0, 2543474.0, 2543814.0, 2555528.0, 2556367.0, 2560970.0, 2555355.0, 2558801.0, 2540156.0, 2558982.0, 2495469.0, 2495966.0, 2532903.0, 2552466.0, 2555317.0, 2557848.0, 2557870.0, 2354.0, 71423.0, 2539320.0, 2540162.0, 2550613.0, 2555158.0, 2555339.0, 2558005.0, 2558065.0, 2541539.0, 2555551.0, 2495441.0, 2553896.0, 496828.0, 2558207.0, 496735.0, 2495872.0, 2540180.0, 2543501.0, 2552261.0, 2558094.0, 2560851.0, 2540165.0, 2541316.0, 2543646.0, 2555234.0, 2558063.0, 2561427.0, 2552490.0, 2559152.0, 2533049.0, 2533034.0, 2560951.0, 2495272.0, 2532828.0, 2552592.0, 2555299.0, 2557945.0, 2561039.0, 2495471.0, 2506581.0, 2543468.0, 2553895.0, 2557856.0, 2558105.0, 2556466.0, 2555552.0, 2550656.0, 1581.0, 2543477.0, 2543614.0, 2543683.0, 2557895.0, 2557973.0, 2559153.0, 2552471.0, 494259.0, 2532848.0, 2541162.0, 2543711.0, 2555280.0, 2555329.0, 2560758.0, 2539237.0, 2495211.0, 2553318.0, 2561018.0, 2506340.0, 2540011.0, 2540160.0, 2543491.0, 2552415.0, 2555343.0, 2532920.0, 2539943.0, 2553796.0, 2558133.0, 2558136.0, 2557880.0, 2495190.0, 2495281.0, 2495826.0, 2557886.0, 2507164.0, 2553687.0, 2560886.0, 496937.0, 2541832.0, 2552568.0, 2555310.0, 2555531.0, 2555536.0, 2557840.0, 2534436.0, 2535698.0, 2539336.0, 2553743.0, 2555260.0, 2559193.0, 2553454.0, 2555224.0, 2560908.0, 2550353.0, 2560735.0, 2550262.0, 2539205.0, 2495108.0, 2532961.0, 2543681.0, 2552385.0, 2553500.0, 2555288.0, 2558176.0, 2543509.0, 2550284.0, 2550617.0, 2552636.0, 2558008.0, 2558250.0, 2541202.0, 2555285.0, 2540200.0, 2555418.0, 2560810.0, 494289.0, 2560877.0, 2553432.0, 2495328.0, 2531332.0, 2543828.0, 2553451.0, 2556462.0, 2561036.0, 2532877.0, 2533059.0, 2555322.0, 2556617.0, 2557979.0, 2495343.0, 2540219.0, 2552486.0, 2553353.0, 2561366.0, 2550189.0, 2543597.0, 2553657.0, 2540169.0, 2543498.0, 2552475.0, 2555334.0, 2555364.0, 2557898.0, 1302.0, 2540197.0, 2543492.0, 2552320.0, 2552488.0, 2556593.0, 2558183.0, 2556277.0, 2557889.0, 2558194.0, 2552382.0, 79848.0, 2495613.0, 2534832.0, 2552689.0, 2555383.0, 2557958.0, 2506467.0, 2507763.0, 2532842.0, 2540158.0, 2552600.0, 2560995.0, 2552315.0, 2552582.0, 2553502.0, 2558258.0, 2559150.0, 2556444.0, 382.0, 71269.0, 2543847.0, 2550256.0, 2552631.0, 2555209.0, 4365.0, 2495775.0, 2508004.0, 2540164.0, 2543464.0, 2555378.0, 2558067.0, 2552402.0, 2555505.0, 2552468.0, 2557841.0, 2558166.0, 2560957.0, 2556642.0, 2558248.0, 2555229.0, 2560757.0, 2561485.0, 2560963.0, 2555178.0, 2543637.0, 2543720.0, 2552389.0, 2555166.0, 2556475.0, 2557980.0, 2560916.0, 2495240.0, 2540928.0, 2543488.0, 2552461.0, 2555468.0, 2560988.0, 2555540.0, 2560964.0, 2557986.0, 2539311.0, 2537931.0, 2561470.0, 2543743.0, 2556365.0, 2552386.0, 2556429.0, 2557961.0, 2558060.0, 2558108.0, 2558976.0, 2560789.0, 2532865.0, 2533031.0, 2540232.0, 2543759.0, 2556396.0, 2560742.0, 2560933.0, 2543466.0, 2558877.0, 2550405.0, 496739.0, 2539309.0, 2539935.0, 2552434.0, 2555539.0, 2558070.0, 2560725.0, 2649.0, 2532956.0, 2540202.0, 2550272.0, 2552580.0, 2555230.0, 2560994.0, 2506404.0, 2556190.0, 2560966.0, 2559053.0, 497240.0, 2504211.0, 2530515.0, 2540145.0, 2543773.0, 2552424.0, 71251.0, 494287.0, 2533057.0, 2533062.0, 2552255.0, 2556571.0, 2561143.0, 2541243.0, 2539265.0, 2559211.0, 2533046.0, 2543699.0, 2504775.0, 2506122.0, 2507166.0, 254183 ...

# %%
defense_part["id"] = player_good_defense.keys()

# %%
defense_part = defense_part.set_index("id")

# %%
def obtainGoodDefenses(playerId):
    return player_good_defense[playerId]

# %%
defense_part["good"] = defense_part.index.map(obtainGoodDefenses)

# %%
def obtainBadDefenses(playerId):
    return player_bad_defense[playerId]

# %%
defense_part["bad"] = defense_part.index.map(obtainBadDefenses)

# %%
defense_part
# Out:
#            good   bad
# id
# 310.0      8558  5460
# 2495454.0  7740  4959
# 2533040.0  8227  5214
# 2543583.0   757   429
# 2555415.0  7371  4688
# ...         ...   ...
# 2552427.0   444   252
# 2556672.0    74    42
# 2561359.0   222   126
# 2552576.0   148    84
# 2556440.0    74    42
#
# [1111 rows x 2 columns]

# %%
defense_part.to_csv("all_players_plays.csv")
