# %%
import pandas as pd
import pickle

#Para el área
from shapely.geometry import Polygon
from shapely.geometry import MultiPoint 
from scipy.spatial import ConvexHull
from shapely.geometry import LineString

# %%
pd.set_option('display.max_columns',None)

# %%
static_defense = pd.read_csv("../transformed_data/static_defenses_yards.csv",index_col=1)
static_defense.head()
# Out:
#                   Unnamed: 0  defensivelinezonePlayers  deepzonePlayers  \
# id
# 2018090600:75:1            0                         0                1
# 2018090600:146:1           1                         0                1
# 2018090600:168:1           2                         0                1
# 2018090600:190:1           3                         1                0
# 2018090600:320:1           5                         1                0
#
#                   hookzonePlayers  curlzonePlayers  flatzonePlayers  \
# id
# 2018090600:75:1                 3                2                1
# 2018090600:146:1                3                2                1
# 2018090600:168:1                2                2                2
# 2018090600:190:1                2                3                1
# 2018090600:320:1                3                3                1
#
#                   defenseArea  defenseAreaCoverDefenders  width  height  \
# id
# 2018090600:75:1     194.31095                  194.31095  22.96   15.25
# 2018090600:146:1    204.17725                  204.17725  29.22   12.57
# 2018090600:168:1    277.65495                  277.65495  33.67   15.21
# 2018090600:190:1    189.16960                  165.05520  26.42   12.91
# 2018090600:320:1    187.12510                  153.20020  27.80   13.29
#
#                   numberQBs  numberWRs  numberTEs  numberRBs  numberFBs  \
# id
# 2018090600:75:1           1          2          1          1          1
# 2018090600:146:1          1          3          1          1          0
# 2018090600:168:1          1          2          1          2          0
# 2018090600:190:1          1          3          1          1          0
# 2018090600:320:1          1          3          1          1          0
#
#                   numberOffensivePlayersAnotherPosition  numberSafeties  \
# id
# 2018090600:75:1                                       0               3
# 2018090600:146:1                                      0               2
# 2018090600:168:1                                      0               2
# 2018090600:190:1                                      0               3
# 2018090600:320:1                                      0               2
#
#                   numberLBs  numberCBs strongSide  \
# id
# 2018090600:75:1           2          2       left
# 2018090600:146:1          2          3      right
# 2018090600:168:1          2          3       left
# 2018090600:190:1          1          3      right
# 2018090600:320:1          3          3       left
#
#                   numberPlayersDefenseStrongSide  \
# id
# 2018090600:75:1                                3
# 2018090600:146:1                               3
# 2018090600:168:1                               5
# 2018090600:190:1                               2
# 2018090600:320:1                               3
#
#                   numberPlayersDefenseWeakSide  \
# id
# 2018090600:75:1                              4
# 2018090600:146:1                             4
# 2018090600:168:1                             2
# 2018090600:190:1                             5
# 2018090600:320:1                             5
#
#                   numberPlayersOffenseStrongSide  \
# id
# 2018090600:75:1                                3
# 2018090600:146:1                               2
# 2018090600:168:1                               4
# 2018090600:190:1                               2
# 2018090600:320:1                               3
#
#                   numberPlayersOffenseWeakSide  \
# id
# 2018090600:75:1                              2
# 2018090600:146:1                             3
# 2018090600:168:1                             1
# 2018090600:190:1                             3
# 2018090600:320:1                             2
#
#                   differenceOffenseVsDefenseWidth  \
# id
# 2018090600:75:1                             -0.63
# 2018090600:146:1                            -1.15
# 2018090600:168:1                             0.71
# 2018090600:190:1                            -3.11
# 2018090600:320:1                            -4.82
#
#                   differenceOffenseVsDefenseStrongSide  \
# id
# 2018090600:75:1                                      0
# 2018090600:146:1                                    -1
# 2018090600:168:1                                    -1
# 2018090600:190:1                                     0
# 2018090600:320:1                                     0
#
#                   differenceOffenseVsDefenseWeakSide  HeightByWeightDeep  \
# id
# 2018090600:75:1                                   -2            0.020227
# 2018090600:146:1                                  -1            0.020227
# 2018090600:168:1                                  -1            0.020227
# 2018090600:190:1                                  -2            0.000000
# 2018090600:320:1                                  -3            0.000000
#
#                   HeightByWeightHook  HeightByWeightCurl  HeightByWeightFlat  \
# id
# 2018090600:75:1             0.018643            0.020066            0.021034
# 2018090600:146:1            0.019228            0.020356            0.020455
# 2018090600:168:1            0.017683            0.020997            0.020745
# 2018090600:190:1            0.020120            0.021193            0.020455
# 2018090600:320:1            0.018995            0.019537            0.021279
#
#                   WeightByArea   density  densityNoLine  densityInsidePoints  \
# id
# 2018090600:75:1       3.376032  0.036025       0.036025             6.974268
# 2018090600:146:1      3.178611  0.034284       0.034284             6.975511
# 2018090600:168:1      2.337434  0.025211       0.025211             6.985594
# 2018090600:190:1      3.192871  0.037004       0.036351             6.973569
# 2018090600:320:1      4.281979  0.042752       0.045692             7.978624
#
#                   densityInsidePointsNoLine  playResult
# id
# 2018090600:75:1                    6.974268          10
# 2018090600:146:1                   6.975511           0
# 2018090600:168:1                   6.985594           0
# 2018090600:190:1                   6.969707          33
# 2018090600:320:1                   7.980418           4

# %%
static_defense.drop(["Unnamed: 0"],axis=1,inplace=True)

# %%
plays = pd.read_csv("../processed_data/clean/plays.csv",index_col=1)
plays.head()
# Out:
#                   Unnamed: 0  \
# id
# 2018090600:75:1            0
# 2018090600:146:1           1
# 2018090600:168:1           2
# 2018090600:190:1           3
# 2018090600:256:1           4
#
#                                                     playDescription  quarter  \
# id
# 2018090600:75:1   (15:00) M.Ryan pass short right to J.Jones pus...        1
# 2018090600:146:1  (13:10) M.Ryan pass incomplete short right to ...        1
# 2018090600:168:1  (13:05) (Shotgun) M.Ryan pass incomplete short...        1
# 2018090600:190:1  (13:01) (Shotgun) M.Ryan pass deep left to J.J...        1
# 2018090600:256:1  (10:59) (Shotgun) M.Ryan pass incomplete short...        1
#
#                   down  yardsToGo possessionTeam        playType yardlineSide  \
# id
# 2018090600:75:1      1         15            ATL  play_type_pass          ATL
# 2018090600:146:1     1         10            ATL  play_type_pass          PHI
# 2018090600:168:1     2         10            ATL  play_type_pass          PHI
# 2018090600:190:1     3         10            ATL  play_type_pass          PHI
# 2018090600:256:1     3          1            ATL  play_type_pass          PHI
#
#                   yardlineNumber offenseFormation        personnelO  \
# id
# 2018090600:75:1               20           I_FORM  2 RB, 1 TE, 2 WR
# 2018090600:146:1              39       SINGLEBACK  1 RB, 1 TE, 3 WR
# 2018090600:168:1              39          SHOTGUN  2 RB, 1 TE, 2 WR
# 2018090600:190:1              39          SHOTGUN  1 RB, 1 TE, 3 WR
# 2018090600:256:1               1          SHOTGUN  2 RB, 3 TE, 0 WR
#
#                   defendersInTheBox  numberOfPassRushers        personnelD  \
# id
# 2018090600:75:1                 7.0                  4.0  4 DL, 2 LB, 5 DB
# 2018090600:146:1                7.0                  4.0  4 DL, 2 LB, 5 DB
# 2018090600:168:1                6.0                  4.0  4 DL, 2 LB, 5 DB
# 2018090600:190:1                6.0                  5.0  4 DL, 1 LB, 6 DB
# 2018090600:256:1                8.0                  6.0  6 DL, 3 LB, 2 DB
#
#                   preSnapVisitorScore  preSnapHomeScore gameClock  \
# id
# 2018090600:75:1                   0.0               0.0  15:00:00
# 2018090600:146:1                  0.0               0.0  13:10:00
# 2018090600:168:1                  0.0               0.0  13:05:00
# 2018090600:190:1                  0.0               0.0  13:01:00
# 2018090600:256:1                  0.0               0.0  10:59:00
#
#                   absoluteYardlineNumber penaltyCodes penaltyJerseyNumbers  \
# id
# 2018090600:75:1                     90.0          NaN                  NaN
# 2018090600:146:1                    49.0          NaN                  NaN
# 2018090600:168:1                    49.0          NaN                  NaN
# 2018090600:190:1                    49.0          NaN                  NaN
# 2018090600:256:1                    11.0          NaN                  NaN
#
#                  passResult  offensePlayResult  playResult       epa  \
# id
# 2018090600:75:1           C                 10          10  0.261827
# 2018090600:146:1          I                  0           0 -0.372360
# 2018090600:168:1          I                  0           0 -0.702779
# 2018090600:190:1          C                 33          33  3.047530
# 2018090600:256:1          I                  0           0 -0.842272
#
#                   isDefensivePI
# id
# 2018090600:75:1           False
# 2018090600:146:1          False
# 2018090600:168:1          False
# 2018090600:190:1          False
# 2018090600:256:1          False

# %%
plays.drop(["Unnamed: 0"],axis=1,inplace=True)

# %%
defense = pd.read_csv("../processed_data/processing_defenses/defense_players_plays_no_rz.csv",index_col=1)
defense.head()
# Out:
#                  Unnamed: 0      x      y     s     a   dis       o     dir  \
# id
# 2018090600:75:1           1  88.89  36.47  0.01  0.01  0.01  105.63   66.66
# 2018090600:75:1           3  86.31  22.01  0.09  0.42  0.01   70.12  168.91
# 2018090600:75:1           5  73.64  28.70  0.03  0.02  0.01  103.05  219.41
# 2018090600:75:1           7  86.48  31.12  0.09  0.03  0.04   95.90   33.36
# 2018090600:75:1           8  82.67  20.53  0.03  0.07  0.01   81.14  174.57
#
#                      nflId      displayName  jerseyNumber position  team  \
# id
# 2018090600:75:1    79848.0  Malcolm Jenkins          27.0       SS  home
# 2018090600:75:1  2495613.0     Corey Graham          24.0       FS  home
# 2018090600:75:1  2534832.0    Rodney McLeod          23.0       FS  home
# 2018090600:75:1  2552315.0     Jordan Hicks          58.0      MLB  home
# 2018090600:75:1  2552689.0     Ronald Darby          21.0       CB  home
#
#                 playDirection
# id
# 2018090600:75:1          left
# 2018090600:75:1          left
# 2018090600:75:1          left
# 2018090600:75:1          left
# 2018090600:75:1          left

# %%
defense.drop(["Unnamed: 0"],axis=1,inplace=True)

# %%
games = pd.read_csv("../raw_data/games.csv",index_col=0)
games.head()
# Out:
#               gameDate gameTimeEastern homeTeamAbbr visitorTeamAbbr  week
# gameId
# 2018090600  09/06/2018        20:20:00          PHI             ATL     1
# 2018090901  09/09/2018        13:00:00          CLE             PIT     1
# 2018090902  09/09/2018        13:00:00          IND             CIN     1
# 2018090903  09/09/2018        13:00:00          MIA             TEN     1
# 2018090900  09/09/2018        13:00:00          BAL             BUF     1

# %% [markdown]
# Determinar una jugada y realizar la transformación:
#     2018090600:1037:1

# %%
single_summary = pd.DataFrame()

# %% [markdown]
# Obtener los jugadores defensivos de esa jugada:

# %%
defense.loc["2018090600:1037:1"]
# Out:
#                        x      y     s     a   dis       o     dir      nflId  \
# id
# 2018090600:1037:1  66.63  35.21  0.00  0.00  0.00  101.79   44.87  2539334.0
# 2018090600:1037:1  65.58  15.28  0.01  0.01  0.01   75.79  295.44  2539653.0
# 2018090600:1037:1  51.97  27.53  0.41  0.31  0.04   95.89  286.70  2543850.0
# 2018090600:1037:1  65.75  21.74  0.00  0.00  0.00   92.67  103.82  2555162.0
# 2018090600:1037:1  66.90  17.19  0.00  0.01  0.00   95.69  338.77  2555255.0
# 2018090600:1037:1  57.77  22.98  0.27  1.17  0.03  126.24  210.03  2555543.0
# 2018090600:1037:1  65.43  28.96  0.93  0.62  0.08   96.78  190.65  2556445.0
#
#                           displayName  jerseyNumber position  team  \
# id
# 2018090600:1037:1     Desmond Trufant          21.0       CB  away
# 2018090600:1037:1       Robert Alford          23.0       CB  away
# 2018090600:1037:1       Ricardo Allen          37.0       SS  away
# 2018090600:1037:1         Deion Jones          45.0      MLB  away
# 2018090600:1037:1  De'Vondre Campbell          59.0      OLB  away
# 2018090600:1037:1          Keanu Neal          22.0       FS  away
# 2018090600:1037:1         Brian Poole          34.0       CB  away
#
#                   playDirection
# id
# 2018090600:1037:1          left
# 2018090600:1037:1          left
# 2018090600:1037:1          left
# 2018090600:1037:1          left
# 2018090600:1037:1          left
# 2018090600:1037:1          left
# 2018090600:1037:1          left

# %%
single_summary["playerId"] = defense.loc["2018090600:1037:1"]["nflId"]
single_summary
# Out:
#                     playerId
# id
# 2018090600:1037:1  2539334.0
# 2018090600:1037:1  2539653.0
# 2018090600:1037:1  2543850.0
# 2018090600:1037:1  2555162.0
# 2018090600:1037:1  2555255.0
# 2018090600:1037:1  2555543.0
# 2018090600:1037:1  2556445.0

# %% [markdown]
# # Individual Actions Data (p): consideramos que el jugador ejecuta una acción en toda la jugada de la acción, hay que sacar por tanto una acción resumen de todas      para cada jugador p_i (i = a ... j) tenemos una serie de m características {p_i1, p_i2, ..., p_im}

# %%
week1 = pd.read_csv("../processed_data/clean/week1.csv",index_col=6)
week1.head()
# Out:
#                  Unnamed: 0  Unnamed: 0.1  Unnamed: 0.1.1  level_0  \
# id
# 2018090600:75:1           0             0               0        0
# 2018090600:75:1           1             1               1        1
# 2018090600:75:1           2             2               2        2
# 2018090600:75:1           3             3               3        3
# 2018090600:75:1           4             4               4        4
#
#                  Unnamed: 0.1.1.1  index                      time      x  \
# id
# 2018090600:75:1                 0      0  2018-09-07T01:07:14.599Z  91.73
# 2018090600:75:1                 1      1  2018-09-07T01:07:14.599Z  88.89
# 2018090600:75:1                 2      2  2018-09-07T01:07:14.599Z  91.35
# 2018090600:75:1                 3      3  2018-09-07T01:07:14.599Z  86.31
# 2018090600:75:1                 4      4  2018-09-07T01:07:14.599Z  90.78
#
#                      y     s     a   dis       o     dir event      nflId  \
# id
# 2018090600:75:1  26.67  0.00  0.01  0.02  289.57  240.93  None      310.0
# 2018090600:75:1  36.47  0.01  0.01  0.01  105.63   66.66  None    79848.0
# 2018090600:75:1  44.16  0.02  0.03  0.01  290.45   16.86  None  2495454.0
# 2018090600:75:1  22.01  0.09  0.42  0.01   70.12  168.91  None  2495613.0
# 2018090600:75:1  36.15  0.00  0.00  0.00  257.61  193.97  None  2533040.0
#
#                      displayName  jerseyNumber position  frameId  team  \
# id
# 2018090600:75:1        Matt Ryan           2.0       QB        1  away
# 2018090600:75:1  Malcolm Jenkins          27.0       SS        1  home
# 2018090600:75:1      Julio Jones          11.0       WR        1  away
# 2018090600:75:1     Corey Graham          24.0       FS        1  home
# 2018090600:75:1     Mohamed Sanu          12.0       WR        1  away
#
#                 playDirection  route
# id
# 2018090600:75:1          left    NaN
# 2018090600:75:1          left    NaN
# 2018090600:75:1          left  HITCH
# 2018090600:75:1          left    NaN
# 2018090600:75:1          left  HITCH

# %%
week1.drop(["Unnamed: 0","Unnamed: 0.1","Unnamed: 0.1.1","level_0","Unnamed: 0.1.1.1","index"],axis=1,inplace=True)

# %%
#### Esto luego no servirá
week1_fpf = week1[week1["event"]=="pass_forward"]
week1_fpf.head()
# Out:
#                                      time      x      y     s     a   dis  \
# id
# 2018090600:75:1  2018-09-07T01:07:18.099Z  96.43  26.78  0.84  2.05  0.08
# 2018090600:75:1  2018-09-07T01:07:18.099Z  84.82  38.33  5.53  4.30  0.54
# 2018090600:75:1  2018-09-07T01:07:18.099Z  80.69  44.91  3.11  6.67  0.34
# 2018090600:75:1  2018-09-07T01:07:18.099Z  86.02  18.64  3.52  0.69  0.35
# 2018090600:75:1  2018-09-07T01:07:18.099Z  82.65  34.56  6.35  1.21  0.64
#
#                       o     dir         event      nflId      displayName  \
# id
# 2018090600:75:1  356.40  333.39  pass_forward      310.0        Matt Ryan
# 2018090600:75:1  295.34  318.58  pass_forward    79848.0  Malcolm Jenkins
# 2018090600:75:1  155.11  297.88  pass_forward  2495454.0      Julio Jones
# 2018090600:75:1   28.19  216.15  pass_forward  2495613.0     Corey Graham
# 2018090600:75:1  262.06  272.78  pass_forward  2533040.0     Mohamed Sanu
#
#                  jerseyNumber position  frameId  team playDirection  route
# id
# 2018090600:75:1           2.0       QB       36  away          left    NaN
# 2018090600:75:1          27.0       SS       36  home          left    NaN
# 2018090600:75:1          11.0       WR       36  away          left  HITCH
# 2018090600:75:1          24.0       FS       36  home          left    NaN
# 2018090600:75:1          12.0       WR       36  away          left  HITCH

# %%
defense_fpf = week1_fpf[week1_fpf.index.isin(["2018090600:1037:1"]) & (week1_fpf["team"]=="away")]
defense_fpf
# Out:
#                                        time      x      y     s     a   dis  \
# id
# 2018090600:1037:1  2018-09-07T01:48:50.000Z  52.54  41.42  5.28  4.91  0.55
# 2018090600:1037:1  2018-09-07T01:48:50.000Z  54.59  16.21  0.62  6.68  0.08
# 2018090600:1037:1  2018-09-07T01:48:50.000Z  43.94  33.11  4.54  1.01  0.46
# 2018090600:1037:1  2018-09-07T01:48:50.000Z  74.19  23.09  3.62  3.72  0.34
# 2018090600:1037:1  2018-09-07T01:48:50.000Z  54.85  24.76  5.19  4.74  0.54
# 2018090600:1037:1  2018-09-07T01:48:50.000Z  44.82  21.17  3.40  3.72  0.36
# 2018090600:1037:1  2018-09-07T01:48:50.000Z  64.28  38.74  6.31  1.42  0.64
#
#                         o     dir         event      nflId  \
# id
# 2018090600:1037:1  296.24  283.67  pass_forward  2539334.0
# 2018090600:1037:1  359.87  294.71  pass_forward  2539653.0
# 2018090600:1037:1   57.92  316.20  pass_forward  2543850.0
# 2018090600:1037:1  117.95  152.92  pass_forward  2555162.0
# 2018090600:1037:1  240.88  274.87  pass_forward  2555255.0
# 2018090600:1037:1   95.92  260.10  pass_forward  2555543.0
# 2018090600:1037:1   76.72  350.73  pass_forward  2556445.0
#
#                           displayName  jerseyNumber position  frameId  team  \
# id
# 2018090600:1037:1     Desmond Trufant          21.0       CB       47  away
# 2018090600:1037:1       Robert Alford          23.0       CB       47  away
# 2018090600:1037:1       Ricardo Allen          37.0       SS       47  away
# 2018090600:1037:1         Deion Jones          45.0      MLB       47  away
# 2018090600:1037:1  De'Vondre Campbell          59.0      OLB       47  away
# 2018090600:1037:1          Keanu Neal          22.0       FS       47  away
# 2018090600:1037:1         Brian Poole          34.0       CB       47  away
#
#                   playDirection route
# id
# 2018090600:1037:1          left   NaN
# 2018090600:1037:1          left   NaN
# 2018090600:1037:1          left   NaN
# 2018090600:1037:1          left   NaN
# 2018090600:1037:1          left   NaN
# 2018090600:1037:1          left   NaN
# 2018090600:1037:1          left   NaN

# %%
week1.loc["2018090600:1037:1"]["event"].unique()
# Out:
# array(['None', 'ball_snap', 'pass_forward', 'pass_arrived',
#        'pass_outcome_caught', 'tackle'], dtype=object)

# %%
week1_pa = week1[week1["event"]=="pass_arrived"]
week1_pa
# Out:
#                                        time      x      y     s     a   dis  \
# id
# 2018090600:75:1    2018-09-07T01:07:19.200Z  96.30  27.52  0.59  0.51  0.06
# 2018090600:75:1    2018-09-07T01:07:19.200Z  82.34  45.18  7.57  1.72  0.75
# 2018090600:75:1    2018-09-07T01:07:19.200Z  81.11  47.87  4.23  1.63  0.42
# 2018090600:75:1    2018-09-07T01:07:19.200Z  82.90  17.62  3.64  4.01  0.36
# 2018090600:75:1    2018-09-07T01:07:19.200Z  77.66  35.52  2.99  3.53  0.31
# ...                                     ...    ...    ...   ...   ...   ...
# 2018091001:4192:1  2018-09-11T05:29:36.799Z  34.72  28.43  4.96  3.17  0.48
# 2018091001:4192:1  2018-09-11T05:29:36.799Z  36.04  40.58  3.47  1.27  0.35
# 2018091001:4192:1  2018-09-11T05:29:36.799Z  41.88  45.46  1.32  2.35  0.14
# 2018091001:4192:1  2018-09-11T05:29:36.799Z  30.16  37.51  4.18  2.09  0.41
# 2018091001:4192:1  2018-09-11T05:29:36.799Z  42.60  45.22  2.84  0.36  0.51
#
#                         o     dir         event      nflId       displayName  \
# id
# 2018090600:75:1    333.07    1.23  pass_arrived      310.0         Matt Ryan
# 2018090600:75:1    354.68  353.52  pass_arrived    79848.0   Malcolm Jenkins
# 2018090600:75:1     53.31   22.58  pass_arrived  2495454.0       Julio Jones
# 2018090600:75:1     13.28  299.37  pass_arrived  2495613.0      Corey Graham
# 2018090600:75:1     78.88  305.48  pass_arrived  2533040.0      Mohamed Sanu
# ...                   ...     ...           ...        ...               ...
# 2018091001:4192:1   44.27  359.68  pass_arrived  2556277.0  Marqui Christian
# 2018091001:4192:1   86.95   16.47  pass_arrived  2556593.0    Cory Littleton
# 2018091001:4192:1  178.51  139.94  pass_arrived  2556885.0     Jalen Richard
# 2018091001:4192:1   69.48   54.34  pass_arrived  2558183.0      John Johnson
# 2018091001:4192:1     NaN     NaN  pass_arrived        NaN          Football
#
#                    jerseyNumber position  frameId      team playDirection  \
# id
# 2018090600:75:1             2.0       QB       47      away          left
# 2018090600:75:1            27.0       SS       47      home          left
# 2018090600:75:1            11.0       WR       47      away          left
# 2018090600:75:1            24.0       FS       47      home          left
# 2018090600:75:1            12.0       WR       47      away          left
# ...                         ...      ...      ...       ...           ...
# 2018091001:4192:1          41.0       SS       34      away          left
# 2018091001:4192:1          58.0      ILB       34      away          left
# 2018091001:4192:1          30.0       RB       34      home          left
# 2018091001:4192:1          43.0       SS       34      away          left
# 2018091001:4192:1           NaN      NaN       34  football          left
#
#                     route
# id
# 2018090600:75:1       NaN
# 2018090600:75:1       NaN
# 2018090600:75:1     HITCH
# 2018090600:75:1       NaN
# 2018090600:75:1     HITCH
# ...                   ...
# 2018091001:4192:1     NaN
# 2018091001:4192:1     NaN
# 2018091001:4192:1  SCREEN
# 2018091001:4192:1     NaN
# 2018091001:4192:1     NaN
#
# [11428 rows x 17 columns]

# %%
defense_pa = week1_pa[week1_pa.index.isin(["2018090600:1037:1"]) & (week1_pa["team"]=="away")]
defense_pa
# Out:
#                                        time      x      y     s     a   dis  \
# id
# 2018090600:1037:1  2018-09-07T01:48:50.799Z  50.87  42.50  1.29  5.10  0.11
# 2018090600:1037:1  2018-09-07T01:48:50.799Z  56.22  16.42  3.45  1.43  0.34
# 2018090600:1037:1  2018-09-07T01:48:50.799Z  42.39  34.76  0.70  4.40  0.09
# 2018090600:1037:1  2018-09-07T01:48:50.799Z  75.50  20.53  2.81  4.16  0.31
# 2018090600:1037:1  2018-09-07T01:48:50.799Z  52.15  23.16  4.10  5.05  0.41
# 2018090600:1037:1  2018-09-07T01:48:50.799Z  44.41  19.65  3.71  5.45  0.35
# 2018090600:1037:1  2018-09-07T01:48:50.799Z  63.20  42.99  4.40  3.32  0.45
#
#                         o     dir         event      nflId  \
# id
# 2018090600:1037:1   77.71   33.20  pass_arrived  2539334.0
# 2018090600:1037:1   94.75   78.67  pass_arrived  2539653.0
# 2018090600:1037:1  104.35  332.97  pass_arrived  2543850.0
# 2018090600:1037:1  159.58  143.01  pass_arrived  2555162.0
# 2018090600:1037:1  152.69  198.60  pass_arrived  2555255.0
# 2018090600:1037:1   96.44  140.31  pass_arrived  2555543.0
# 2018090600:1037:1  120.75  336.93  pass_arrived  2556445.0
#
#                           displayName  jerseyNumber position  frameId  team  \
# id
# 2018090600:1037:1     Desmond Trufant          21.0       CB       55  away
# 2018090600:1037:1       Robert Alford          23.0       CB       55  away
# 2018090600:1037:1       Ricardo Allen          37.0       SS       55  away
# 2018090600:1037:1         Deion Jones          45.0      MLB       55  away
# 2018090600:1037:1  De'Vondre Campbell          59.0      OLB       55  away
# 2018090600:1037:1          Keanu Neal          22.0       FS       55  away
# 2018090600:1037:1         Brian Poole          34.0       CB       55  away
#
#                   playDirection route
# id
# 2018090600:1037:1          left   NaN
# 2018090600:1037:1          left   NaN
# 2018090600:1037:1          left   NaN
# 2018090600:1037:1          left   NaN
# 2018090600:1037:1          left   NaN
# 2018090600:1037:1          left   NaN
# 2018090600:1037:1          left   NaN

# %%
week1[week1.index.isin(["2018090600:1037:1"]) & (week1["event"]=="ball_snap")]["frameId"].values[0]
# Out:
# 11

# %%
defense_fpf["frameId"].values[0]
# Out:
# 47

# %%
defense_pa["frameId"].values[0]
# Out:
# 55

# %%
def obtainOffenseTeam(playId):
    playIdParts = playId.split(":")
    gameId = playIdParts[0]
    visitorTeam = games.loc[int(gameId)]["visitorTeamAbbr"]
    homeTeam = games.loc[int(gameId)]["homeTeamAbbr"]
    possessionTeam = plays.loc[playId]["possessionTeam"]
    
    if possessionTeam == visitorTeam: #si equipo visitante tiene el balón, el equipo local es el que defiende
        value = "away"
    elif possessionTeam == homeTeam:
        value = "home"
    
    return value

# %%
obtainOffenseTeam("2018090600:1037:1")
# Out:
# 'home'

# %% [markdown]
# Por cada jugador, ver el jugador más cercano rival y ver su distancia euclidea

# %%
for frame in range(11,48):
    players = week1[(week1["frameId"]==frame)&(week1["team"]==obtainOffenseTeam("2018090600:1037:1"))&(week1["route"].notnull())]
    for index,row in players.iterrows():
        playerId = row["nflId"]
        x = players[(players["frameId"]==frame)&(players["nflId"]==playerId)]["x"].values[0]
        y = players[(players["frameId"]==frame)&(players["nflId"]==playerId)]["y"].values[0]
        distances = []
        for index1,row1 in players.iterrows():
            if row1["nflId"] != playerId:
                x_value = row1["x"]
                y_value = row1["y"]
                line = LineString([(x, y), (x_value, y_value)]) #distancia euclidea
                distances.append(line.length) #habría que tener en cuenta el jugador???
        print(min(distances))
# Out:
# 1.1872657663724666
# 1.784656829757475
# 1.9849433241279186
# 1.359779393872402
# 2.095709903588757
# 0.857962703152063
# 1.1872657663724666
# 1.784656829757475
# 1.359779393872402
# 0.5600892785976165
# 0.857962703152063
# 1.1872657663724666
# 1.784656829757475
# 1.359779393872402
# 2.095709903588757
# 1.1872657663724666
# 1.784656829757475
# 1.9849433241279186
# 1.359779393872402
# 0.5600892785976165
# 1.1872657663724666
# 1.784656829757475
# 1.359779393872402
# 2.095709903588757
# 1.1872657663724666
# 1.784656829757475
# 1.9849433241279186
# 1.359779393872402
# 2.095709903588757
# 1.1872657663724666
# 1.784656829757475
# 1.9849433241279186
# 1.359779393872402
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-29-d53a0b30c1e4> in <module>
#      11                 y_value = row1["y"]
#      12                 line = LineString([(x, y), (x_value, y_value)]) #distancia euclidea
# ---> 13                 distances.append(line.length) #habría que tener en cuenta el jugador???
#      14         print(min(distances))
#
# ~/.local/lib/python3.9/site-packages/shapely/geometry/base.py in length(self)
#     451     def length(self):
#     452         """Unitless length of the geometry (float)"""
# --> 453         return self.impl['length'](self)
#     454
#     455     @property
#
# ~/.local/lib/python3.9/site-packages/shapely/topology.py in __call__(self, this)
#      55         self._validate(this)
#      56         d = c_double()
# ---> 57         retval = self.fn(this._geom, byref(d))
#      58         return d.value
#      59
#
# KeyboardInterrupt:

# %%
for frame in selected_play["frameId"].unique():
    players = selected_play[(selected_play["frameId"]==frame)&(selected_play["team"]==obtainOffenseTeam("2018090600:1037:1"))&(selected_play["route"].notnull())]
    x = unique_player[unique_player["frameId"]==frame]["x"].values[0]
    y = unique_player[unique_player["frameId"]==frame]["y"].values[0]
    p = Point(x, y)
    circle = p.buffer(5.0)
    #distances = []
    number_players = 0
    for index,row in players.iterrows():
        x_value = row["x"]
        y_value = row["y"]
        point = Point(x_value,y_value)
        if circle.contains(point):
            number_players += 1
        #line = LineString([(x, y), (x_value, y_value)]) #distancia euclidea
        #distances.append(line.length) #habría que tener en cuenta el jugador???
    print(number_players)

# %% [markdown]
# # Complex Features (c): Características dinámicas de la acción en general. Posiblemente podría ser cosas como variación de la superficie cubierta, variación de densidad, defensores en la zona del pase, ....

# %%
def obtainAreaDefense(playId):
    defenders = defense_fpf.loc[playId]
    position_players = []
    playDirection = defenders["playDirection"].values[0]
    los = plays.loc[playId]["absoluteYardlineNumber"]
    
    for index,row in defenders.iterrows():
        if row["position"] in ["DL","NT","DT","DE"]:
            continue
        
        if playDirection == "right" and row["x"] < los:
            continue
        elif playDirection == "left" and row["x"] > los:
            continue
        
        position_players.append((row["x"],row["y"]))
        
    hull = ConvexHull(position_players)
    
    return hull.volume

# %%
single_summary["areaDifference"] = single_summary.index.map(obtainAreaDefense) - static_defense.loc["2018090600:1037:1"]["defenseArea"]

# %%
def calculateNumberDeepPlayers(playId):
    los = plays.loc[playId]["absoluteYardlineNumber"]
    defenders = defense_fpf.loc[playId]
    playDirection = defenders["playDirection"].values[0]
    deepzone = -1
    
    if playDirection == "right":
        deepzone = los + 15
    elif playDirection == "left":
        deepzone = los - 15
        
    number_players=0
    for index,row in defenders.iterrows():
        if row["position"] in ["DL","NT","DT","DE"]: #muy dificil que pase, pero por si acaso
            continue
        player_x = row["x"]
        if playDirection == "right" and player_x > deepzone:
            number_players+=1
        elif playDirection == "left" and player_x < deepzone:
            number_players+=1
            
    return number_players

# %%
single_summary["numberPlayersDeep"] = single_summary.index.map(calculateNumberDeepPlayers)

# %%
single_summary["numberPlayersDeepDifference"] = single_summary["numberPlayersDeep"] - static_defense.loc["2018090600:1037:1"]["deepzonePlayers"]

# %%
def calculateNumberUnderneath(playId):
    los = plays.loc[playId]["absoluteYardlineNumber"]
    defenders = defense_fpf.loc[playId]
    playDirection = defenders["playDirection"].values[0]
    deepzone = -1
    
    if playDirection == "right":
        deepzone = los + 15
    elif playDirection == "left":
        deepzone = los - 15
        
    number_players=0
    for index,row in defenders.iterrows():
        if row["position"] in ["DL","NT","DT","DE"]: #muy dificil que pase, pero por si acaso
            continue
        player_x = row["x"]
        if playDirection == "right" and player_x < deepzone and player_x > los:
            number_players+=1
        elif playDirection == "left" and player_x > deepzone and player_x < los:
            number_players+=1
            
    return number_players

# %%
single_summary["numberPlayersUnderneath"] = single_summary.index.map(calculateNumberUnderneath)

# %%
single_summary["densityDifference"] = (single_summary["numberPlayersDeep"] + single_summary["numberPlayersUnderneath"])/single_summary["areaDifference"]

# %%
def calculateHeight(playId):
    defenders = defense_fpf.loc[playId]
    playDirection = defenders["playDirection"].values[0]
    los = plays.loc[playId]["absoluteYardlineNumber"]
    
    players_x = []
    
    for index,row in defenders.iterrows():
        if playDirection == "right" and los < row["x"]:
            players_x.append(row["x"])
        elif playDirection == "left" and los > row["x"]:
            players_x.append(row["x"])
        
    return abs(max(players_x) - min(players_x))

# %%
single_summary["heightDifference"] = single_summary.index.map(calculateHeight) - static_defense.loc["2018090600:1037:1"]["height"]

# %%
def calculateWidth(playId):
    defenders = defense_fpf.loc[playId]
    playDirection = defenders["playDirection"].values[0]
    los = plays.loc[playId]["absoluteYardlineNumber"]
    
    players_y = []
    
    for index,row in defenders.iterrows():
        if playDirection == "right" and los < row["x"]:
            players_y.append(row["y"])
        elif playDirection == "left" and los > row["x"]:
            players_y.append(row["y"])
        
    return max(players_y) - min(players_y)

# %%
single_summary["widthDifference"] = single_summary.index.map(calculateWidth) - static_defense.loc["2018090600:1037:1"]["width"]

# %% [markdown]
# # se pueden añadir las características estáticas del comienzo o el cluster.

# %% [markdown]
# # Game context features(g): down, score ...

# %%
single_summary["homeScore"] = plays.loc["2018090600:1037:1"]["preSnapHomeScore"]

# %%
single_summary["visitorScore"] = plays.loc["2018090600:1037:1"]["preSnapVisitorScore"]

# %%
single_summary["down"] = plays.loc["2018090600:1037:1"]["down"]

# %%
single_summary["quarter"] = plays.loc["2018090600:1037:1"]["quarter"]

# %%
single_summary["yardsToGo"] = plays.loc["2018090600:1037:1"]["yardsToGo"]

# %%
def obtainYardsToEndZone(playId):
    absoluteYard = plays.loc["2018090600:1037:1"]["absoluteYardlineNumber"]
    direction = defense.loc["2018090600:1037:1"]["playDirection"][0]
    if direction == "right":
        value = 120 - absoluteYard
    elif direction == "left":
        value = absoluteYard - 10
        
    return value

# %%
single_summary["yardsToEndZone"] = single_summary.index.map(obtainYardsToEndZone)

# %%
single_summary["gameClock"] = plays.loc["2018090600:1037:1"]["gameClock"]

# %%
single_summary
# Out:
#                     playerId  areaDifference  numberPlayersDeep  \
# id
# 2018090600:1037:1  2539334.0         164.095                  2
# 2018090600:1037:1  2539653.0         164.095                  2
# 2018090600:1037:1  2543850.0         164.095                  2
# 2018090600:1037:1  2555162.0         164.095                  2
# 2018090600:1037:1  2555255.0         164.095                  2
# 2018090600:1037:1  2555543.0         164.095                  2
# 2018090600:1037:1  2556445.0         164.095                  2
#
#                    numberPlayersDeepDifference  numberPlayersUnderneath  \
# id
# 2018090600:1037:1                            1                        4
# 2018090600:1037:1                            1                        4
# 2018090600:1037:1                            1                        4
# 2018090600:1037:1                            1                        4
# 2018090600:1037:1                            1                        4
# 2018090600:1037:1                            1                        4
# 2018090600:1037:1                            1                        4
#
#                    homeScore  visitorScore  down  quarter  yardsToGo  \
# id
# 2018090600:1037:1        0.0           3.0     3        2          7
# 2018090600:1037:1        0.0           3.0     3        2          7
# 2018090600:1037:1        0.0           3.0     3        2          7
# 2018090600:1037:1        0.0           3.0     3        2          7
# 2018090600:1037:1        0.0           3.0     3        2          7
# 2018090600:1037:1        0.0           3.0     3        2          7
# 2018090600:1037:1        0.0           3.0     3        2          7
#
#                    yardsToEndZone gameClock  densityDifference  \
# id
# 2018090600:1037:1            57.0  12:53:00           0.036564
# 2018090600:1037:1            57.0  12:53:00           0.036564
# 2018090600:1037:1            57.0  12:53:00           0.036564
# 2018090600:1037:1            57.0  12:53:00           0.036564
# 2018090600:1037:1            57.0  12:53:00           0.036564
# 2018090600:1037:1            57.0  12:53:00           0.036564
# 2018090600:1037:1            57.0  12:53:00           0.036564
#
#                    heightDifference  widthDifference
# id
# 2018090600:1037:1              5.41             5.28
# 2018090600:1037:1              5.41             5.28
# 2018090600:1037:1              5.41             5.28
# 2018090600:1037:1              5.41             5.28
# 2018090600:1037:1              5.41             5.28
# 2018090600:1037:1              5.41             5.28
# 2018090600:1037:1              5.41             5.28
